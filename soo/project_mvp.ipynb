# %%
import csv

def find_all_products_by_efficacy(filepath, target_efficacy):
    """
    CSV 파일에서 특정 효능을 가진 "모든" 제품을 찾아 반환합니다.

    Args:
        filepath (str): CSV 파일 경로.
        target_efficacy (str): 사용자가 찾는 효능 (예: "보습").

    Returns:
        list: 제품 정보가 담긴 딕셔너리 리스트.
    """
    found_products = []
    
    with open(filepath, mode='r', encoding='utf-8-sig') as infile:
        # CSV 파일을 딕셔너리 형태로 읽어옵니다.
        reader = csv.DictReader(infile)
        
        # 각 제품(행)을 순회합니다.
        for row in reader:
            # '효능' 컬럼이 존재하고, 해당 효능을 포함하는지 확인합니다.
            if '효능' in row and target_efficacy in row['효능']:
                found_products.append(row)
                    
    return found_products

# --- 메인 실행 부분 ---
if __name__ == '__main__':
    # 이 스크립트가 실행되는 위치에 'product_data.csv' 파일이 있다고 가정합니다.
    csv_filepath = 'product_data.csv'
    
    # 예시: '보습' 효능을 가진 "모든" 제품을 찾아보기
    user_request = '보습'
    
    print(f"'{user_request}' 효능을 가진 모든 제품을 검색합니다...")
    products = find_all_products_by_efficacy(csv_filepath, user_request)
    
    if products:
        print(f"\n[총 {len(products)}개의 제품 검색 완료]")
        for i, product in enumerate(products):
            print(f"{i+1}. {product['제품명']}")
    else:
        print("\n해당 효능을 가진 제품을 찾지 못했습니다.")
# Out:
# '보습' 효능을 가진 모든 제품을 검색합니다...
#
# [총 105개의 제품 검색 완료]
# 1. 아쿠아 오아시스 토너
# 2. 1025 독도 토너
# 3. 원더 세라마이드 모찌 토너
# 4. 다이브인 저분자 히알루론산 토너
# 5. 초저분자 히아루론산 토너
# 6. 판테놀 베리어 토너
# 7. 올리고 히알루론산 딥 토너
# 8. 하이드라 셀 부스팅 토너
# 9. 무알콜 뮤신 에센스 토너
# 10. 어성초 77 수딩 토너
# 11. 어성초 진정해 수분 토너
# 12. 나인 토너
# 13. 비피다 바이옴 앰플 토너
# 14. 리얼 히알루로닉 100 토너
# 15. 시카테롤 토너
# 16. 세라마이드 아토 로션
# 17. MLE 로션
# 18. 더 심플 데일리 로션
# 19. 아토베리어365 로션
# 20. 1025 독도 로션
# 21. 수딩 젤 로션
# 22. 서양송악 순수 로션
# 23. 탄탄 모공 펩타노산™ 단백질 로션
# 24. 판테놀 베리어 에멀전
# 25. 스킨 베리어 카밍 로션
# 26. 제주 말차 로우 피에이치 수딩 에멀전 크림
# 27. 모이스춰라이징 로션
# 28. 엑토인 로션
# 29. DMT 페이셜 로션
# 30. 소나무 진정 시카 로션
# 31. 다이브인 저분자 히알루론산 세럼
# 32. 리얼 히알루로닉 블루 100 앰플
# 33. PDRN 히알루론산 캡슐 100 세럼
# 34. 데일리 컨셔스 세럼
# 35. 아쿠아 스쿠알란 세럼
# 36. 마데카소사이드 흔적 리페어 세럼
# 37. 베러 밸런스 앰플
# 38. 트리플 이펙트 시너지 세럼
# 39. 베리어덤 링거 앰플
# 40. 아토베리어365 크림
# 41. 아쿠아 스쿠알란 수분크림
# 42. 다이브인 저분자 히알루론산 수딩 크림
# 43. 녹두 모공 타이트업 수딩 크림
# 44. 레드 블레미쉬 클리어 수딩 크림
# 45. PDRN 히알루론산 100 수분 크림
# 46. 다이브인 저분자 히알루론산 크림
# 47. 마다가스카르 리얼 수분크림
# 48. 진정한 수분크림
# 49. 어성초 히알루론 수딩 크림
# 50. 인테카 수딩 크림
# 51. 모이스춰 닥터 크림
# 52. 밸런스풀 시카 진정 크림
# 53. 포어 더블 리커버리 바나티놀 크림
# 54. 시카좀 카밍 워터 젤 크림
# 55. 시카플라스트 밤 B5+
# 56. 순정 판텐소사이드 10 시카 밤
# 57. 콜라겐 앰플 스틱
# 58. MLE 크림 스틱 밤
# 59. 비자 시카 밤
# 60. 시카이드 밤
# 61. 레드수딩 어드밴스드 릴리프밤
# 62. 인텐시브 SOS 플러스 밤
# 63. 베리어덤 릴리프 밤
# 64. 안티퍼티그 아이 컨투어 스틱
# 65. 더모이스처 배리어.D 멀티 밤
# 66. 판테놀 스틱밤
# 67. 울트라 훼이셜 베리어 스틱 밤
# 68. 다시마 앰플 클렌징폼
# 69. 다이브인 저분자 히알루론산 클렌징 폼
# 70. 아쿠아 라이스 약산성 클렌징폼
# 71. 릴리프 하이드레이션 라이트 폼 클렌저
# 72. 퓨어&딥 클렌징 폼
# 73. 프레시 클렌저 떡솝 [그린]
# 74. 리커버리 머드 팩투폼 클렌저
# 75. 포어 퓨리파잉 살리실산 포밍 클렌저
# 76. 1025 독도 클렌저
# 77. 그린 토마토 클레이 팩 클렌저
# 78. 세이프 미 릴리프 모이스처 클렌징폼
# 79. 마데카소사이드 에센셜 마스크 [흔적리페어]
# 80. 다이브인 저분자 히알루론산 마스크
# 81. 올리브 시카 카밍 앰플 마스크
# 82. 수퍼 아쿠아겔 오아시스 앰플 마스크
# 83. 다시마 콜라겐 퍼밍 마스크
# 84. 펩타테놀 수분 밸런스 겔 마스크
# 85. 에센셜 마스크 [티트리]
# 86. 밸런스풀 시카 마스크
# 87. 하이퍼 마스크 [콜라겐]
# 88. 핑크 콜라겐 앰플 마스크
# 89. 쿨링 마스크 [시카]
# 90. 시카 리페어 판테놀 마스크
# 91. 슈퍼 콜라겐 마스크
# 92. 자작나무 수분 선크림
# 93. 히알루론산 프레쉬 선 세럼
# 94. 워터풀 선크림 [에센스]
# 95. 맑은 어성초 진정 수분 선크림
# 96. 릴리프 하이드레이션 라이트 썬스크린
# 97. 다이브인 무기자차 마일드 선크림
# 98. 그린 마일드 업 선 플러스
# 99. 마다가스카르 센텔라 히알루-시카 워터핏 선 세럼
# 100. 선뮤즈 모이스처 선크림
# 101. 마데카소사이드 수분 선세럼 흔적 리페어
# 102. 덕만이 무기차자 썬크림
# 103. 바이옴 레미디 톤업 선크림 [보라]
# 104. 썬스크린 [레이저UV]
# 105. 올 데이 에어리 선크림

# %%
import csv
import os
from openai import OpenAI

# --- 사전 준비: OpenAI API 키 설정 ---
# 이 코드는 환경 변수에서 API 키를 자동으로 불러옵니다.
# 코드를 실행하기 전에 터미널에서 API 키를 설정해주세요.
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

if not os.getenv("OPENAI_API_KEY"):
    print("="*60)
    print("경고: OPENAI_API_KEY 환경 변수가 설정되지 않았습니다.")
    print("LLM 분석 기능이 작동하지 않습니다.")
    print("터미널에서 'export OPENAI_API_KEY=\"your_api_key\"'를 실행해주세요.")
    print("="*60)


def find_all_products_by_efficacy(filepath, target_efficacy):
    """
    CSV 파일에서 특정 효능을 가진 "모든" 제품을 찾아 반환합니다.
    """
    found_products = []
    
    with open(filepath, mode='r', encoding='utf-8-sig') as infile:
        reader = csv.DictReader(infile)
        for row in reader:
            if '효능' in row and target_efficacy in row['효능']:
                found_products.append(row)
                    
    return found_products

def analyze_ingredients_with_llm(ingredients_text, user_context):
    """
    OpenAI API를 호출하여 제품 성분을 분석하고 유의 성분을 반환합니다.

    Args:
        ingredients_text (str): 분석할 제품의 전체 성분 문자열.
        user_context (str): 사용자의 피부 타입 등 컨텍스트 (예: "건성 피부").

    Returns:
        str: LLM이 분석한 유의 성분 및 이유.
    """
    if not os.getenv("OPENAI_API_KEY"):
        return "API 키가 설정되지 않아 분석할 수 없습니다."

    prompt = f"""
    당신은 화장품 성분 분석 전문가입니다.

    [사용자 정보]: {user_context}
    [제품 전성분]: {ingredients_text}

    위 [사용자 정보]를 가진 사람에게 [제품 전성분] 목록에서 잠재적으로 자극을 주거나 유의해야 할 성분이 있는지 웹 검색을 통해 분석해주세요.
    결과는 "성분명: 이유" 형식으로, 여러 개일 경우 쉼표(,)로 구분해서 알려주세요.
    만약 특별히 유의할 성분이 없다면 "특별히 유의할 성분 없음"이라고 답변해주세요.
    """
    
    try:
        print(f"\n> OpenAI API 호출 중... (제품: {ingredients_text[:20]}...)")
        
        response = client.chat.completions.create(
            model="gpt-4o",  # OpenAI의 gpt-4o 모델을 사용합니다.
            messages=[
                {"role": "system", "content": "You are a helpful assistant specialized in cosmetic ingredient analysis."},
                {"role": "user", "content": prompt}
            ]
        )
        
        # API 응답에서 실제 텍스트 내용을 추출합니다.
        result = response.choices[0].message.content.strip()
        print(f"> API 응답 수신 완료.")
        return result

    except Exception as e:
        print(f"!! OpenAI API 호출 중 오류 발생: {e}")
        return "API 호출 중 오류가 발생했습니다."

# --- 메인 실행 부분 ---
if __name__ == '__main__':
    csv_filepath = 'product_data.csv'
    
    # 1. 사용자 요청 및 컨텍스트 정의
    user_request_efficacy = '보습'
    user_context_info = '건성 피부'
    
    print(f"'{user_request_efficacy}' 효능을 가진 제품을 '{user_context_info}' 기준으로 분석합니다...")
    
    # 2. 효능에 맞는 모든 제품 가져오기
    products_found = find_all_products_by_efficacy(csv_filepath, user_request_efficacy)
    
    analyzed_products = []
    if products_found:
        # 3. 각 제품의 성분을 LLM으로 분석
        for product in products_found:
            ingredients = product.get('전성분', '')
            if ingredients:
                caution_info = analyze_ingredients_with_llm(ingredients, user_context_info)
                product['유의성분'] = caution_info
            else:
                product['유의성분'] = "전성분 정보 없음"
            
            analyzed_products.append(product)

    # 4. 최종 결과 출력
    if analyzed_products:
        print(f"\n\n======= 최종 분석 결과 =======")
        for i, product in enumerate(analyzed_products):
            print(f"✅ {i+1}. {product.get('제품명', 'N/A')}")
            print(f"   👉 유의 성분 분석: {product.get('유의성분', 'N/A')}")
            
    else:
        print("\n해당 효능을 가진 제품을 찾지 못했습니다.")
# Out:
# '보습' 효능을 가진 제품을 '건성 피부' 기준으로 분석합니다...
#
# > OpenAI API 호출 중... (제품: 정제수;다이프로필렌글라이콜;부틸렌글라...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;펜틸렌...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이프로필렌글라이콜;글리세린;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;다이프로필렌글라...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;메틸프로판다이올;1,2-헥산다...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;판테놀;다이프로...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;1,2-헥산다이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;1,2...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;판테놀...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 약모밀꽃/잎/줄기수(77%);정제수;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;약모밀추출물;부틸렌글라이콜;다...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;2,3-부탄다이올;판...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;프로판...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 하이드롤라이즈드하이알루로닉애씨드(93...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;병풀추출물;1,2...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;프로판다이올;하이드로...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;카프릴릭/카프릭트라이글리세라이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;펜틸렌글라이콜;비...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;다이메...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;퀸즈랜드넛오일;1,2...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;펜타에...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;부틸렌글라이콜;카프릴...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;프로판다이올;카...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;판테놀;프로판다이올;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;프로판다이올;카프릴릭...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 녹차수(358,800ppm);정제수;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;아이소프로필팔미테이트...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜다이카프릴레이트/...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;카프릴릭/카프릭트라이글리세라이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;1,2-헥산다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;다이프...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;펜틸렌글라이콜;글...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;프로판다이올;글...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 병풀추출물;부틸렌글라이콜;글리세린;정...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;부틸렌글라이콜;메틸프...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;부틸렌글라이콜;프로판...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;부틸렌글라이콜;글...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 밤부사불가리스수;정제수;해바라기씨오일...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;글리세린;1,2-...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;부틸렌...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;스쿠알란(150,000ppm)...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;1,2...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;부틸렌글라이콜;다이프...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;부틸렌글라이콜;다이카...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;스쿠알란;글리세린;나이아신아마...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;다이프...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 병풀잎수(80%);글리세린;하이드로제...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이프로필렌글라이콜;글리세린;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;비닐다이메티콘;부틸렌...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;글리세린;글리세릴...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;세틸에틸헥사노에이트;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;헵틸운...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 바나나수(660,000ppm);판테놀...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;1,2...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;판테놀;스쿠알란...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;판테놀;스쿠알란...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 해바라기씨오일;폴리글리세릴-2트라이아...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 해바라기씨오일;세테아릴알코올;시어버터...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;글리세린;사이클로...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;부틸렌글라이콜;카프릴...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;올리브오일;글리세린;펜틸렌글라...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;카프릴릭/카프릭트라이글리세라이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이프로필렌글라이콜;글리세린;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 프로필렌글라이콜;글리세린;정제수;다마...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;다이프로필렌글라이콜;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 해바라기씨오일;세테아릴알코올;시어버터...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수다이카프릴릴카보네이트부틸렌글라이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;다시마즙(10%);미...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;소듐코코일글라이시네이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 쌀추출물;글리세린;소듐코코일글라이시네...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;소듐코코일글라이시네이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 글리세린;정제수;미리스틱애씨드;스테아...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 글리세린;정제수;소듐코코일이세티오네이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;소듐코코일이세티오네이트;글리세...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;소듐코코일글라이시네이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;소듐코코일이세티오네이트;글리세...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 토마토수(49%);미리스틱애씨드;글리...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;소듐코코일이세티오네이트;글리세...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;프로판다이올;다이프로필렌글라이...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;다이프...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;다이프로필렌글라이콜;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;1,2...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;프로필렌글라이콜;메틸...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;다이프로필렌글라이콜;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;다이프로필렌글라이콜;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;부틸렌글라이콜;글리세린;다이프...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;다이프로필렌글라이콜;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;부틸렌글라이콜;다이프...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;1,2-헥산다이올;병...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;나이아신아마이드;세틸...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;글리세린;다이프로필렌글라이콜;...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;프로판다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;프로판다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;사이클로펜타실록세인;티타늄디옥...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;프로판다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;프로판다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;징크옥사이드;사이클로헥사실록세...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;징크옥사이드;프로판다이올;부틸...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;프로판다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;프로판다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;프로판다이올...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;징크옥사이드(17%);프로필헵...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;부틸옥틸살리...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;징크옥사이드;다이부틸아디페이트...)
# > API 응답 수신 완료.
#
# > OpenAI API 호출 중... (제품: 정제수;다이부틸아디페이트;부틸옥틸살리...)
# > API 응답 수신 완료.
#
#
# ======= 최종 분석 결과 =======
# ✅ 1. 아쿠아 오아시스 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 2. 1025 독도 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 3. 원더 세라마이드 모찌 토너
#    👉 유의 성분 분석: 이 제품의 전성분을 건성 피부에 대해 분석한 결과, 잠재적으로 유의할 성분은 다음과 같습니다.
#
# 1. **레몬껍질오일**: 시트러스 계열 오일은 일부 사용자에게 자극을 줄 수 있으며, 햇빛에 의해 민감성을 유발할 수 있습니다.
# 2. **로즈우드오일**: 에센셜 오일은 피부에 따라 자극을 줄 수 있으므로 주의가 필요합니다.
# 3. **리날룰, 리모넨**: 향료 성분으로, 알레르기 반응을 일으킬 수 있는 가능성이 있는 성분입니다.
#
# 그 외의 성분은 일반적으로 건성 피부에 적합하며, 수분 공급과 보호에 도움이 될 수 있습니다. 그러나 민감한 피부일 경우 패치 테스트를 권장합니다.
# ✅ 4. 다이브인 저분자 히알루론산 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 5. 초저분자 히아루론산 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 6. 판테놀 베리어 토너
#    👉 유의 성분 분석: 건성 피부에 대해 분석한 결과, 주의할 만한 자극성 성분은 다음과 같습니다:
#
# 1. **시트릭애씨드**: 피부의 산도를 조절하는 성분으로, 민감한 사람에게는 자극을 줄 수 있습니다.
#
# 위 성분을 제외하면 나머지 성분들은 대부분 보습 및 진정 효과가 있거나 피부에 직접적인 자극을 줄 가능성이 낮은 성분들입니다. 따라서 전반적으로 해당 제품은 건성 피부에 적합한 성분으로 구성되어 있다고 판단됩니다.
# ✅ 7. 올리고 히알루론산 딥 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 8. 하이드라 셀 부스팅 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 9. 무알콜 뮤신 에센스 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 10. 어성초 77 수딩 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 11. 어성초 진정해 수분 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 12. 나인 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 13. 비피다 바이옴 앰플 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 14. 리얼 히알루로닉 100 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 15. 시카테롤 토너
#    👉 유의 성분 분석: 특별히 유의할 성분 없음.
# ✅ 16. 세라마이드 아토 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 17. MLE 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 18. 더 심플 데일리 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 19. 아토베리어365 로션
#    👉 유의 성분 분석: [제품 전성분] 목록을 살펴본 결과, 건성 피부에 사용할 때 특별히 유의해야 할 성분은 없습니다. 이 제품은 주로 보습에 중점을 두고 있으며, 건성 피부에 적합한 성분들로 구성되어 있습니다. "특별히 유의할 성분 없음"이라고 판단됩니다.
# ✅ 20. 1025 독도 로션
#    👉 유의 성분 분석: 저장된 정보에 기반하여, 제공된 제품 성분 목록을 분석한 결과, 건성 피부를 가진 사용자에게 특별히 유의할 성분은 없습니다. 제품의 성분은 대부분 보습 및 피부 장벽 강화에 도움을 주는 성분들로 구성되어 있습니다. "특별히 유의할 성분 없음"으로 보입니다.
# ✅ 21. 수딩 젤 로션
#    👉 유의 성분 분석: 사용자 정보에 따르면 건성 피부를 가지고 계십니다. 해당 피부 유형은 보습과 자극 완화가 중요합니다. 주어진 화장품의 전성분을 분석한 결과, 특별히 자극 가능성이 있거나 건성 피부에 유의해야 할 성분은 아래와 같습니다:
#
# 1. **카보머**: 건조감을 유발할 수 있는 성분으로, 피부에 보호막을 형성해 수분 손실을 방지하지만 일부 민감한 피부에는 건조함을 느낄 수 있습니다.
# 2. **부틸렌글라이콜**: 일반적으로 안전한 성분이지만, 일부 피부에서는 드물게 자극을 일으킬 수 있습니다.
# 3. **광곽향오일, 캐모마일꽃오일, 살비아오일, 블루탄지꽃오일, 멕시칸주니퍼오일**: 에센셜 오일로, 건성 피부를 포함하여 민감한 피부에서 자극을 유발할 수 있습니다.
#
# 이 외의 성분들은 일반적으로 건성 피부에 적합한 보습 및 보호 기능을 제공하는 성분들이 포함되어 있습니다. 사용하시기 전, 패치 테스트를 통해 개인적인 민감 반응을 확인하는 것이 좋습니다.
# ✅ 22. 서양송악 순수 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 23. 탄탄 모공 펩타노산™ 단백질 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 24. 판테놀 베리어 에멀전
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 25. 스킨 베리어 카밍 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 26. 제주 말차 로우 피에이치 수딩 에멀전 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 27. 모이스춰라이징 로션
#    👉 유의 성분 분석: [사용자 정보]에 제공된 화장품의 [제품 전성분] 목록을 검토한 결과, 건성 피부에 특별히 자극을 줄 가능성이나 유의할 성분이 아래와 같이 확인되었습니다.
#
# 벤질알코올: 벤질알코올은 보존제로 사용되며 소량으로는 안전하지만, 민감한 피부나 건성 피부에서는 건조함을 유발할 수 있습니다.
#
# 하지만 사용된 농도를 고려할 때, 일반적인 경우에는 큰 문제가 되지 않을 수 있습니다. 건성 피부라면 보습에 신경 써서 사용하시면 좋겠습니다. 그 외에 특별히 유의할 성분은 없습니다.
# ✅ 28. 엑토인 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 29. DMT 페이셜 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 30. 소나무 진정 시카 로션
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 31. 다이브인 저분자 히알루론산 세럼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 32. 리얼 히알루로닉 블루 100 앰플
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 33. PDRN 히알루론산 캡슐 100 세럼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 34. 데일리 컨셔스 세럼
#    👉 유의 성분 분석: 제품 전성분을 분석해본 결과, 특별히 유의할 성분은 없습니다. 제품은 건성 피부에 적합할 것으로 보입니다. 다양한 보습 성분(하이알루로닉애씨드, 소듐하이알루로네이트, 글리세린 등)과 피부 진정 성분(병풀추출물, 무궁화나무껍질추출물 등)이 포함되어 있어 건성 피부에 도움을 줄 수 있습니다.
# ✅ 35. 아쿠아 스쿠알란 세럼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 36. 마데카소사이드 흔적 리페어 세럼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 37. 베러 밸런스 앰플
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 38. 트리플 이펙트 시너지 세럼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 39. 베리어덤 링거 앰플
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 40. 아토베리어365 크림
#    👉 유의 성분 분석: 건성 피부를 가진 사용자의 경우, 제품의 성분 목록에서 주로 피부에 보습과 보호 기능을 제공할 수 있는 성분들이 포함되어 있습니다. 다음은 분석 결과입니다:
#
# - 나이아신아마이드: 일부 민감한 피부에서는 간혹 자극을 느낄 수 있습니다. 하지만 건성 피부에는 일반적으로 유익하며, 피부 장벽을 강화하고 수분을 유지하는 데 도움을 줄 수 있습니다.
#
# 그러나 전체적으로 이 성분 목록에는 건성 피부에 특별히 유의해야 할 성분은 없어 보입니다.
#
# 따라서 결론적으로:
#
# "특별히 유의할 성분 없음"
# ✅ 41. 아쿠아 스쿠알란 수분크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 42. 다이브인 저분자 히알루론산 수딩 크림
#    👉 유의 성분 분석: 조사 결과, 제공된 성분 목록에서 건성 피부에 특별히 자극을 주거나 유의해야 할 성분은 발견되지 않았습니다. 전반적으로 제품에는 보습 성분과 피부 진정 성분들이 잘 포함되어 있어 건성 피부에도 적합할 것으로 보입니다.
#
# "특별히 유의할 성분 없음"
# ✅ 43. 녹두 모공 타이트업 수딩 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 44. 레드 블레미쉬 클리어 수딩 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 45. PDRN 히알루론산 100 수분 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 46. 다이브인 저분자 히알루론산 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 47. 마다가스카르 리얼 수분크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 48. 진정한 수분크림
#    👉 유의 성분 분석: 이 제품 성분 목록을 검토한 결과, 건성 피부 유형에 특별히 자극을 줄 가능성이 있는 성분은 찾지 못했습니다. 제품에 포함된 대부분의 성분들은 보습, 진정 및 피부 장벽 강화에 도움을 주는 성분들입니다. 따라서, "특별히 유의할 성분 없음"이라고 답변드릴 수 있습니다. 다만, 개개인의 피부 상태에 따라 민감하게 반응할 수 있음을 고려하여, 새로운 제품을 사용하기 전에는 항상 패치 테스트를 권장합니다.
# ✅ 49. 어성초 히알루론 수딩 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 50. 인테카 수딩 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 51. 모이스춰 닥터 크림
#    👉 유의 성분 분석: [사용자 정보]에 따라 건성 피부에 적합하지 않거나 잠재적으로 자극을 줄 수 있는 성분을 분석한 결과, 아래와 같이 나왔습니다.
#
# 1. **자몽껍질오일 (Citrus Paradisi (Grapefruit) Peel Oil)**: 시트러스 계열 오일은 일부 사람들에게 광독성이나 자극을 유발할 수 있습니다.
# 2. **리모넨 (Limonene)**: 시트러스 오일에 흔히 포함된 성분으로, 산화 시 피부 자극을 유발할 수 있습니다.
#
# 나머지 성분들은 대체로 건성 피부에 적합하며, 수분 공급과 보습에 도움이 되는 성분들이 많이 포함되어 있습니다. 이점 참고하시어 사용하시기 바랍니다.
# ✅ 52. 밸런스풀 시카 진정 크림
#    👉 유의 성분 분석: 제품 성분 목록을 검토한 결과, 건성 피부를 가진 사용자에게 특별히 유의해야 할 성분은 다음과 같습니다:
#
# - 카프릴로일살리실릭애씨드: 살리실산 유도체로, 각질 제거 효과가 있어 건성 피부에는 자극적일 수 있습니다.
# - 카프릴릭/카프릭트라이글리세라이드: 일반적으로 무난하지만 매우 드물게 모공을 막아 트러블을 유발할 수 있습니다.
# - 1,2-헥산다이올: 보습 및 방부 효과가 있지만, 일부 민감한 피부에는 자극이 될 수 있습니다.
#
# 이 외에는 건성 피부에 특별히 유의할 성분은 없습니다. 다만, 개별 피부 상태에 따라 다를 수 있으니 사용 전에 패치 테스트를 권장합니다.
# ✅ 53. 포어 더블 리커버리 바나티놀 크림
#    👉 유의 성분 분석: 건성 피부를 가진 사용자가 제품의 전성분을 검토할 때 잠재적으로 자극을 줄 수 있는 성분이나 유의할 만한 성분은 다음과 같습니다:
#
# 1. 오렌지껍질오일: 감귤류 오일은 피부에 향을 제공하는데, 민감한 사람에게는 자극을 줄 수 있습니다.
# 2. 하이드록시피나콜론레티노에이트: 레티노이드 계열의 성분으로, 민감한 피부에는 자극을 일으킬 수 있습니다.
# 3. 시트랄, 리모넨, 리날룰: 이러한 성분들은 천연 에센셜 오일에 포함되어 있을 수 있으며, 피부에 자극을 줄 가능성이 있습니다.
#
# 이 성분들은 건성 피부에 자극을 줄 가능성이 있으니 사용 시 모니터링하시는 것이 좋습니다. 기타 나머지 성분들은 대체로 건성 피부에 적합하며 수분 공급 및 보습에 도움이 되는 성분들입니다.
# ✅ 54. 시카좀 카밍 워터 젤 크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 55. 시카플라스트 밤 B5+
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 56. 순정 판텐소사이드 10 시카 밤
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 57. 콜라겐 앰플 스틱
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 58. MLE 크림 스틱 밤
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 59. 비자 시카 밤
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 60. 시카이드 밤
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 61. 레드수딩 어드밴스드 릴리프밤
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 62. 인텐시브 SOS 플러스 밤
#    👉 유의 성분 분석: "특별히 유의할 성분 없음"
# ✅ 63. 베리어덤 릴리프 밤
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 64. 안티퍼티그 아이 컨투어 스틱
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 65. 더모이스처 배리어.D 멀티 밤
#    👉 유의 성분 분석: 이 제품의 성분 목록을 기반으로 건성 피부를 가진 사용자에게 잠재적으로 자극을 줄 수 있는 성분을 분석하였습니다. 이 제품 성분 중 일반적으로 건성 피부에 자극을 줄 가능성이 있는 성분은 발견되지 않았습니다. 다만, 모든 피부 타입은 개개인의 피부 상태와 민감성에 따라 다르게 반응할 수 있으므로 새로운 제품을 사용할 때는 항상 패치 테스트를 권장합니다.
#
# 결론: 특별히 유의할 성분 없음.
# ✅ 66. 판테놀 스틱밤
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 67. 울트라 훼이셜 베리어 스틱 밤
#    👉 유의 성분 분석: 살리실릭애씨드: 살리실릭애씨드는 각질 제거제로 사용되며, 민감한 피부나 건성 피부의 경우 자극을 유발할 수 있습니다. 따라서 건성 피부를 가진 사용자의 경우 주의가 필요할 수 있습니다.
#
# 그 외에 특별히 유의할 성분은 보이지 않습니다.
# ✅ 68. 다시마 앰플 클렌징폼
#    👉 유의 성분 분석: 건성 피부를 가진 사용자에게 잠재적으로 유의해야 할 성분을 분석한 결과는 다음과 같습니다:
#
# 1. **살리실릭애씨드**: 살리실릭애씨드는 베타하이드록시산(BHA)로, 각질 제거 및 모공 청소에 사용됩니다. 하지만 건성 피부에는 자극을 줄 수 있어 주의가 필요합니다. 건성 피부의 경우 과도한 사용은 피부 건조를 악화시킬 수 있습니다.
#
# 2. **향료**: 화장품의 향을 위해 사용되지만 일부 민감성 피부 또는 특정 향 성분에 알레르기가 있는 경우 자극을 줄 수 있습니다.
#
# 위 성분은 건성 피부 사용자에게 자극을 줄 수 있으므로, 개인의 피부 상태에 따라 주의해서 사용하시길 권장드립니다. 그 외 성분은 특별히 유의할 사항이 없는 것으로 보입니다.
# ✅ 69. 다이브인 저분자 히알루론산 클렌징 폼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음.
# ✅ 70. 아쿠아 라이스 약산성 클렌징폼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 71. 릴리프 하이드레이션 라이트 폼 클렌저
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 72. 퓨어&딥 클렌징 폼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 73. 프레시 클렌저 떡솝 [그린]
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 74. 리커버리 머드 팩투폼 클렌저
#    👉 유의 성분 분석: 이 제품 성분 목록을 검토한 결과, 건성 피부를 가진 사용자에게 특별히 유의할 필요가 있는 성분은 없습니다.
#
# 다만, 일반적으로 주의할 수 있는 점은:
#
# - **시트릭애씨드**: 일부 민감한 피부 유형에서는 자극을 유발할 수 있지만, 대개는 제품 내 다른 성분들과 함께 문제를 일으키지 않습니다.
#
# - **유칼립투스잎오일**: 일부 사람들에게는 알레르기 반응을 일으킬 수 있으나, 일반적으로 낮은 농도로 사용되며 큰 문제가 되지 않습니다.
#
# 전반적으로, 이 성분들은 건성 피부에 큰 문제를 일으킬 위험이 없습니다. 제품 사용 중 피부가 건조하거나 자극이 발생한다면 사용을 중단하고 피부과 전문의와 상담하세요. 특별히 유의할 성분은 없는 것으로 판단됩니다.
# ✅ 75. 포어 퓨리파잉 살리실산 포밍 클렌저
#    👉 유의 성분 분석: 건성 피부를 가진 사용자가 유의해야 할 성분을 분석한 결과, 잠재적으로 주의가 필요한 성분은 다음과 같습니다:
#
# 1. **살리실릭애씨드 (Salicylic Acid)**: 건성 피부의 경우 살리실릭 애씨드와 같은 각질 제거제는 피부를 더 건조하게 만들 수 있으므로 주의가 필요합니다.
#
# 2. **시트릭애씨드 (Citric Acid)**: 산성 성분으로 가끔 자극을 유발할 수 있습니다. 건성 피부는 이러한 산성 성분에 민감할 수 있습니다.
#
# 3. **말릭애씨드 (Malic Acid)**: AHA(알파하이드록시애씨드)로 건성 피부에 민감도를 높일 수 있으므로주의해야 합니다.
#
# 이 외의 성분들은 일반적으로 건성 피부에 특별히 문제를 일으키지 않습니다. 하지만 신제품을 사용할 때는 패치 테스트 등을 통해 개인적인 반응을 확인하는 것이 좋습니다.
# ✅ 76. 1025 독도 클렌저
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 77. 그린 토마토 클레이 팩 클렌저
#    👉 유의 성분 분석: [사용자 정보]에 기반하여 건성 피부를 가진 사람에게 잠재적으로 자극을 줄 수 있거나 유의해야 할 성분을 분석한 결과는 다음과 같습니다:
#
# 1. 미리스틱애씨드: 건성 피부에 사용 시 약간의 건조감을 줄 수 있는 세정 성분입니다.
# 2. 라우릭애씨드: 지방산으로 클렌징 제품에 사용될 경우 건조감을 유발할 수 있습니다.
# 3. 포타슘하이드록사이드: 제품의 pH 조절제로 사용되며, 고농도일 경우 피부 자극을 줄 수 있습니다.
#
# 특별히 심각한 위험성이 큰 성분은 확인되지 않았지만, 건성 피부 특성과 이러한 성분들이 조합될 경우 건조함을 유발할 수 있으므로 보습제를 충분히 사용하는 것을 권장합니다.
# ✅ 78. 세이프 미 릴리프 모이스처 클렌징폼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 79. 마데카소사이드 에센셜 마스크 [흔적리페어]
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 80. 다이브인 저분자 히알루론산 마스크
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 81. 올리브 시카 카밍 앰플 마스크
#    👉 유의 성분 분석: 건성 피부를 가진 사용자가 주의할 만한 성분을 분석한 결과, 아래와 같은 성분을 확인할 수 있습니다:
#
# 1. 라벤더오일: 에센셜 오일은 경우에 따라 피부 자극을 줄 수 있으며, 특히 민감한 피부에서는 주의가 필요할 수 있습니다.
#
# 건성 피부가 특별히 주의할 성분은 위와 같은데, 많은 경우에 있어서는 민감성 여부에 따라 반응이 다를 수 있으니, 피부 반응을 살피면서 사용해야 합니다. 나머지 성분들은 일반적으로 건성 피부에 유익한 보습 및 진정 효과를 제공하는 성분들이며, 특별히 유의할 성분은 없습니다.
# ✅ 82. 수퍼 아쿠아겔 오아시스 앰플 마스크
#    👉 유의 성분 분석: 특별히 유의할 성분 없음.
# ✅ 83. 다시마 콜라겐 퍼밍 마스크
#    👉 유의 성분 분석: 제품의 성분 목록을 검토한 결과, 건성 피부에 잠재적으로 자극을 주거나 유의해야 할 성분은 다음과 같습니다:
#
# 1. 변성알코올: 고농도 알코올은 피부에 건조함을 유발할 수 있습니다.
# 2. 향료: 건성 피부의 경우, 향료는 자극을 유발할 수 있습니다.
#
# 이 두 성분이 건성 피부를 가진 사용자에게는 약간의 주의를 요할 수 있으므로 피부 상태를 잘 관찰하면서 사용하는 것이 좋습니다. 그러나 개인의 피부 반응은 다를 수 있으므로, 테스트 후 사용을 권장합니다.
# ✅ 84. 펩타테놀 수분 밸런스 겔 마스크
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 85. 에센셜 마스크 [티트리]
#    👉 유의 성분 분석: [사용자 정보]에 따르면 건성 피부를 가진 분이 사용하실 제품입니다. 제품의 [전성분]을 분석했을 때 포함된 성분 중 건성 피부에 잠재적으로 자극을 주거나 유의해야 할 성분은 다음과 같습니다.
#
# 1. 티트리추출물 및 티트리 관련 성분: 티트리추출물, 티트리잎오일, 화이트티트리잎추출물 등 여러 티트리 관련 성분이 포함되어 있습니다. 티트리는 항균 및 항염 작용을 하여 지성 피부나 여드름 피부에 유익할 수 있지만, 건성 피부에는 자극적일 수 있어 주의가 필요합니다.
#
# 2. 베르가모트오일: 감광성 물질로, 햇빛에 노출되면 피부를 민감하게 만들 수 있습니다. 건성 피부의 경우 민감도가 더 높아질 수 있습니다.
#
# 3. 알코올 및 기타 용매 성분: 페녹시에탄올, 메틸프로판다이올, 프로판다이올 등은 특정 용매 기능을 하며 피부에 따라 건조함을 유발할 수 있습니다.
#
# 나머지 성분들은 일반적으로 건성 피부에 큰 문제를 일으키지 않는 성분입니다. 그러나 민감한 피부를 가진 경우, 개인별로 다르게 반응할 수 있으므로 반드시 패치 테스트를 권장합니다.
# ✅ 86. 밸런스풀 시카 마스크
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 87. 하이퍼 마스크 [콜라겐]
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 88. 핑크 콜라겐 앰플 마스크
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 89. 쿨링 마스크 [시카]
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 90. 시카 리페어 판테놀 마스크
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 91. 슈퍼 콜라겐 마스크
#    👉 유의 성분 분석: 현재 주어진 제품의 전성분을 분석한 결과, 건성 피부에 특별히 자극을 줄 수 있는 성분이나 유의할 성분은 발견되지 않았습니다. 따라서 "특별히 유의할 성분 없음"이라고 말씀드릴 수 있습니다.
#
# 건성 피부에 적합한 성분들도 많이 포함되어 있어서, 수분과 영양 공급에 도움이 될 것으로 예상됩니다. 제품을 사용할 때 피부가 편안한지, 특별한 자극이 없는지 확인하며 사용해 보시는 것을 추천드립니다.
# ✅ 92. 자작나무 수분 선크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 93. 히알루론산 프레쉬 선 세럼
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 94. 워터풀 선크림 [에센스]
#    👉 유의 성분 분석: [사용자 정보]에 기반하여 [제품 전성분] 목록을 검토한 결과, 건성 피부의 경우 일반적으로 유의해야 할 잠재적인 자극 성분은 다음과 같습니다.
#
# 1. 에탄올: 건성 피부에 수분을 빼앗아 갈 수 있어 자극을 주거나 건조함을 유발할 수 있습니다.
# 2. 향료: 특정 사용자의 피부에 자극을 줄 수 있으며, 알레르기 반응을 일으킬 가능성이 있습니다.
#
# 나머지 성분은 건성 피부에 특별히 주의가 필요한 성분으로 분류되지 않습니다. 이 제품은 수분 공급 성분도 다수 포함하고 있어 건성 피부에 긍정적인 효과를 줄 수 있습니다.
#
# 따라서 "특별히 유의할 성분 없음"이라고 말씀드릴 수 있습니다. 다만, 피부 민감도는 개인마다 다르므로 새로 사용하기 전에 패치 테스트를 권장합니다.
# ✅ 95. 맑은 어성초 진정 수분 선크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음.
# ✅ 96. 릴리프 하이드레이션 라이트 썬스크린
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 97. 다이브인 무기자차 마일드 선크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 98. 그린 마일드 업 선 플러스
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 99. 마다가스카르 센텔라 히알루-시카 워터핏 선 세럼
#    👉 유의 성분 분석: [사용자 정보]인 건성 피부에 대해 [제품 전성분]을 분석했을 때, 잠재적으로 유의해야 할 성분은 다음과 같습니다:
#
# 1. **에틸헥실트리아존**: 자외선 차단제 성분으로, 일부 민감한 피부에 자극을 줄 수 있습니다. 건성 피부는 보통 민감할 수 있으므로 주의가 필요할 수 있습니다.
# 2. **아크릴레이트/C10-30알킬아크릴레이트크로스폴리머**: 사용감 개선을 위한 성분으로, 일부 사용자가 이 성분에 대해 건조함을 경험할 수 있습니다.
#
# 일반적으로 이 제품의 성분들은 건성 피부에 특별히 큰 문제를 일으키지 않으며, 보습과 항산화 성분도 포함되어 있어 보습효과를 기대할 수 있습니다. 그러나, 위의 두 성분은 개개인의 피부 상태에 따라 다르게 반응할 수 있으므로 주의가 필요할 수 있습니다.
#
# 따라서, "에틸헥실트리아존: 일부 민감한 피부에 자극 가능성, 아크릴레이트/C10-30알킬아크릴레이트크로스폴리머: 건조함 유발 가능성"입니다.
#
# 특별히 민감하지 않다면 "특별히 유의할 성분 없음"으로 볼 수 있습니다.
# ✅ 100. 선뮤즈 모이스처 선크림
#    👉 유의 성분 분석: 이 제품의 전성분을 분석한 결과, 특별히 건성 피부에 유의해야 할 성분은 발견되지 않았습니다. 오히려 보습에 도움이 될 수 있는 글리세린, 부틸렌글라이콜, 펜틸렌글라이콜 등의 성분이 포함되어 있습니다.
#
# 따라서, "특별히 유의할 성분 없음"이라고 답변 드립니다.
# ✅ 101. 마데카소사이드 수분 선세럼 흔적 리페어
#    👉 유의 성분 분석: 사용자 정보에 따르면 건성 피부를 가지고 계신데, 건성 피부에는 주로 수분 보충과 피부 장벽 강화가 중요합니다. 제공된 전성분 목록을 검토한 결과, 건성 피부에 특별히 유의해야 할 성분은 다음과 같습니다:
#
# 1. 알코올류: 하이드록시에틸우레아, 베헤닐알코올, 아이소도데케인 - 이러한 성분은 일부 피부에 건조함을 유발할 수 있습니다.
# 2. 다이메티콘/비닐다이메티콘크로스폴리머 - 실리콘 계열 성분으로 보습막을 형성하지만, 일부 민감한 건성 피부에는 모공을 막아 트러블을 유발할 수 있습니다.
#
# 단, 전반적으로 본 제품은 다양한 보습 성분(글리세린, 판테놀, 히알루론산 등)과 진정 성분(병풀 추출물 등)을 포함하고 있어 특별히 자극을 유발할 가능성은 낮습니다. 제품 사용 후 피부 상태를 점검하며 사용하시는 것이 좋겠습니다.
#
# 전반적으로 "특별히 유의할 성분 없음"이라고 판단됩니다.
# ✅ 102. 덕만이 무기차자 썬크림
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 103. 바이옴 레미디 톤업 선크림 [보라]
#    👉 유의 성분 분석: 이 제품의 성분을 분석한 결과, 건성 피부에 특별히 유의할 성분은 다음과 같습니다:
#
# 1. **카올린**: 흡착력이 뛰어난 성분으로, 건성 피부에는 피부를 더욱 건조하게 만들 수 있습니다.
# 2. **알코올류 (예: 세테아릴알코올)**: 건성 피부에는 알코올 성분이 피부를 더 건조하게 만들 수 있습니다. 하지만 세테아릴알코올은 보통 지방알코올로, 보습 효과도 있으니 피부 상태에 따라 다르게 반응할 수 있습니다.
#
# 나머지 성분들은 일반적으로 건성 피부에 도움이 되는 성분들이거나 중성인 성분들이므로, 특별히 유의할 필요는 없습니다. 대신, 사용자 분의 피부에 맞는 제품인지 테스트를 통해 확인해보시는 것이 좋습니다. 추가적인 자극이나 알레르기 반응이 있을 경우 사용을 중단하시고 전문가의 상담을 받으시기 바랍니다.
# ✅ 104. 썬스크린 [레이저UV]
#    👉 유의 성분 분석: 특별히 유의할 성분 없음
# ✅ 105. 올 데이 에어리 선크림
#    👉 유의 성분 분석: [사용자 정보]에 따라 건성 피부에 적합한 제품 성분인지 살펴보았습니다. 제공된 제품 전성분 목록을 분석한 결과, 건성 피부에 잠재적으로 자극을 줄 수 있는 성분은 아래와 같습니다:
#
# 1. **알코올 변형제(스테아릴알코올, 세테아릴알코올)**: 이런 알코올은 일반적으로 보습 및 유화제로 사용되며, 자극적이지 않지만 피부 타입에 따라 다르게 반응할 수 있습니다. 그러나 이 성분들은 보통 건성 피부에 유익할 수 있습니다. 다만, 매우 민감한 피부라면 체크할 필요가 있습니다.
#
# 따라서, 제공된 성분 중 특별히 주의할 성분은 없으며, 전반적으로 건성 피부에 적합한 성분들로 이루어진 제품으로 보입니다. "특별히 유의할 성분 없음"이라고 보시면 됩니다.

# %%
import csv
import os
from langchain_openai import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate

# --- 사전 준비: OpenAI API 키 설정 ---
if not os.getenv("OPENAI_API_KEY"):
    print("="*60)
    print("경고: OPENAI_API_KEY 환경 변수가 설정되지 않았습니다.")
    # 실제 실행 시에는 API 키가 없으면 종료하도록 처리할 수 있습니다.
    # exit()

# --- 1단계: 데이터베이스에서 제품 정보 가져오기 (기존 함수 재사용) ---
def find_all_products_by_efficacy(filepath, target_efficacy):
    """CSV 파일에서 특정 효능을 가진 '모든' 제품을 찾아 반환합니다."""
    found_products = []
    with open(filepath, mode='r', encoding='utf-8-sig') as infile:
        reader = csv.DictReader(infile)
        for row in reader:
            if '효능' in row and target_efficacy in row['효능']:
                # LLM에게 전달할 정보만 간추려서 추가합니다.
                product_info = {
                    "name": row.get('제품명', 'N/A'),
                    "ingredients": row.get('전성분', 'N/A')
                }
                found_products.append(product_info)
    return found_products

# --- 2단계: LangChain 설정 ---

# LLM 모델 설정 (gpt-4o 사용)
llm = ChatOpenAI(model_name="gpt-4o", temperature=0.7)

# 대화 메모리 설정
memory = ConversationBufferMemory(memory_key="history")

# 프롬프트 템플릿 설정
# {history}와 {input}은 LangChain이 자동으로 관리해주는 변수입니다.
template = """
당신은 친절하고 전문적인 화장품 추천 전문가입니다.
사용자와의 이전 대화 내용은 아래와 같습니다.

{history}

사용자의 현재 질문: {input}
전문가로서 답변해주세요.
"""

prompt = PromptTemplate(
    input_variables=["history", "input"], 
    template=template
)

# 대화 체인 생성 (LLM, 메모리, 프롬프트를 하나로 묶어줍니다)
conversation = ConversationChain(
    llm=llm,
    memory=memory,
    prompt=prompt,
    verbose=True # 체인의 작동 과정을 터미널에 출력해서 보기 쉽게 합니다.
)


# --- 3단계: 메인 챗봇 실행 로직 ---
def run_chat():
    print("="*50)
    print("✨ 화장품 추천 챗봇에 오신 것을 환영합니다! ✨")
    print("찾으시는 제품의 '효능'과 '피부 타입'을 알려주세요.")
    print("예시: 보습력 좋은 건성 피부용 크림 찾아줘")
    print("종료하시려면 '종료'를 입력하세요.")
    print("="*50)

    # 첫 번째 질문인지 확인하기 위한 플래그
    is_first_question = True

    while True:
        user_input = input("당신: ")
        if user_input.lower() == '종료':
            print("챗봇을 종료합니다. 이용해주셔서 감사합니다.")
            break

        # 첫 질문일 경우, CSV에서 관련 제품을 찾아 컨텍스트를 만들어줍니다.
        if is_first_question:
            # 사용자의 첫 질문에서 효능 키워드를 간단히 추출 (예: '보습', '진정', '미백' 등)
            # 실제 서비스에서는 더 정교한 키워드 추출 로직이 필요합니다.
            efficacy_keyword = None
            if "보습" in user_input: efficacy_keyword = "보습"
            elif "진정" in user_input: efficacy_keyword = "진정"
            elif "미백" in user_input: efficacy_keyword = "미백"
            
            product_context = ""
            if efficacy_keyword:
                products = find_all_products_by_efficacy('product_data.csv', efficacy_keyword)
                if products:
                    product_context += f"\n\n--- 참고: '{efficacy_keyword}' 효능을 가진 제품 목록 ---\n"
                    for p in products:
                        product_context += f"제품명: {p['name']}, 전성분: {p['ingredients']}\n"
                    product_context += "--- 위 목록과 사용자 정보를 바탕으로 제품을 추천해주세요. ---\n"

            # 첫 질문에만 제품 정보를 추가해서 전달
            full_input = user_input + product_context
            response = conversation.predict(input=full_input)
            is_first_question = False
        else:
            # 두 번째 질문부터는 대화 내용만 전달
            response = conversation.predict(input=user_input)

        print(f"챗봇: {response}")


if __name__ == '__main__':
    run_chat()
# Out:
# ==================================================
# ✨ 화장품 추천 챗봇에 오신 것을 환영합니다! ✨
# 찾으시는 제품의 '효능'과 '피부 타입'을 알려주세요.
# 예시: 보습력 좋은 건성 피부용 크림 찾아줘
# 종료하시려면 '종료'를 입력하세요.
# ==================================================
# C:\Users\sec\AppData\Local\Temp\ipykernel_49828\3327640236.py:37: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key="history")
# C:\Users\sec\AppData\Local\Temp\ipykernel_49828\3327640236.py:57: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use :class:`~langchain_core.runnables.history.RunnableWithMessageHistory` instead.
#   conversation = ConversationChain(
# > Entering new ConversationChain chain...
# Prompt after formatting:
#
# 당신은 친절하고 전문적인 화장품 추천 전문가입니다.
# 사용자와의 이전 대화 내용은 아래와 같습니다.
#
#
#
# 사용자의 현재 질문: 난 건성 피부인데, 보습에 좋은 제품 찾아줘
#
# --- 참고: '보습' 효능을 가진 제품 목록 ---
# 제품명: 아쿠아 오아시스 토너, 전성분: 정제수;다이프로필렌글라이콜;부틸렌글라이콜;글리세린;1,2-헥산다이올;베타인;판테놀;알란토인;파파야열매추출물;글루코노락톤;자일리틸글루코사이드;안하이드로자일리톨;자일리톨;소듐하이알루로네이트;글루코오스;파파인;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머
# 제품명: 1025 독도 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;펜틸렌글라이콜;프로판다이올;아이리쉬모스추출물;사탕수수추출물;해수;1,2-헥산다이올;프로테아제;베타인;판테놀;에틸헥실글리세린;알란토인;잔탄검;다이소듐이디티에이
# 제품명: 원더 세라마이드 모찌 토너, 전성분: 정제수;다이프로필렌글라이콜;글리세린;펜타에리스리틸테트라아이소스테아레이트;글리세레스-26;1,2-헥산다이올;마카다미아씨오일(구명칭);페닐트라이메티콘;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;스타이렌/브이피코폴리머;에틸헥실글리세린;병풀추출물;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;카프릴릭/카프릭트라이글리세라이드;알란토인;하이드로제네이티드레시틴;프로판다이올;판테놀;피토스테릴/옥틸도데실라우로일글루타메이트;세라마이드엔피;소듐하이알루로네이트;로즈우드오일;레몬껍질오일;다이소듐이디티에이;리날룰;리모넨
# 제품명: 다이브인 저분자 히알루론산 토너, 전성분: 정제수;부틸렌글라이콜;다이프로필렌글라이콜;1,2-헥산다이올;글리세린;베타인;알란토인;판테놀;쇠비름추출물;트레할로오스;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드(100ppm);소듐하이알루로네이트크로스폴리머;하이드롤라이즈드소듐하이알루로네이트;소듐아세틸레이티드하이알루로네이트;2,3-부탄다이올;펜틸렌글라이콜;말라카이트추출물;다이소듐이디티에이;에틸헥실글리세린
# 제품명: 초저분자 히아루론산 토너, 전성분: 정제수;메틸프로판다이올;1,2-헥산다이올;해수;글리세린;베타인;알란토인;부틸렌글라이콜;카프릴릴글라이콜;에틸헥실글리세린;판테놀;잔탄검;말라카이트추출물;다이소듐이디티에이;하이드롤라이즈드하이알루로닉애씨드;펜틸렌글라이콜;자일리틸글루코사이드;안하이드로자일리톨;소듐하이알루로네이트;자일리톨;포타슘하이알루로네이트;글루코오스;다이메틸실란올하이알루로네이트;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드록시프로필트라이모늄하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드칼슘하이알루로네이트;하이알루로닉애씨드;버지니아풍년화추출물;소듐설페이티드하이알루로네이트;편백잎추출물;소듐스테아로일하이알루로네이트;소듐올레오일하이알루로네이트
# 제품명: 판테놀 베리어 토너, 전성분: 정제수;부틸렌글라이콜;판테놀;다이프로필렌글라이콜;글리세레스-26;나이아신아마이드;1,2-헥산다이올;카카두플럼추출물;병풀추출물;아시아티코사이드;마데카소사이드;세라마이드엔피;얼룩파인애플추출물;파파야열매추출물;귀리가루추출물;락토바실러스/콩발효추출물;락토바실러스/쌀발효물;락토바실러스/인삼뿌리발효여과물;효모/율무씨발효여과물;효모/감자추출물발효여과물;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;동백나무씨오일;아시아틱애씨드;마데카식애씨드;리놀레익애씨드;락토바이오닉애씨드;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;하이드로제네이티드레시틴;프로판다이올;소듐시트레이트;베타인;글리세린;시트릭애씨드;소듐폴리아크릴로일다이메틸타우레이트;하이드록시프로필트라이모늄하이알루로네이트;아데노신;펜틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;에틸헥실글리세린
# 제품명: 올리고 히알루론산 딥 토너, 전성분: 정제수;부틸렌글라이콜;1,2-헥산다이올;글리세린;베타-글루칸;베타인;소듐하이알루로네이트(2,700ppm);판테놀;솔비톨;아세틸글루코사민;글루쿠로닉애씨드;알란토인;토코페롤;에틸헥실글리세린;다이소듐이디티에이
# 제품명: 하이드라 셀 부스팅 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;1,2-헥산다이올;하이드록시아세토페논;알란토인;카보머;알지닌;다이소듐이디티에이;녹차추출물;소듐하이알루로네이트;나이아신아마이드;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드글라이코사미노글리칸;리보플라빈;폴릭애씨드;판테놀;메나다이온;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;다이메틸실란올하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;바이오틴;사이아노코발아민;아스코빅애씨드;티아민에이치씨엘;피리독신;바이오플라보노이드
# 제품명: 무알콜 뮤신 에센스 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;판테놀;1,2-헥산다이올;와일드얌뿌리추출물(7395ppm);카보머;알지닌;병풀잎수;펜틸렌글라이콜;소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드하이알루로닉애씨드;에틸헥실글리세린;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트
# 제품명: 어성초 77 수딩 토너, 전성분: 약모밀꽃/잎/줄기수(77%);정제수;1,2-헥산다이올;글리세린;베타인;부틸렌글라이콜;아이소펜틸다이올;판테놀;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;병풀추출물;우엉뿌리추출물;진흙버섯추출물;쇠비름추출물;마트리카리아꽃추출물;체이스트트리추출물;소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;다이소듐이디티에이
# 제품명: 어성초 진정해 수분 토너, 전성분: 정제수;약모밀추출물;부틸렌글라이콜;다이프로필렌글라이콜;프로판다이올;1,2-헥산다이올;글리세린;하이드록시아세토페논;에틸헥실글리세린;카프릴릴글라이콜;폴리글리세릴-10라우레이트;폴리글리세릴-4라우레이트;카보머;알란토인;다이포타슘글리시리제이트;소듐파이테이트;소듐하이알루로네이트;병풀잎추출물;알지닌;살비아오일;마데카소사이드;제올라이트;루이보스잎추출물;마조람잎추출물;서양측백나무잎추출물;티트리잎추출물;로즈마리잎추출물;병풀추출물;살비아잎추출물;타임추출물;레몬밤잎추출물;히솝추출물;티트리추출물;작약뿌리추출물;녹차추출물
# 제품명: 나인 토너, 전성분: 정제수;글리세린;2,3-부탄다이올;판테놀;다이프로필렌글라이콜;1,2-헥산다이올;하이드록시아세토페논;에리스리톨;베타인;트레할로오스;알란토인;에틸헥실글리세린;소듐하이알루로네이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;알지닌;다이소듐이디티에이;쑥위추출물;부틸렌글라이콜;포타슘하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;로즈마리잎추출물;자작나무수액;트루로즈오브예리코추출물;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드
# 제품명: 비피다 바이옴 앰플 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;프로판다이올;펜틸렌글라이콜;버지니아풍년화수;락토바실러스발효용해물;락토코쿠스발효용해물;락토바실러스/호박발효추출물;효모발효여과물;베타인;알란토인;판테놀;세라마이드엔피;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드글라이코사미노글리칸;소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드로제네이티드레시틴;비피다발효여과물;비피다발효용해물;자일리톨;안하이드로자일리톨;자일리틸글루코사이드;글루코오스;1,2-헥산다이올;흰버드나무껍질추출물;락토바이오닉애씨드;사탕수수추출물;쿠티박테리움그라눌로숨발효추출여과물;프룩토오스;프룩토올리고사카라이드;카프릴릭/카프릭트라이글리세라이드;벤질글라이콜;토코페롤;에틸헥실글리세린;잔탄검;다이소듐이디티에이;아이리쉬모스추출물;클로렐라불가리스추출물
# 제품명: 리얼 히알루로닉 100 토너, 전성분: 하이드롤라이즈드하이알루로닉애씨드(932601.50052ppm);글리세린;프로판다이올;하이드로제네이티드레시틴;소듐하이알루로네이트(1.0052ppm);1,2-헥산다이올;알지닌;벤질글라이콜;베타인;부틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;시트릭애씨드;다이메틸실란올하이알루로네이트;다이소듐이디티에이;에틸헥실글리세린;글라이신;히스티딘;하이알루로닉애씨드(1.00001ppm);하이드롤라이즈드글라이코사미노글리칸(0.0056ppm);하이드롤라이즈드소듐하이알루로네이트(1.5ppm);하이드록시프로필트라이모늄하이알루로네이트(0.80012ppm);라이소레시틴;포타슘하이알루로네이트;세린;소듐아세틸레이티드하이알루로네이트(0.400002ppm);소듐시트레이트;소듐하이알루로네이트크로스폴리머(0.801ppm);소듐하이알루로네이트다이메틸실란올;소듐피씨에이;소듐스테아로일글루타메이트;수크로오스라우레이트;토코페롤;정제수;잔탄검
# 제품명: 시카테롤 토너, 전성분: 정제수;프로판다이올;병풀추출물;1,2-헥산다이올;베타-시토스테롤
# 제품명: 세라마이드 아토 로션, 전성분: 정제수;글리세린;프로판다이올;하이드로제네이티드쌀겨오일;사이클로펜타실록세인;하이드로제네이티드폴리(C6-14올레핀);사이클로헥사실록세인;다이메티콘;세틸에틸헥사노에이트;다이아이소스테아릴말레이트;1,2-헥산다이올;부틸렌글라이콜;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;C14-22알코올;아라키딜알코올;스테아릭애씨드;글리세릴스테아레이트;팔미틱애씨드;베헤닐알코올;C12-20알킬글루코사이드;.글리세릴카프릴레이트;아라키딜글루코사이드;인삼수;다이소듐이디티에이;에틸헥실글리세린;솔비탄아이소스테아레이트;폴리솔베이트60;들깨추출물;시호뿌리추출물;왜당귀뿌리추출물;소엽맥문동뿌리추출물;하이드록시프로필비스팔미타마이드엠이에이(세라마이드PC-10465.5ppm);만니톨;글루코오스;검정콩오일;미리스틱애씨드;아크릴레이트/암모늄메타크릴레이트코폴리머;아라키딕애씨드;세라마이드엔피(4ppm);콜레스테롤;실리카;피토스핑고신;하이드로제네이티드레시틴;토코페롤;카놀라오일;로즈마리잎추출물
# 제품명: MLE 로션, 전성분: 정제수;카프릴릭/카프릭트라이글리세라이드;글리세린;부틸렌글라이콜;펜틸렌글라이콜;세테아릴알코올;펜타에리스리틸스테아레이트/카프레이트/카프릴레이트/아디페이트;호호바씨오일;폴리글리세릴-5스테아레이트;소듐하이알루로네이트;스테아릭애씨드;글리세릴스테아레이트;솔비탄스테아레이트;시어버터;하이드로제네이티드식물성오일;토코페롤;팔미토일팔미타마이드엠이에이;비스-카프릴로일옥시팔미타미도아이소프로판올;N-데카노일세린올;알란토인;약모밀추출물;류신;라이신;페닐알라닌;트레오닌;발린;피토스테롤;카보머;피토스테릴올리에이트;잔탄검;소듐파이테이트;알지닌;해바라기씨오일;살비아오일;소두구씨오일;베타-글루칸;광곽향오일;멕시칸주니퍼오일;두송열매오일;캐모마일꽃오일;1,2-헥산다이올;카프릴릭/카프릭글리세라이즈
# 제품명: 더 심플 데일리 로션, 전성분: 정제수;프로판다이올;펜틸렌글라이콜;비닐다이메티콘;글리세린;세틸에칠헥사노에이트;알바수련꽃추출물;알로에베라잎즙;부틸렌글라이콜;마데카소사이드;세테아릴올리베이트;카보머;솔비탄올리베이트;트로메타민;소듐하이알루로네이트
# 제품명: 아토베리어365 로션, 전성분: 정제수;부틸렌글라이콜;글리세린;다이메티콘;스쿠알란;펜타에리스리틸테트라아이소스테아레이트;베타인;폴리글리세릴-3메틸글루코오스다이스테아레이트;부틸렌글라이콜다이카프릴레이트/다이카프레이트;카프릴릭/카프릭트라이글리세라이드;팔미틱애씨드;1,2-헥산다이올;스테아릭애씨드;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;글리세릴스테아레이트;하이드록시프로필비스팔미타마이드엠이에이;글리세릴스테아레이트시트레이트;콜레스테롤;나이아신아마이드;다이메티콘올;하이드록시프로필비스라우라마이드엠이에이;베헤닐알코올;글리세릴카프릴레이트;카보머;다이소듐이디티에이;에틸헥실글리세린;트로메타민;솔비탄아이소스테아레이트;피토스핑고신;만니톨;세라마이드엔피;토코페롤;하이드로제네이티드레시틴;아크릴레이트/암모늄메타크릴레이트코폴리머;실리카;스핑고리피드;아라키딕애씨드;올레익애씨드
# 제품명: 1025 독도 로션, 전성분: 정제수;글리세린;퀸즈랜드넛오일;1,2-헥산다이올;펜틸렌글라이콜;호호바에스터;아이리쉬모스추출물;사탕수수추출물;해수;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;소듐하이알루로네이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;글리세릴스테아레이트;하이드로제네이티드폴리데센;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;카프릴릴글라이콜;트로메타민;소듐파이테이트;판테놀;스쿠알란;부틸렌글라이콜;토코페롤;소듐카복시메틸베타-글루칸;에틸헥실글리세린;세테아릴알코올;카보머
# 제품명: 수딩 젤 로션, 전성분: 정제수;부틸렌글라이콜;글리세린;펜타에리스리틸스테아레이트/카프레이트/카프릴레이트/아디페이트;1,2-헥산다이올;세테아릴알코올;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;카프릴릭/카프릭글리세라이즈;글리세릴스테아레이트시트레이트;솔비탄스테아레이트;스테아릭애씨드;카보머;미리스토일/팔미토일옥소스테아라마이드/아라카마이드엠이에이;해수;피토스테롤;해바라기씨오일;팔미토일팔미타마이드엠이에이;비스-카프릴로일옥시팔미타미도아이소프로판올;N-데카노일세린올;소듐하이알루로네이트;블루탄지꽃오일;캐모마일꽃추출물;살비아오일;광곽향오일;소두구씨오일;콘민트오일;캐모마일꽃오일;멕시칸주니퍼오일;류신;아줄렌;라이신;페닐알라닌;트레오닌;발린
# 제품명: 서양송악 순수 로션, 전성분: 정제수;글리세린;부틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;1,2-헥산다이올;옥틸도데칸올;폴리글리세릴-3다이스테아레이트;서양송악추출물(200,000ppb);서양송악잎/줄기추출물(570,000ppb);세라마이드엔피;피토스핑고신;사과나무잎추출물;비치스트로베리추출물;서양배추출물;세테아릴알코올;카보머;알지닌;폴리글리세릴-10다이아이소스테아레이트;글리세릴스테아레이트시트레이트;잔탄검;에틸헥실글리세린
# 제품명: 탄탄 모공 펩타노산™ 단백질 로션, 전성분: 정제수;부틸렌글라이콜;프로판다이올;카프릴릭/카프릭트라이글리세라이드;글리세린;나이아신아마이드;하이드로제네이티드다이데센;프로필헵틸카프릴레이트;피씨에이다이메티콘;폴리글리세릴-3다이스테아레이트;메틸글루세스-20;1,2-헥산다이올;소듐폴리아크릴레이트;옥틸도데실미리스테이트;호호바에스터;글리세릴스테아레이트;하이드록시아세토페논;해바라기씨왁스;귀리펩타이드;에틸헥실글리세린;베타-시토스테롤;글리세릴스테아레이트시트레이트;올레일알코올;카프릴릴/카프릴글루코사이드;잔탄검;아데노신;다이소듐이디티에이;피토스테롤;하이드로제네이티드레시틴;폴리글리세린-3;피브이엠/엠에이코폴리머;귀리아미노산;병풀추출물;무화과추출물;세라마이드엔피;엑토인;귀리단백질추출물;토코페롤;귀리커넬추출물;으름덩굴추출물;감나무잎추출물;잇꽃꽃추출물;밤껍질추출물;커피콩추출물;호장근추출물
# 제품명: 판테놀 베리어 에멀전, 전성분: 정제수;글리세린;판테놀;프로판다이올;1,2-헥산다이올;다이프로필렌글라이콜;하이드로제네이티드폴리데센;퀸즈랜드넛오일;나이아신아마이드;카카두플럼추출물;스쿠알란;세테아릴올리베이트;부틸렌글라이콜;세테아릴알코올;글리세릴스테아레이트;솔비탄올리베이트;카보머;트로메타민;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;카프릴릭/카프릭트라이글리세라이드;토코페롤;해바라기씨오일;에틸헥실글리세린;하이드로제네이티드레시틴;락토바실러스/인삼뿌리발효여과물;효모/감자추출물발효여과물;아데노신;락토바실러스/콩발효추출물;락토바실러스/쌀발효물;효모/율무씨발효여과물;다이소듐이디티에이;시어버터;솔비탄아이소스테아레이트;베타인;세라마이드엔피;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;소듐하이알루로네이트;펜틸렌글라이콜;마데카소사이드;콜레스테롤;세라마이드에이피;세라마이드엔에스;세라마이드에이에스;데실글루코사이드;유칼립투스잎추출물;카프릴릴글라이콜;병풀추출물;아시아티코사이드;아시아틱애씨드;마데카식애씨드;피토스핑고신;세라마이드이오피
# 제품명: 스킨 베리어 카밍 로션, 전성분: 정제수;글리세린;프로판다이올;카프릴릭/카프릭트라이글리세라이드;세틸에틸헥사노에이트;1,2-헥산다이올;글리세릴스테아레이트;페닐트라이메티콘;C14-22알코올;폴리솔베이트60;알지닌;황련뿌리추출물;카보머;부틸렌글라이콜;몰로키아잎추출물;당근추출물;마테잎추출물;보리지추출물;C12-20알킬글루코사이드;병풀추출물;글루코오스;폴리글리세릴-10라우레이트;에틸헥실글리세린;트라이펩타이드-1;카퍼트라이펩타이드-1;팔미토일펜타펩타이드-4;팔미토일트라이펩타이드-1;헥사펩타이드-9;헥사펩타이드-11;아세틸테트라펩타이드-2;아세틸테트라펩타이드-5;팔미토일트라이펩타이드-5
# 제품명: 제주 말차 로우 피에이치 수딩 에멀전 크림, 전성분: 녹차수(358,800ppm);정제수;부틸렌글라이콜;프로판다이올;글리세린;글리세레스-26;1,2-헥산다이올;아이소노닐아이소노나노에이트;스쿠알란;폴리글리세릴-3다이스테아레이트;폴리아크릴레이트크로스폴리머-6;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;녹차가루(3,000ppm);알란토인;베타인;트레할로오스;카프릴릭/카프릭트라이글리세라이드;녹차추출물(500ppm);에틸헥실글리세린;글리세릴스테아레이트시트레이트;폴리솔베이트60;시트릭애씨드;다이소듐이디티에이;솔비탄아이소스테아레이트;하이드로제네이티드레시틴;효모/자일리눔/홍차발효물;타임추출물;라벤더추출물;오레가노꽃/잎/줄기추출물;로즈마리추출물;피토스테릴/옥틸도데실라우로일글루타메이트;세라마이드엔피;하이드로제네이티드포스파티딜콜린;소듐하이알루로네이트;병풀추출물;수크로오스스테아레이트;세테아릴알코올;아시아티코사이드;마데카식애씨드;아시아틱애씨드;마데카소사이드
# 제품명: 모이스춰라이징 로션, 전성분: 정제수;글리세린;아이소프로필팔미테이트;세테아릴알코올;세테아레스-20;판테놀;나이아신아마이드;토코페릴아세테이트;다이메티콘;아보카도오일;해바라기씨오일;판토락톤;글리세릴스테아레이트;소듐벤조에이트0.5%;벤질알코올0.25%;시트릭애씨드
# 제품명: 엑토인 로션, 전성분: 정제수;부틸렌글라이콜다이카프릴레이트/다이카프레이트;다이프로필렌글라이콜;폴리글리세릴-3메틸글루코오스다이스테아레이트;1,2-헥산다이올;카프릴릭/카프릭/석시닉트라이글리세라이드;세테아릴에틸헥사노에이트;글리세릴스테아레이트시트레이트;세테아릴알코올;호호바씨오일;엑토인(5,000ppm);식물성오일;카보머;아미노메틸프로판다이올;판테놀;하이드로제네이티드포스파티딜콜린;포타슘시트레이트;세라마이드엔피
# 제품명: DMT 페이셜 로션, 전성분: 정제수;카프릴릭/카프릭트라이글리세라이드;글리세린;펜틸렌글라이콜;코코넛야자오일;오일팜오일;시어버터;올리브오일;하이드로제네이티드레시틴;하이드록시에틸셀룰로오스;카프릴릴글라이콜;잔탄검;스쿠알란;카보머;소듐카보머;세라마이드엔피
# 제품명: 소나무 진정 시카 로션, 전성분: 정제수;프로판다이올;1,2-헥산다이올;글리세린;세틸에틸헥사노에이트;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;소듐하이알루로네이트;소나무잎추출물(5,012ppm);인도멀구슬나무잎추출물;부틸렌글라이콜;에틸헥실글리세린;병풀추출물 (61.12ppm);인도멀구슬나무꽃추출물;카카오씨추출물;세테아릴올리베이트;글리세레스-26;글라이코프로테인(1.0024ppm);카프릴로일살리실릭애씨드;C12-20알킬글루코사이드;암모늄폴리아크릴로일다이메틸타우레이트;하이드로제네이티드폴리데센;덱스트린;아시아티코사이드(0.0501ppm);아시아틱애씨드(0.0501ppm);마데카소사이드(0.0501ppm);마데카식애씨드(0.0501ppm);비닐다이메티콘;솔비탄올리베이트;카보머;C14-22알코올;다이소듐이디티에이;트로메타민
# 제품명: 다이브인 저분자 히알루론산 세럼, 전성분: 정제수;부틸렌글라이콜;글리세린;다이프로필렌글라이콜;1,2-헥산다이올;판테놀;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드소듐하이알루로네이트;알란토인;트레할로오스;베타인;프로판다이올;쇠비름추출물;버지니아풍년화추출물;마데카소사이드;마데카식애씨드;세라마이드엔피;베타-글루칸;말라카이트추출물;콜레스테롤;펜틸렌글라이콜;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머;폴리글리세릴-10라우레이트;잔탄검;트로메타민;카보머;에틸헥실글리세린;황금추출물;모란뿌리추출물
# 제품명: 리얼 히알루로닉 블루 100 앰플, 전성분: 정제수;프로판다이올;펜틸렌글라이콜;글리세린;1,2-헥산다이올;판테놀;참마뿌리추출물;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;카바카바잎/뿌리/줄기추출물;병풀추출물;인삼열매추출물;가지열매추출물;알로에베라꽃추출물;홀리바질잎추출물;울금뿌리추출물;참산호말추출물;갈랑가갈랑갈추출물;소듐하이알루로네이트(1,000ppm);하이드로제네이티드레시틴;메틸프로판다이올;소듐아크릴릭애씨드/엠에이코폴리머;부틸렌글라이콜;잔탄검;소듐시트레이트;글라이코실트레할로오스;하이드로제네이티드스타치하이드롤리세이트;아데노신;시트릭애씨드;라피노오스;레시틴;폴리쿼터늄-51;베타-글루칸;사카라이드아이소머레이트;사이아노코발아민;바이오사카라이드검-1;카프릴릭/카프릭트라이글리세라이드;소듐스테아로일글루타메이트;수크로오스라우레이트;글라이신;세린;알지닌;히스티딘;리솔레시틴;하이드롤라이즈드소듐하이알루로네이트(0.1ppm);토코페롤;벤질글라이콜;하이드롤라이즈드글라이코사미노글리칸(0.0056ppm);소듐아세틸레이티드하이알루로네이트(0.000002ppm);소듐하이알루로네이트크로스폴리머(0.001ppm);하이드록시프로필트라이모늄하이알루로네이트(0.0001ppm);하이드롤라이즈드하이알루로닉애씨드(0.0005ppm);하이알루로닉애씨드(0.00001ppm);에틸헥실글리세린;카프릴릴글라이콜
# 제품명: PDRN 히알루론산 캡슐 100 세럼, 전성분: 정제수;부틸렌글라이콜;프로판다이올;글리세린;하이드롤라이즈드하이알루로닉애씨드;1,2-헥산다이올;나이아신아마이드;글리세릴올리에이트;라우릴글루코사이드;미리스틸글루코사이드;폴리글리세릴-6라우레이트;하이드로제네이티드레시틴;글루타티온;하이드롤라이즈드콜라겐;소듐하이알루로네이트;황련뿌리추출물;아데노신;소듐디엔에이;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;포타슘하이알루로네이트;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;가지열매추출물;홀리바질잎추출물;시트릭애씨드;울금뿌리추출물;참산호말추출물;소듐시트레이트;펜틸렌글라이콜
# 제품명: 데일리 컨셔스 세럼, 전성분: 병풀추출물;부틸렌글라이콜;글리세린;정제수;1,2-헥산다이올;프로판다이올;카보머;하이드록시아세토페논;트로메타민;셀룰로오스검;글리세레스-25피씨에이아이소스테아레이트;하이드롤라이즈드치자추출물;하이드롤라이즈드맥아추출물;하이드롤라이즈드삼색제비꽃추출물;코튼열매수;에틸헥실글리세린;아데노신;다이프로필렌글라이콜;맥아추출물;다이소듐이디티에이;여주열매추출물;접시꽃추출물;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;무궁화나무껍질추출물;소듐하이알루로네이트;바쿠치올
# 제품명: 아쿠아 스쿠알란 세럼, 전성분: 정제수;글리세린;부틸렌글라이콜;메틸프로판다이올;1,2-헥산다이올;베타인;다시마추출물;한련초잎추출물;버지니아풍년화추출물;소듐하이알루로네이트;하이드로제네이티드레시틴;판테놀;알란토인;프룩토올리고사카라이드;베타-글루칸;하이드롤라이즈드하이알루로닉애씨드;식물성스쿠알란(1ppm);하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;하이알루로닉애씨드;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;에틸헥실글리세린;카보머;트로메타민;잔탄검;다이소듐이디티에이
# 제품명: 마데카소사이드 흔적 리페어 세럼, 전성분: 정제수;글리세린;부틸렌글라이콜;프로판다이올;1,2-헥산다이올;나이아신아마이드;글리세릴폴리메타크릴레이트;판테놀;베타인;폴리글리세릴-10라우레이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;다이페닐다이메티콘;트로메타민;트라이에틸헥사노인;마데카소사이드(540ppm);잔탄검;에틸헥실글리세린;하이드로제네이티드레시틴;소듐하이알루로네이트;병풀추출물(51ppm);서양배추출물;연필향나무오일;병풀잎추출물(21ppm);베타-글루칸;다마스크장미꽃수;멜론추출물;오리스뿌리추출물;서양송악잎/줄기추출물;호호바씨오일;광곽향오일;불가리스쑥오일;로즈마리잎오일;토코페롤;다이프로필렌글라이콜;펜틸렌글라이콜;카프릴릴/카프릴글루코사이드;마데카식애씨드(0.00004ppm);아시아틱애씨드(0.00003ppm);아시아티코사이드(39ppm);세라마이드엔피
# 제품명: 베러 밸런스 앰플, 전성분: 정제수;프로판다이올;부틸렌글라이콜;글리세린;1,2-헥산다이올;글리세레스-26;나이아신아마이드;푸른연꽃수;판테놀;알지닌;카보머;베타인;에리스리톨;에틸헥실글리세린;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;트레할로오스;잔탄검;아데노신;말라카이트추출물;다이포타슘글리시리제이트;다이소듐이디티에이;폴리쿼터늄-51;소듐하이알루로네이트;블루아가베잎추출물;베타-글루칸;약모밀추출물;밤부사불가리스추출물;병풀추출물;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;편백잎추출물;소나무잎추출물;측백나무추출물
# 제품명: 트리플 이펙트 시너지 세럼, 전성분: 밤부사불가리스수;정제수;해바라기씨오일;카프릴릭/카프릭트라이글리세라이드;부틸렌글라이콜;다이프로필렌글라이콜;글리세레스-26;1,2-헥산다이올;바쿠치올;마데카소사이드;소듐하이알루로네이트;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;포타슘하이알루로네이트;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;다이메틸실란올하이알루로네이트;소듐하이알루로네이트다이메틸실란올;약모밀추출물;마카다미아씨오일;판테놀;하이드록시아세토페논;씨솔트;토코페롤;베타인;서양배추출물;알지닌;카보머;한련초추출물;다마스크장미꽃수;아데노신;아미노부티릭애씨드;다이소듐이디티에이;오리스뿌리추출물;인도멀구슬나무잎추출물;멜론추출물;서양송악잎/줄기추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;드럼스틱씨오일;가지열매추출물;호호바씨오일;병풀추출물;참산호말추출물;울금뿌리추출물;홀리바질잎추출물;펜틸렌글라이콜;프로판다이올
# 제품명: 베리어덤 링거 앰플, 전성분: 정제수;프로판다이올;글리세린;1,2-헥산다이올;클로렐라불가리스추출물;소듐하이알루로네이트;락토바실러스발효용해물;판테놀;글라이코실트레할로오스;글루코오스;부틸렌글라이콜;하이드로제네이티드스타치하이드롤리세이트;프룩토올리고사카라이드;프룩토오스;폴리쿼터늄-51;글리세릴글루코사이드;사카라이드아이소머레이트;에틸헥실글리세린;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;알란토인;하이드록시프로필트라이모늄하이알루로네이트;트로메타민;덱스트린;소듐파이테이트;소듐클로라이드;베타-글루칸;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;사이아노코발아민;시트릭애씨드;소듐시트레이트;소듐바이카보네이트;칼슘클로라이드;포타슘클로라이드;토코페롤;잔탄검;치자추출물
# 제품명: 아토베리어365 크림, 전성분: 정제수;부틸렌글라이콜;글리세린;부틸렌글라이콜다이카프릴레이트/다이카프레이트;세틸에틸헥사노에이트;스쿠알란;펜타에리스리틸테트라아이소스테아레이트;다이카프릴릴카보네이트;베헤닐알코올;다이메티콘;하이드록시프로필비스팔미타마이드엠이에이;스테아릭애씨드;베타인;만니톨;C14-22알코올;팔미틱애씨드;하이드록시프로필비스라우라마이드엠이에이;아라키딜알코올;콜레스테롤;폴리아크릴레이트-13;C12-20알킬글루코사이드;알란토인;아라키딜글루코사이드;나이아신아마이드;세라마이드엔피;글리세릴카프릴레이트;에틸헥실글리세린;하이드로제네이티드폴리아이소부텐;카보머;트로메타민;다이메티콘올;폴리글리세릴-10라우레이트;하이드로제네이티드레시틴;에틸헥실팔미테이트;아크릴레이트/암모늄메타크릴레이트코폴리머;솔비탄아이소스테아레이트;실리카;피토스핑고신;스핑고리피드;아라키딕애씨드;토코페롤;올레익애씨드
# 제품명: 아쿠아 스쿠알란 수분크림, 전성분: 정제수;스쿠알란(150,000ppm);글리세린;1,2-헥산다이올;베타인;판테놀;소듐하이알루로네이트;하이드롤라이즈드콜라겐;하이드록시프로필트라이모늄하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;아세틸헥사펩타이드-8;아데노신;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;알지닌;알란토인;자일리틸글루코사이드;안하이드로자일리톨;자일리톨;글루코오스;부틸렌글라이콜;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;카프릴릴글라이콜
# 제품명: 다이브인 저분자 히알루론산 수딩 크림, 전성분: 정제수;부틸렌글라이콜;글리세린;1,2-헥산다이올;하이드로제네이티드다이데센;알란토인;트레할로오스;버지니아풍년화추출물;판테놀;하이드롤라이즈드하이알루로닉애씨드;소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;2,3-부탄다이올;세테아릴알코올;C14-22알코올;C12-20알킬글루코사이드;펜틸렌글라이콜;솔비탄아이소스테아레이트;카프릴릭/카프릭트라이글리세라이드;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;가지열매추출물;홀리바질잎추출물;울금뿌리추출물;참산호말추출물;클레리추출물;라벤더꽃추출물;히아신스전초추출물;마트리카리아꽃추출물;수레국화꽃추출물;보리지추출물;다이소듐이디티에이;카보머;트로메타민;잔탄검;글루타티온;말라카이트추출물;에틸헥실글리세린
# 제품명: 녹두 모공 타이트업 수딩 크림, 전성분: 정제수;글리세린;부틸렌글라이콜;다이프로필렌글라이콜;카프릴릭/카프릭트라이글리세라이드;나이아신아마이드;1,2-헥산다이올;아이소도데케인;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;C12-14알케스-12;세테아릴알코올;카보머;세테아릴올리베이트;트로메타민;솔비탄올리베이트;에틸헥실글리세린;메틸다이아이소프로필프로피온아마이드;아데노신;다이소듐이디티에이;치자추출물;소듐폴리아크릴레이트;황련추출물;알란토인;C18-21알케인;폴리글리세릴-10올리에이트;녹두씨추출물(10.05ppm);녹두추출물(10ppm);녹두싹추출물(10ppm);녹두전초추출물(10ppm);다이포타슘글리시리제이트;사과수;프로판다이올;카프릴릴글라이콜;백미꽃추출물;소듐하이알루로네이트;팔미토일트라이펩타이드-5;아세틸헥사펩타이드-1;하이드록시신나믹애씨드;소듐하이알루로네이트크로스폴리머;루틴;포타슘하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;다이메틸실란올하이알루로네이트;소듐아세틸레이티드하이알루로네이트
# 제품명: 레드 블레미쉬 클리어 수딩 크림, 전성분: 정제수;글리세린;부틸렌글라이콜;다이카프릴릴에터;나이아신아마이드;1,2-헥산다이올;하이드로제네이티드폴리데센;펜틸렌글라이콜;다이카프릴릴카보네이트;비닐다이메티콘;카프릴릴메티콘;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;판테놀;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;다이메티콘올;폴리메틸실세스퀴옥세인;트로메타민;다이포타슘글리시리제이트;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;에틸헥실글리세린;잔탄검;병풀잎추출물;프룩토올리고사카라이드;소듐파이테이트;알란토인;락토바실러스발효물;락토바실러스/콩발효추출물;류코노스톡/무발효여과물;효모발효추출물;토코페롤;에피갈로카테킨갈레이트;마데카소사이드;베타-글루칸;병풀추출물;아시아티코사이드;마데카식애씨드;아시아틱애씨드
# 제품명: PDRN 히알루론산 100 수분 크림, 전성분: 정제수;스쿠알란;글리세린;나이아신아마이드;펜틸렌글라이콜;1,2-헥산다이올;소듐디엔에이;하이드롤라이즈드콜라겐;소듐하이알루로네이트;인도멀구슬나무잎추출물;하이드롤라이즈드하이알루로닉애씨드;인도멀구슬나무꽃추출물;아이비고드열매추출물;하이알루로닉애씨드;알로에베라꽃추출물;가지열매추출물;홀리바질잎추출물;참산호말추출물;울금뿌리추출물;병풀잎추출물;다이페닐실록시페닐트라이메티콘;피씨에이다이메티콘;부틸렌글라이콜;프로판다이올;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;다이글리세린;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;C12-20알킬글루코사이드;메틸프로판다이올;에틸헥실글리세린;아데노신;소듐파이테이트;아미노메틸프로판다이올;피브이엠/엠에이코폴리머;마데카소사이드;C12-13알케스-9;다이메틸실란올하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;아시아티코사이드;포타슘하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;소듐하이알루로네이트크로스폴리머;소듐하이알루로네이트다이메틸실란올;소듐아세틸레이티드하이알루로네이트;베헤닐알코올;C14-22알코올;카보머
# 제품명: 다이브인 저분자 히알루론산 크림, 전성분: 정제수;부틸렌글라이콜;글리세린;다이프로필렌글라이콜;카프릴릭/카프릭트라이글리세라이드;1,2-헥산다이올;C14-22알코올;글리세릴스테아레이트;에틸헥실팔미테이트;세테아릴알코올;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드(100ppm);소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드소듐하이알루로네이트;호호바씨오일;마카다미아씨오일;아르간커넬오일;트레할로스;에스에이치-올리고펩타이드-1;알란토인;프로판다이올;베타인;베타-글루칸;세라마이드엔피;쇠비름추출물;버지니아풍년화잎추출물;검은뽕나무열매추출물;구기자추출물;비치스트로베리추출물;불가리스매자뿌리추출물;마데카소사이드;마데카식애씨드;세테아릴올리베이트;소르비탄올리베이트;말라카이트추출물;펜틸렌글라이콜;다이메티콘/비닐다이메티콘크로스폴리머;C12-20알킬글루코사이드;폴리글리세릴-10미리스테이트;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;잔탄검;알지닌;카보머;트로메타민;에틸헥실글리세린;황금추출물;모란뿌리추출물
# 제품명: 마다가스카르 리얼 수분크림, 전성분: 병풀잎수(80%);글리세린;하이드로제네이티드레시틴;부틸렌글라이콜;황금추출물;모란뿌리추출물;카프릴릭/카프릭트라이글리세라이드;헵틸운데실레네이트;폴리글루타믹애씨드;소듐하이알루로네이트;에리스리톨;솔비톨;마데카소사이드;아시아티코사이드;마데카식애씨드;아시아틱애씨드;아세틸헥사펩타이드-8;베타-글루칸;판테놀;로우스위트블루베리추출물;석류추출물;무화과추출물;뽕나무열매추출물;은행추출물;하이드롤라이즈드하이알루로닉애씨드;하이드록시에틸우레아;알란토인;다이포타슘글리시리제이트;토코페롤;1,2-헥산다이올
# 제품명: 진정한 수분크림, 전성분: 정제수;다이프로필렌글라이콜;글리세린;카프릴릭/카프릭트라이글리세라이드;메틸트라이메티콘;세틸에틸헥사노에이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;메도우폼씨오일;밤부사불가리스추출물;베타인;하이드로제네이티드폴리아이소부텐;세테아릴알코올;폴리글리세릴-3스테아레이트;글리세릴스테아레이트;1,2-헥산다이올;트레할로오스;판테놀;알지닌;카보머;카프릴릴글라이콜;하이드록시아세토페논;하이드로제네이티드식물성글리세라이즈;폴리글리세릴-10라우레이트;아미노부티릭애씨드;폴리글리세릴-4라우레이트;소듐스테아로일락틸레이트;에틸헥실글리세린;부틸렌글라이콜;약모밀추출물;판토락톤;아데노신;서양배추출물;트라이소듐에틸렌다이아민다이석시네이트;다마스크장미꽃수;글리세릴글루코사이드;살비아오일;오리스뿌리추출물;멜론추출물;서양송악잎/줄기추출물;흰목이버섯폴리사카라이드;향부자추출물;판토테닉애씨드;서양민들레뿌리줄기/뿌리추출물;소엽잎추출물;소듐하이알루로네이트;마그네슘피씨에이;소듐피씨에이;칼슘피씨에이
# 제품명: 어성초 히알루론 수딩 크림, 전성분: 정제수;글리세린;비닐다이메티콘;부틸렌글라이콜;카프릴릴메티콘;다이프로필렌글라이콜;1,2-헥산다이올;펜틸렌글라이콜;에리스리톨;자일리톨;어성초추출물(=약모밀추출물;6,501ppm);효모발효여과물;소듐하이알루로네이트(102.1ppm);편백오일;유칼립투스잎오일;하이드롤라이즈드하이알루로닉애씨드(0.15ppm);하이알루로닉애씨드(0.1ppm);칸디다봄비콜라/글루코오스/메틸레이프씨데이트발효물;포도씨오일;병풀잎추출물;산구절초추출물;해바라기씨오일;쇠비름추출물;에틸헥실팔미테이트;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;솔비톨;트로메타민;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;카프릴릭/카프릭트라이글리세라이드;에틸헥실글리세린;판테놀;하이드로제네이티드레시틴;소듐파이테이트;세라마이드엔피;베타-글루칸;다발방패버섯추출물;엑토인;셀룰로오스;폴리글루타믹애씨드;하이알루로닉애씨드/폴리아이소프로필아크릴아마이드코폴리머(1ppm);글리세릴카프릴레이트;다이메틸실란올하이알루로네이트(0.15ppm);하이드롤라이즈드소듐하이알루로네이트(0.15ppm);포타슘하이알루로네이트(0.1ppm);토코페롤;하이드록시프로필트라이모늄하이알루로네이트(0.08ppm);소듐하이알루로네이트크로스폴리머(0.08ppm);프로판다이올;소듐하이알루로네이트다이메틸실란올(0.05ppm);소듐아세틸레이티드하이알루로네이트(0.04ppm);폴리글리세릴-10아이소스테아레이트;폴리글리세릴-10올리에이트;스테아릭애씨드;세라마이드엔에스;콜레스테롤;피토스핑고신;세라마이드에이피;세라마이드에이에스;세라마이드이오피;카보머;세테아릴알코올
# 제품명: 인테카 수딩 크림, 전성분: 정제수;프로판다이올;글리세린;글리세릴글루코사이드;1,2-헥산다이올;카프릴릭/카프릭트라이글리세라이드;하이드로제네이티드폴리데센;나이아신아마이드;부틸렌글라이콜;솔비톨;세테아릴올리베이트;비닐다이메티콘;솔비탄올리베이트;카보머;칸디다봄비콜라/글루코오스/메틸레이프씨데이트발효물;해바라기씨오일;아시아티코사이드;아시아틱애씨드;마데카식애씨드;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;소듐하이알루로네이트;다이프로필렌글라이콜;글리세릴스테아레이트에스이;하이드로제네이티드레시틴;트로메타민;에틸헥실글리세린;아데노신;다이소듐이디티에이;에톡시다이글라이콜패드:정제수;프로판다이올;나이아신아마이드;다이프로필렌글라이콜;1,2-헥산다이올;자일리톨;폴리글리세릴-10라우레이트;칸디다봄비콜라/글루코오스/메틸레이프씨데이트발효물;부틸렌글라이콜;글루코노락톤;트로메타민;카보머;에틸헥실글리세린;아데노신;해바라기씨오일;알란토인;두충나무껍질추출물;아시아티코사이드;마데카식애씨드;아시아틱애씨드;에톡시다이글라이콜
# 제품명: 모이스춰 닥터 크림, 전성분: 정제수;글리세린;세틸에틸헥사노에이트;카프릴릭/카프릭트라이글리세라이드;베타인;마카다미아씨오일;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드글라이코사미노글리칸;티트리잎추출물;쇠비름추출물;약모밀추출물(어성초추출물);판테놀;피토스핑고신;세라마이드엔피;알지닌;카보머;흰버드나무껍질추출물;오레가노잎추출물;편백잎추출물;락토바실러스/콩발효추출물;육계나무껍질추출물;잔탄검;솔비탄세스퀴올리에이트;자몽껍질오일;부틸렌글라이콜;1,2-헥산다이올;프로판다이올;포트마리골드꽃추출물;황금추출물;모란뿌리추출물;스페인감초뿌리추출물;하이드로제네이티드레시틴;리모넨
# 제품명: 밸런스풀 시카 진정 크림, 전성분: 정제수;부틸렌글라이콜;글리세린;헵틸운데실레네이트;1,2-헥산다이올;판테놀(2,000ppm);병풀추출물;마데카식애씨드;아시아티코사이드(780ppb);아시아틱애씨드;마데카소사이드;알란토인;하이드롤라이즈드하이알루로닉애씨드;쓴풀추출물;푸른연꽃추출물;락토바실러스발효물;접시꽃추출물;잇꽃꽃추출물;베타인;카프릴릭/카프릭트라이글리세라이드;세테아릴알코올;프로판다이올;C14-22알코올;다이펩타이드-2;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;소듐폴리아크릴레이트;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머;솔비탄아이소스테아레이트;폴리글리세릴-3폴리리시놀리에이트;아이소펜틸다이올;카프릴로일살리실릭애씨드;C12-20알킬글루코사이드;폴리글리세릴-4올리에이트;소듐스테아로일글루타메이트;소듐서팩틴;카프로익애씨드;잔탄검;트로메타민;소듐아세테이트;다이소듐이디티에이;에틸헥실글리세린;치자추출물
# 제품명: 포어 더블 리커버리 바나티놀 크림, 전성분: 바나나수(660,000ppm);판테놀;프로판다이올;펜타에리스리틸테트라에틸헥사노에이트;글리세린;1,2-헥산다이올;부틸렌글라이콜;나이아신아마이드;다이카프릴릴카보네이트;에틸헥실스테아레이트;해바라기씨오일;아이소펜틸다이올;펜틸렌글라이콜;트라이에틸헥사노인;정제수;C14-22알코올;소듐폴리아크릴로일다이메틸타우레이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;세테아릴올리베이트;트로메타민;C12-20알킬글루코사이드;솔비탄올리베이트;오렌지껍질오일;메도우폼씨오일;알란토인;다이포타슘글리시리제이트;아보카도오일;트레할로오스;하이드로제네이티드레시틴;다이메틸아이소소바이드;아데노신;리씨열매오일;세테아릴알코올;에틸헥실글리세린;다이소듐이디티에이;트라넥사믹애씨드;스테아릭애씨드;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;스테아릴알코올;약모밀추출물;황련추출물;하이드록시피나콜론레티노에이트;바나나꽃수;글리세릴스테아레이트에스이;바나나즙;바나나잎추출물;바나나껍질추출물;세라마이드엔피;다마스크장미꽃추출물;삼나무잎추출물;연꽃잎추출물;효모발효물;달맞이꽃추출물;대왕소나무잎추출물;칡뿌리추출물;당느릅나무뿌리추출물;병풀추출물;세라마이드엔에스;다이메틸실란올하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;콜레스테롤;하이알루로닉애씨드;피토스핑고신;포타슘하이알루로네이트;소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;소듐하이알루로네이트크로스폴리머;세라마이드에이피;세라마이드에이에스;소듐하이알루로네이트다이메틸실란올;소듐아세틸레이티드하이알루로네이트;할미꽃추출물;우스니아추출물;초피나무열매추출물;세라마이드이오피;시트랄;리모넨;리날룰
# 제품명: 시카좀 카밍 워터 젤 크림, 전성분: 정제수;부틸렌글라이콜;글리세린;1,2-헥산다이올;하이드로제네이티드폴리데센;나이아신아마이드;판테놀;프로판다이올;베헤닐알코올;세테아릴알코올;비닐다이메티콘;카보머;세테아릴올리베이트;솔비탄올리베이트;트로메타민;폴리아크릴레이트-13;베타인;병풀추출물(767.4ppm);하이드로제네이티드폴리아이소부텐;황련뿌리추출물;에틸헥실글리세린;하이드롤라이즈드치자추출물;하이드롤라이즈드맥아추출물;하이드롤라이즈드삼색제비꽃추출물;다이소듐이디티에이;폴리글리세릴-10라우레이트;에틸헥실팔미테이트;알란토인;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;소듐하이알루로네이트;솔비탄아이소스테아레이트;덱스트린;약모밀추출물;병풀잎추출물(11ppm);치자추출물;병풀뿌리추출물(1ppm);프랑스해안송껍질추출물;밤부사불가리스잎추출물;아시아티코사이드(0.01ppm);아시아틱애씨드(0.01ppm);마데카소사이드(0.01ppm);마데카식애씨드(0.01ppm)
# 제품명: 시카플라스트 밤 B5+, 전성분: 정제수;부틸렌글라이콜;판테놀;스쿠알란;세테아릴알코올;1,2-헥산다이올;하이드로제네이티드폴리(C6-14올레핀);페닐트라이메티콘;다이아이소스테아릴말레이트;폴리글리세릴-10스테아레이트;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;글리세릴스테아레이트시트레이트;글리세릴스테아레이트;세테아릴글루코사이드;하이드로제네이티드레시틴;트로메타민;글리세린;카프릴릴글라이콜;폴리글리세릴-3메틸글루코오스다이스테아레이트;다이소듐이디티에이;에틸헥실글리세린;솔비탄아이소스테아레이트;마데카소사이드;아시아티코사이드;마데카식애씨드;아시아틱애씨드;글루코오스;녹차추출물;토코페롤
# 제품명: 순정 판텐소사이드 10 시카 밤, 전성분: 정제수;부틸렌글라이콜;판테놀;스쿠알란;세테아릴알코올;1,2-헥산다이올;하이드로제네이티드폴리(C614올레핀);페닐트라이메티콘;다이아이소스테아릴말레이트;폴리글리세릴-10스테아레이트;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;글리세릴스테아레이트시트레이트;글리세릴스테아레이트;세테아릴글루코사이드;하이드로제네이티드레시틴;트로메타민;글리세린;카프릴릴글라이콜;폴리글리세릴-3메틸글루코오스다이스테아레이트;다이소듐이디티에이;에틸헥실글리세린;솔비탄아이소스테아레이트;마데카소사이드;아시아티코사이드;마데카식애씨드;아시아틱애씨드;글루코오스;녹차추출물;토코페롤
# 제품명: 콜라겐 앰플 스틱, 전성분: 해바라기씨오일;폴리글리세릴-2트라이아이소스테아레이트;시어버터;폴리에틸렌;옥틸도데칸올;칸데릴라왁스;마이크로크리스탈린왁스;토코페릴아세테이트;스위트아몬드오일;다이아이소스테아릴말레이트;하이드롤라이즈드콜라겐;하이드롤라이즈드콜라겐추출물;지모뿌리추출물;화이트루핀씨추출물;아스타잔틴;판테놀;모나스커스추출물;풍선덩굴꽃/잎/덩굴추출물;올리브오일;녹차씨오일;동백나무씨오일;아르간커넬오일;퀸즈랜드넛오일;호호바씨오일;달맞이꽃오일;에키움플란타기네움씨오일;포도씨오일;알파-비사보롤;토코페롤;하이드로제네이티드폴리아이소부텐;드럼스틱씨오일;해바라기씨오일불검화물;정제수;부틸렌글라이콜;1,2-헥산다이올;하이드록시아세토페논;에틸헥실글리세린;데하이드로아세틱애씨드
# 제품명: MLE 크림 스틱 밤 , 전성분: 해바라기씨오일;세테아릴알코올;시어버터;폴리글리세릴-3비즈왁스;세레신;펜타에리스리틸스테아레이트/카프레이트/카프릴레이트/아디페이트;올리브오일;하이드로제네이티드식물성오일;다이머다이리놀레일다이머다이리놀리에이트;팔미토일팔미타마이드엠이에이;토코페롤;카프릴릴글라이콜;피토스테롤;이테야자열매오일;캐모마일꽃오일;살비아오일;정제수;단향오일;비스-카프릴로일옥시팔미타미도아이소프로판올;N-데카노일세린올;1,2-헥산다이올;판테놀;류신;라이신;페닐알라닌;트레오닌;발린
# 제품명: 비자 시카 밤 , 전성분: 정제수;프로판다이올;글리세린;사이클로펜타실록세인;스쿠알란;사이클로헥사실록세인;세테아릴알코올;판테놀;1,2-헥산다이올;C12-16알코올;폴리솔베이트60;다이아이소스테아릴말레이트;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;팔미틱애씨드;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;하이드로제네이티드레시틴;트로메타민;세테아릴글루코사이드;비자나무씨오일;다이소듐이디티에이;솔비탄아이소스테아레이트;마데카소사이드;아시아티코사이드;마데카식애씨드;아시아틱애씨드;글루코오스
# 제품명: 시카이드 밤, 전성분: 정제수;글리세린;부틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;펜타에리스리틸테트라에틸헥사노에이트;다이프로필렌글라이콜;세틸알코올;글리세릴스테아레이트;마이크로크리스탈린왁스;비즈왁스;시어버터;폴리솔베이트60;마카다미아씨오일;올리브오일;소듐하이알루로네이트;세라마이드엔피;티트리잎추출물;오레가노잎추출물;편백잎추출물;흰버드나무껍질추출물;락토바실러스/콩발효추출물;쇠비름추출물;육계나무껍질추출물;황금추출물;병풀추출물;마데카소사이드;마데카식애씨드;아시아티코사이드;아시아틱애씨드;바이오티노일헥사펩타이드-2아마이드;팔미틱애씨드;스테아릭애씨드;스테아릴알코올;아라키딜알코올;카프릴릴글라이콜;다이메티콘;알지닌;메틸프로판다이올;미리스틸알코올;카보머;옥틸도데칸올;하이드록시아세토페논;알란토인;토코페릴아세테이트;판테놀;글리세릴카프릴레이트;에틸헥실글리세린;잔탄검;하이드로제네이티드레시틴;1,2-헥산다이올;다이소듐이디티에이
# 제품명: 레드수딩 어드밴스드 릴리프밤, 전성분: 정제수;올리브오일;글리세린;펜틸렌글라이콜;오일팜오일;식물성오일;하이드로제네이티드레시틴;스쿠알란;베타인;팔미타마이드엠이에이;아세타마이드엠이에이;사코신;하이드록시에틸셀룰로오스;카보머;소듐카보머;잔탄검;토코페롤;다이소듐포스페이트;소듐포스페이트
# 제품명: 인텐시브 SOS 플러스 밤, 전성분: 정제수;카프릴릭/카프릭트라이글리세라이드;코코글리세라이즈;아이소펜틸다이올;사이클로헥사실록세인;글리세린;비닐다이메티콘;폴리글리세릴-3폴리리시놀리에이트;판테놀;폴리글리세릴-4다이아이소스테아레이트/폴리하이드록시스테아레이트/세바케이트;에틸헥실아이소노나노에이트;1,2-헥산다이올;비닐다이메티콘/메티콘실세스퀴옥세인크로스폴리머;보론나이트라이드;마그네슘설페이트;징크옥사이드;실리카실릴레이트;폴리글리세릴-3리시놀리에이트;알란토인;토코페롤;비스-헥실아미도아이소프로판올;메도우폼씨오일;소듐하이알루로네이트;펜틸렌글라이콜;마그네슘아스파테이트;징크글루코네이트;하이드롤라이즈드하이알루로닉애씨드;하이드록시프로필트라이모늄하이알루로네이트;메틸카프로오일타이로지네이트;카퍼글루코네이트;소듐아세틸레이티드하이알루로네이트;미리스토일/팔미토일옥소스테아라마이드/아라카마이드엠이에이;솔비탄스테아레이트;세테아릴알코올;글리세릴스테아레이트;카프릴릴글라이콜;피토스테롤;스테아릭애씨드;잔탄검
# 제품명: 베리어덤 릴리프 밤, 전성분: 정제수;다이프로필렌글라이콜;글리세린;메틸트라이메티콘;세테아릴알코올;운데케인;베헤닐알코올;트라이올레인;1,2-헥산다이올;시어버터;트라이데케인;다이펜타에리스리틸헥사하이드록시스테아레이트/헥사스테아레이트/헥사로지네이트;세테아릴올리베이트;솔비탄올리베이트;조류추출물;한련초잎추출물;병풀추출물;무화과추출물;한련초추출물;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;당느릅나무뿌리추출물;줄맨드라미씨추출물;가지열매추출물;알로에베라꽃추출물;홀리바질잎추출물;울금뿌리추출물;참산호말추출물;하이드로제네이티드레시틴;해바라기씨오일;글리세릴다이올리에이트;팔미틱애씨드;스테아릭애씨드;세테아릴글루코사이드;부틸렌글라이콜;글리세릴스테아레이트에스이;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;세라마이드엔피;C12-15알킬벤조에이트;콜레스테롤;잔탄검;프룩토올리고사카라이드;다이소듐이디티에이;베타-글루칸;미리스틱애씨드;하이드롤라이즈드하이알루로닉애씨드;드럼스틱씨오일;글라이신;토코페롤;세린;글루타믹애씨드;구아이아줄렌;아스파틱애씨드;류신;알라닌;라이신;알지닌;타이로신;페닐알라닌;발린;트레오닌;프롤린;아이소류신;히스티딘;메티오닌;시스테인
# 제품명: 안티퍼티그 아이 컨투어 스틱, 전성분: 프로필렌글라이콜;글리세린;정제수;다마스크장미꽃수;소듐스테아레이트;프로판다이올;귀리커넬추출물;에버라스팅꽃수;소듐하이드록사이드;서양송악잎/줄기추출물;소듐벤조에이트;시트릭애씨드;포타슘솔베이트
# 제품명: 더모이스처 배리어.D 멀티 밤, 전성분: 정제수;글리세린;다이프로필렌글라이콜;사이클로펜타실록세인;다이카프릴릴에터;세테아릴알코올;베헤닐알코올;1,2-헥산다이올;다이메티콘;글리세릴글루코사이드;세테아릴올리베이트;다이펜타에리스리틸헥사하이드록시스테아레이트/헥사스테아레이트/헥사로지네이트;한련초잎추출물;다시마추출물;병풀추출물;무화과추출물;꽃가루추출물;하이드로제네이티드레시틴;포도씨오일;호호바씨오일;퀸즈랜드넛오일;올리브오일;솔비탄올리베이트;팔미틱애씨드;덱스판테놀;스테아릭애씨드;다이메티콘올;글리세릴스테아레이트에스이;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;세테아릴글루코사이드;콜레스테롤;잔탄검;부틸렌글라이콜;글루코오스;프룩토올리고사카라이드;베타-글루칸;다이소듐이디티에이;세라마이드엔피;스쿠알란;하이드롤라이즈드하이알루로닉애씨드;올리브오일불검화물;밀배아오일불검화물;돌콩오일불검화물;토코페롤;카프릴릭/카프릭트라이글리세라이드;아이소말트;돌콩스테롤;리놀레익애씨드;포스포리피드;수크로오스팔미테이트;폴리글리세릴-10스테아레이트;폴리글리세릴-10올리에이트;알루미늄/마그네슘하이드록사이드스테아레이트;소듐스테아로일글루타메이트;7-데하이드로콜레스테롤;칼슘클로라이드;피톨;향료;에틸헥실글리세린
# 제품명: 판테놀 스틱밤, 전성분: 해바라기씨오일;세테아릴알코올;시어버터;폴리글리세릴-3비즈왁스;실리카;코코넛야자오일;올리브오일;하이드로제네이티드식물성오일;세레신;판테놀(10,000ppm);비사보롤;코코-카프릴레이트/카프레이트;토코페롤;카프릴릴글라이콜;미리스토일/팔미토일옥소스테아라마이드/아라카마이드엠이에이;피토스테롤;카카오씨버터;살비아오일;소두구씨오일;광곽향오일;멕시칸주니퍼오일;두송열매오일;캐모마일꽃오일;팔미토일팔미타마이드엠이에이;비스-카프릴로일옥시팔미타미도아이소프로판올;N-데카노일세린올;메틸카프로오일타이로지네이트;정제수;1,2-헥산다이올;류신;라이신;페닐알라닌;트레오닌;발린
# 제품명: 울트라 훼이셜 베리어 스틱 밤, 전성분: 정제수다이카프릴릴카보네이트부틸렌글라이콜아이소데실네오펜타노에이트합성왁스다이메티콘마이크로크리스탈린왁스글리세린나이아신아마이드라우릴피이지-8다이메티콘소듐클로라이드다이프로필렌글라이콜트레할로오스1,2-헥산다이올카프릴릭/카프릭트라이글리세라이드솔비탄세스퀴올리에이트스쿠알란글리세릴카프릴레이트다이메티콘/피이지-10/15크로스폴리머토코페롤스테아랄코늄헥토라이트세라마이드엔피슈도알테로모나스발효추출물프로정제수다이카프릴릴카보네이트부틸렌글라이콜아이소데실네오펜타노에이트합성왁스다이메티콘마이크로크리스탈린왁스글리세린나이아신아마이드라우릴피이지-8다이메티콘소듐클로라이드다이프로필렌글라이콜트레할로오스1,2-헥산다이올카프릴릭/카프릭트라이글리세라이드솔비탄세스퀴올리에이트스쿠알란글리세릴카프릴레이트다이메티콘/피이지-10/15크로스폴리머토코페롤스테아랄코늄헥토라이트세라마이드엔피슈도알테로모나스발효추출물프로필렌카보네이트아데노신소듐시트레이트살리실릭애씨드소듐하이드록사이드필렌카보네이트아데노신소듐시트레이트살리실릭애씨드소듐하이드록사이드
# 제품명: 다시마 앰플 클렌징폼, 전성분: 정제수;글리세린;다시마즙(10%);미리스틱애씨드;팔미틱애씨드;스테아릭애씨드;라우릭애씨드;포타슘하이드록사이드;솔비톨;코카미도프로필베타인;글리세릴스테아레이트;다시마가루(1%);합성비즈왁스;솔비탄올리베이트;1,2-헥산다이올;소듐폴리아크릴레이트;소듐클로라이드;향료;폴리쿼터늄-7;살리실릭애씨드;아라키딕애씨드;다이소듐이디티에이;소듐벤조에이트;석시닉애씨드;부틸렌글라이콜;블랙윌로우나무껍질추출물;소듐하이알루로네이트;숯추출물;하이드록시프로필트라이모늄하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트
# 제품명: 다이브인 저분자 히알루론산 클렌징 폼, 전성분: 정제수;글리세린;소듐코코일글라이시네이트;소듐라우로일글루타메이트;소듐하이알루로네이트;하이알루로닉애씨드(100ppm);하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;판테놀;알란토인;트레할로오스;토코페롤;버지니아풍년화추출물;녹차추출물;마트리카리아추출물;부틸렌글라이콜;다이프로필렌글라이콜;하이드록시프로필스타치포스페이트;글리세릴스테아레이트에스이;포타슘벤조에이트;소듐클로라이드;폴리쿼터늄-67;소듐아세테이트;1,2-헥산다이올;시트릭애씨드;에틸헥실글리세린;다이소듐이디티에이;말라카이트추출물
# 제품명: 아쿠아 라이스 약산성 클렌징폼, 전성분: 쌀추출물;글리세린;소듐코코일글라이시네이트;솔비톨;정제수;소듐라우로일글루타메이트;다이소듐코코암포다이아세테이트;1,2-헥산다이올;당호박추출물;팥추출물;라우릴베타인;쌀가루;소듐클로라이드;하이드록시프로필스타치포스페이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;폴리쿼터늄-22;헥실렌글라이콜;에틸헥실글리세린;하이드록시아세토페논;시트릭애씨드
# 제품명: 릴리프 하이드레이션 라이트 폼 클렌저, 전성분: 정제수;글리세린;소듐코코일글라이시네이트;소듐라우로일글루타메이트;1,2-헥산다이올;하이드록시프로필스타치포스페이트;병풀추출물;삼나무잎추출물;연꽃잎추출물;세라마이드엔피;세라마이드에이에스;세라마이드에이피;세라마이드엔에스;세라마이드이오피;병풀잎추출물;병풀뿌리추출물;마데카소사이드;마데카식애씨드;아시아티코사이드;아시아틱애씨드;콘민트가루;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;카카오씨추출물;다시마추출물;한련초잎추출물;라벤더추출물;마시멜로잎/뿌리추출물;바질꽃/잎추출물;로즈마리잎추출물;약모밀추출물;캐모마일꽃추출물;회향추출물;하이드로제네이티드레시틴;라우릴베타인;부틸렌글라이콜;소듐클로라이드;데실렌글라이콜;다이프로필렌글라이콜;베타-글루칸;글리세릴스테아레이트;덱스트린;효모발효여과물;콜레스테롤;프룩토올리고사카라이드;하이드롤라이즈드하이알루로닉애씨드;효모발효물;하이드록시아세토페논;에틸헥실글리세린;펜틸렌글라이콜;토코페롤
# 제품명: 퓨어&딥 클렌징 폼, 전성분: 글리세린;정제수;미리스틱애씨드;스테아릭애씨드;라우릭애씨드;포타슘코코에이트;포타슘하이드록사이드;포타슘코코일글리시네이트;팔미틱애씨드;소듐하이알루로네이트;부틸렌글라이콜;라벤더꽃수;보리지추출물;수레국화꽃추출물;클레리추출물;히아신스전초추출물;세라마이드엔피;마트리카리아꽃/잎추출물;하이드로제네이티드레시틴;연꽃꽃추출물;인동덩굴꽃추출물;알바수련꽃추출물;세룰라타벚나무꽃추출물;장미꽃추출물;1,2-헥산다이올;코코-글루코사이드;글리세릴스테아레이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐코코일이세티오네이트;올레익애씨드;카프릴릭/카프릭트라이글리세라이드;에틸헥실글리세린;퀼라자껍질추출물;잇꽃꽃추출물;크리산텔룸인디쿰추출물;아라키딕애씨드;소듐파이테이트;폴리쿼터늄-7;다마스크장미꽃오일;센티드제라늄꽃오일;일랑일랑꽃오일;시트릭애씨드;포타슘솔베이트;소듐벤조에이트;오렌지껍질오일;해바라기씨오일;베르가모트오일
# 제품명: 프레시 클렌저 떡솝 [그린], 전성분: 글리세린;정제수;소듐코코일이세티오네이트;스위트아몬드씨드케이크;소듐코코일글라이시네이트;1,2-헥산다이올;코코넛애씨드;쌀가루;향료;카올린;소듐이세티오네이트;하이드록시프로필스타치포스페이트;글리세릴스테아레이트;사철쑥가루;잔탄검;덱스트린;에틸헥실글리세린;치자추출물;리날룰;녹차추출물;히솝추출물;구기자추출물;버지니아풍년화추출물;티트리추출물;삼백초추출물;병풀추출물;쇠비름추출물;마트리카리아꽃추출물;무화과추출물;귀리커넬추출물;연꽃잎추출물;가지열매추출물;바다포도추출물;바오밥나무열매추출물;쑥잎추출물;인삼추출물;감초추출물;커피콩추출물;유칼립투스잎추출물;쌀추출물
# 제품명: 리커버리 머드 팩투폼 클렌저, 전성분: 정제수;소듐코코일이세티오네이트;글리세린;소듐메틸코코일타우레이트;코코넛애씨드;씨실트;소듐클로라이드;1,2-헥산다이올;소듐이세티오네이트;시트릭애씨드;포타슘코코일글리시네이트;숯가루;포타슘코코에이트;유칼립투스잎오일;다이소듐이디티에이;부틸렌글라이콜;블랙윌로우나무껍질추출물;동백나무꽃추출물;달맞이꽃추출물;서양산딸기추출물;엘더열매추출물;크랜베리추출물;소듐하이알루로네이트;개청각추출물;감태추출물;겔리듐카르틸라기네움추출물;톳추출물
# 제품명: 포어 퓨리파잉 살리실산 포밍 클렌저, 전성분: 정제수;글리세린;소듐코코일글라이시네이트;소듐라우로일글루타메이트;소듐메틸코코일타우레이트;부틸렌글라이콜;글리세릴스테아레이트;1,2-헥산다이올;살리실릭애씨드;시트릭애씨드;다이메틸설폰;몬모릴로나이트;일라이트;덱스트린;치자추출물;말릭애씨드;사과추출물
# 제품명: 1025 독도 클렌저, 전성분: 정제수;소듐코코일이세티오네이트;글리세린;소듐메틸코코일타우레이트;코코-베타인;포타슘코코일글리시네이트;포타슘벤조에이트;소듐클로라이드;폴리쿼터늄-67;포타슘코코에이트;시트릭애씨드;프룩토올리고사카라이드;사카라이드하이드롤리세이트;다이소듐이디티에이;풀루란;1,2-헥산다이올;알란토인;판테놀;해수;소듐아세테이트;부틸렌글라이콜;마트리카리아꽃오일;카프릴릭/카프릭트라이글리세라이드;베타-글루칸;포스파티딜콜린;하이알루로닉애씨드;에틸헥실글리세린;세라마이드엔피;글라이신;하이드롤라이즈드하이알루로닉애씨드;글루타믹애씨드;세린;소듐하이알루로네이트;라이신;알라닌;알지닌;트레오닌;프롤린
# 제품명: 그린 토마토 클레이 팩 클렌저, 전성분: 토마토수(49%);미리스틱애씨드;글리세린;카올린;벤토나이트;포타슘하이드록사이드;라우릭애씨드;티타늄디옥사이드;옥수수전분;팔미틱애씨드;정제수;부틸렌글라이콜;스테아릭애씨드;코코-글루코사이드;1,2-헥산다이올;무화과추출물;병풀추출물;달맞이꽃꽃추출물;당느릅나무뿌리추출물;대왕소나무잎추출물;칡뿌리추출물;토마토즙(5,229PPM);하이드로제네이티드레시틴;마그네슘알루미늄실리케이트;콘민트가루;하이드록시아세토페논;글리세릴스테아레이트;다이프로필렌글라이콜;에틸헥실글리세린;데실렌글라이콜;소듐코코일글라이시네이트;소듐파이테이트;베타-글루칸;토코페롤;세라마이드엔피;캐나다콜로이달클레이;헥토라이트;일라이트;몬모릴로나이트;크로뮴옥사이드그린6종복합클레이총함량120;000PPM함유
# 제품명: 세이프 미 릴리프 모이스처 클렌징폼, 전성분: 정제수;소듐코코일이세티오네이트;글리세린;소듐메틸코코일타우레이트;베타인;판테놀;라즈베리추출물;쓴박하추출물;소듐하이알루로네이트;바오밥나무열매추출물;코코-베타인;포타슘코코일글리시네이트;포타슘벤조에이트;소듐클로라이드;폴리쿼터늄-67;포타슘코코에이트;소듐아세테이트;1,2-헥산다이올;에틸헥실글리세린;시트릭애씨드;다이소듐이디티에이;로즈마리잎오일;다이프로필렌글라이콜
# 제품명: 마데카소사이드 에센셜 마스크 [흔적리페어], 전성분: 정제수;프로판다이올;다이프로필렌글라이콜;나이아신아마이드;글리세린;1,2-헥산다이올;트레할로오스;하이드록시아세토페논;알지닌;카보머;폴리글리세릴-10라우레이트;에틸헥실글리세린;폴리글리세릴-4라우레이트;잔탄검;다이소듐이디티에이;옥틸도데세스-16;연필향나무오일;마데카소사이드(50ppm);서양배추출물;호호바씨오일;다마스크장미꽃수;광곽향오일;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;오리스뿌리추출물;멜론추출물;불가리스쑥오일;서양송악잎/줄기추출물;로즈마리잎오일;부틸렌글라이콜;해수;소듐하이알루로네이트;병풀추출물;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드글라이코사미노글리칸;하이드로제네이티드레시틴;향부자추출물;벤질글라이콜;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;판테놀;세라마이드엔피
# 제품명: 다이브인 저분자 히알루론산 마스크, 전성분: 정제수;부틸렌글라이콜;글리세린;다이프로필렌글라이콜;소듐하이알루로네이트크로스폴리머;소듐하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨(100ppm);판테놀;트레할로오스;알란토인;마트리카리아꽃추출물;포트마리골드꽃추출물;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;가지열매추출물;홀리바질잎추출물;울금뿌리추출물;참산호말추출물;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머;사카라이드아이소머레이트;카보머;잔탄검;트로메타민;펜틸렌글라이콜;1,2-산다이올;하이드록시아세토페논;쇠비름추출물;말라카이트추출물;에틸헥실글리세린
# 제품명: 올리브 시카 카밍 앰플 마스크, 전성분: 정제수;글리세린;다이프로필렌글라이콜;1,2-헥산다이올;하이드록시에틸우레아;아미노부티릭애씨드;하이드록시아세토페논;카보머;알지닌;트레할로오스;베타인;판테놀;폴리글리세릴-10라우레이트;부틸렌글라이콜;에틸헥실글리세린;폴리글리세릴-4라우레이트;아데노신;잔탄검;글리세릴글루코사이드;다이소듐이디티에이;소듐하이알루로네이트;다마스크장미꽃수;흰목이버섯폴리사카라이드;치자꽃추출물;첨차잎추출물;양까막까치밥나무잎추출물;아마씨추출물;밤부사불가리스잎추출물;살비아오일;올리브추출물;마데카소사이드;라벤더오일;서양송악잎/줄기추출물;병풀추출물;병풀잎추출물;하이드로제네이티드포스파티딜콜린;카프릴릭/카프릭트라이글리세라이드;수크로오스스테아레이트;세테아릴알코올;아시아티코사이드;마데카식애씨드;아시아틱애씨드;소듐피씨에이;마그네슘피씨에이;칼슘피씨에이
# 제품명: 수퍼 아쿠아겔 오아시스 앰플 마스크, 전성분: 정제수;부틸렌글라이콜;글리세린;1,2-헥산다이올;베타인;알지닌;알란토인;소듐하이알루로네이트;하이드롤라이즈드콜라겐;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;소듐하이알루로네이트크로스폴리머;카퍼트라이펩타이드-1;하이드롤라이즈드소듐하이알루로네이트;포타슘하이알루로네이트;다이펩타이드-2;올리고펩타이드-1;트라이펩타이드-1;팔미토일펜타펩타이드-4;토코페롤;모란뿌리추출물;솔비톨;하이드록시에틸셀룰로오스;에틸헥실글리세린;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;다이소듐이디티에이
# 제품명: 다시마 콜라겐 퍼밍 마스크, 전성분: 정제수;글리세린;프로필렌글라이콜;메틸프로판다이올;변성알코올;폴리솔베이트80;부틸렌글라이콜;페녹시에탄올;베타인;카보머;클로페네신;잔탄검;트라이에탄올아민;향료;1,2-헥산다이올;다이소듐이디티에이;덱스트린;치자추출물;수용성콜라겐(50ppm);다이프로필렌글라이콜;알란토인;다시마추출물(10ppm);판테놀;트레할로오스;자일리틸글루코사이드;안하이드로자일리톨;카프릴릭/카프릭트라이글리세라이드;카프릴릴글라이콜;자일리톨;수크로오스팔미테이트;글루코오스;글라이신;하이드로제네이티드레시틴;세린;글루타믹애씨드;세라마이드엔피;소듐하이알루로네이트;아스파틱애씨드;류신;알라닌;라이신;알지닌;타이로신;페닐알라닌;프롤린;트레오닌;발린;아이소류신;히스티딘;시스테인;메티오닌;에틸헥실글리세린;아세틸헥사펩타이드-8;카퍼트라이펩타이드-1;올리고펩타이드-29;올리고펩타이드-32;팔미토일펜타펩타이드-4
# 제품명: 펩타테놀 수분 밸런스 겔 마스크, 전성분: 정제수;글리세린;다이프로필렌글라이콜;메틸프로판다이올;카프릴릭/카프릭트라이글리세라이드;나이아신아마이드;판테놀(10,050ppm);캐롭검;아이리쉬모스가루;아이리쉬모스;글리세릴스테아레이트;셀룰로오스검;피이지-100스테아레이트;하이드록시아세토페논;시어버터;카프릴릴글라이콜;포타슘클로라이드;소듐폴리아크릴레이트;폴리솔베이트60;하이드로제네이티드폴리데센;수크로오스;에틸헥실글리세린;아데노신;판토락톤;트라이데세스-6;C11-13아이소알케인;다이포타슘글리시리제이트;프로판다이올;부틸렌글라이콜;알로에베라잎추출물;벤질글라이콜;하이드롤라이즈드글라이코사미노글리칸;소듐하이알루로네이트;1,2-헥산다이올;소듐하이알루로네이트크로스폴리머;폴리글리세릴-10라우레이트;하이드롤라이즈드하이알루로닉애씨드;티트리잎추출물;하이드록시프로필트라이모늄하이알루로네이트;트라이펩타이드-1(0.007ppm);하이알루로닉애씨드;아세틸테트라펩타이드-2(0.0005ppm);아세틸테트라펩타이드-5(0.0005ppm);카퍼트라이펩타이드-1(0.0005ppm);팔미토일트라이펩타이드-1(0.0005ppm);팔미토일펜타펩타이드-4(0.0005ppm);헥사펩타이드-11(0.0005ppm);헥사펩타이드-9(0.0005ppm);소듐아세틸레이티드하이알루로네이트;팔미토일트라이펩타이드-5(0.0001ppm);다이소듐이디티에이;향료
# 제품명: 에센셜 마스크 [티트리], 전성분: 정제수;글리세린;다이프로필렌글라이콜;1,2-헥산다이올;티트리추출물(12,000ppm);메틸프로판다이올;프로판다이올;하이드록시아세토페논;알지닌;카보머;아미노부티릭애씨드;부틸렌글라이콜;잔탄검;폴리글리세릴-10라우레이트;아데노신;폴리글리세릴-4라우레이트;해수;다이소듐이디티에이;트루로즈오브예리코추출물;티트리잎오일(90ppm);폴리쿼터늄-51;하이드로제네이티드레시틴;베르가모트오일;티트리잎추출물(10ppm);4-터피네올(10ppm);글리세릴글루코사이드;화이트티트리잎추출물(10ppm);티트리꽃/잎/줄기추출물(10ppm);티트리잎수(10ppm);트레할로오스;소엽잎추출물;서양민들레뿌리줄기/뿌리추출물;향부자추출물;소두구씨오일;판테놀;세라마이드엔피
# 제품명: 밸런스풀 시카 마스크, 전성분: 정제수;부틸렌글라이콜;글리세린;다이프로필렌글라이콜;1,2-헥산다이올;병풀추출물(1,000ppm);마데카식애씨드;아시아티코사이드;아시아틱애씨드;마데카소사이드;판테놀;알란토인;쓴풀추출물;푸른연꽃추출물;락토바실러스발효물;접시꽃추출물;하이드롤라이즈드하이알루로닉애씨드;다이펩타이드-2;다이포타슘글리시리제이트;프로판다이올;아이소펜틸다이올;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;폴리글리세릴-4올리에이트;소듐스테아로일글루타메이트;피브이엠/엠에이코폴리머;소듐서팩틴;카보머;잔탄검;트로메타민;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;다이소듐이디티에이;에틸헥실글리세린
# 제품명: 하이퍼 마스크 [콜라겐], 전성분: 정제수;글리세린;다이프로필렌글라이콜;나이아신아마이드;세틸에틸헥사노에이트;카프릴릭/카프릭트라이글리세라이드;캐롭검;아이리쉬모스;아이리쉬모스가루;하이드록시아세토페논;셀룰로오스검;시어버터;카프릴릴글라이콜;포타슘클로라이드;호호바에스터;글리세릴스테아레이트;소듐폴리아크릴레이트;콜라겐(1;100ppm);스테아릴알코올;세틸알코올;솔비탄세스퀴올리에이트;하이드로제네이티드폴리데센;수크로오스;에틸헥실글리세린;소듐스테아로일글루타메이트;해바라기씨왁스;아데노신;부틸렌글라이콜;로즈마리잎오일;트라이데세스-6;C11-13아이소알케인;하이드롤라이즈드치자추출물;폴리글리세린-3;말토덱스트린;라벤더오일;1,2-헥산다이올;다이포타슘글리시리제이트;황련뿌리추출물;글루타티온;하이드롤라이즈드콜라겐(500ppb);구기자추출물;석류추출물;토코페롤;하이드로제네이티드레시틴;수용성콜라겐(100ppb);글루코오스;만노오스;콜라겐추출물(1ppb);다이소듐이디티에이
# 제품명: 핑크 콜라겐 앰플 마스크, 전성분: 정제수;글리세린;부틸렌글라이콜;다이프로필렌글라이콜;1,2-헥산다이올;트레할로오스;베타인;판테놀;하이드록시아세토페논;카보머;알지닌;잔탄검;아미노부티릭애씨드;폴리글리세릴-10라우레이트;아데노신;폴리글리세릴-4라우레이트;다이소듐이디티에이;글리세릴글루코사이드;바나나꽃추출물;다마스크장미꽃수;하이드롤라이즈드익스텐신;서양배추출물;서양자두추출물;멜론추출물;흰목이버섯폴리사카라이드;서양송악잎/줄기추출물;밤부사불가리스잎추출물;아마씨추출물;소듐하이알루로네이트;에틸헥실글리세린;팔미토일트라이펩타이드-1;팔미토일펜타펩타이드-4;헥사펩타이드-9;마그네슘피씨에이;소듐피씨에이;아세틸헥사펩타이드-8;칼슘피씨에이;트라이펩타이드-1;카퍼트라이펩타이드-1
# 제품명: 쿨링 마스크 [시카], 전성분: 정제수;글리세린;1,2-헥산다이올;병풀추출물;영지버섯줄기추출물;다발방패버섯추출물;병풀꽃/잎/줄기추출물;병풀뿌리추출물;병풀잎추출물;소듐하이알루로네이트;베타인;트레할로오스;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;판테놀;폴리글리세릴-10라우레이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;메틸다이아이소프로필프로피온아마이드;트로메타민;글리세릴글루코사이드;다이소듐이디티에이;알란토인;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;효모발효여과물;부틸렌글라이콜;효모발효물;아시아티코사이드;마데카소사이드;마데카식애씨드;아세틸헥사펩타이드-8;아스파틱애씨드;아시아틱애씨드;하이드록시아세토페논;펜틸렌글라이콜
# 제품명: 시카 리페어 판테놀 마스크, 전성분: 정제수;글리세린;나이아신아마이드;세틸에틸헥사노에이트;캐롭검;다이프로필렌글라이콜;아이리쉬모스추출물;1,2-헥산다이올;아이리쉬모스가루;수크로오스;세테아릴올리베이트;하이드록시아세토페논;판테놀(2,000ppm);솔비탄올리베이트;시어버터;포타슘클로라이드;카프릴릭/카프릭트라이글리세라이드;소듐폴리아크릴레이트;알란토인;폴리솔베이트60;하이드로제네이티드폴리데센;아데노신;포도씨오일;부틸렌글라이콜;다이소듐이디티에이;카프릴릴글라이콜;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;콜라겐수;다이포타슘글리시리제이트;트라이데세스-6;콜라겐추출물;마데카소사이드;아시아티코사이드;베타-글루칸;병풀추출물(52,300ppb);아이비고드열매추출물;자일리틸글루코사이드;C11-13아이소알케인;안하이드로자일리톨;호박가루;가지열매추출물;소듐하이알루로네이트;홀리바질잎추출물;울금뿌리추출물;자일리톨;카프릴로일살리실릭애씨드;폴리글리세릴-4카프레이트;하이드로제네이티드레시틴;토코페롤;참산호말추출물;드럼스틱씨오일;스테아릭애씨드;소듐디엔에이;대왕송잎추출물;당느릅나무뿌리추출물;달맞이꽃추출물;칡뿌리추출물;하이드롤라이즈드하이알루로닉애씨드;에틸헥실글리세린;소듐아세틸레이티드하이알루로네이트;폴리글리세릴-10라우레이트;트라이펩타이드-1;팔미토일트라이펩타이드-1;팔미토일펜타펩타이드-4;헥사펩타이드-9;아세틸헥사펩타이드-8;카퍼트라이펩타이드-1
# 제품명: 슈퍼 콜라겐 마스크, 전성분: 정제수;글리세린;다이프로필렌글라이콜;세틸에틸헥사노에이트;나이아신아마이드;캐롭검;1,2-헥산다이올;하이드롤라이즈드콜라겐(5,000ppm);아텔로콜라겐;콜라겐추출물;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;인삼뿌리프로토플라스트;에델바이스캘러스배양추출물;레티놀;하이알루로닉애씨드;팔미토일트라이펩타이드-5;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;카퍼트라이펩타이드-1;다이펩타이드-2;올리고펩타이드-1;팔미토일펜타펩타이드-4;트라이펩타이드-1;아데노신;인체제대혈세포배양액(30ppm);하이드록시아세토페논;아이리쉬모스추출물;아이리쉬모스;베타인;판테놀;트레할로오스;셀룰로오스검;시어버터;글리세릴스테아레이트;소듐폴리아크릴레이트;피이지-100스테아레이트;폴리솔베이트60;잔탄검;포타슘클로라이드;하이드로제네이티드폴리데센;수크로오스;다이소듐이디티에이;에틸헥실글리세린;트라이데세스-6;레시틴;하이드롤라이즈드치자추출물;하이드로제네이티드레시틴;말토덱스트린;부틸렌글라이콜;돌콩오일;토코페롤;콜레스테롤;소듐시트레이트;세린;알진;향료
# 제품명: 자작나무 수분 선크림, 전성분: 정제수;다이부틸아디페이트;프로판다이올;디에칠아미노하이드록시벤조일헥실벤조에이트;폴리메틸실세스퀴옥세인;에칠헥실트리아존;나이아신아마이드;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;카프릴릴메티콘;디에칠헥실부타미도트리아존;글리세린;1,2-헥산다이올;부틸렌글라이콜;자작나무수액(1,425ppm);소듐하이알루로네이트;하이알루로닉애씨드;글리세릴글루코사이드;다이포타슘글리시리제이트;알란토인;쇠비름추출물;개똥쑥추출물;구주소나무잎오일;캐모마일꽃오일;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;아스코빅애씨드;아데노신;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;잔탄검;t-부틸알코올;토코페롤;카보머
# 제품명: 히알루론산 프레쉬 선 세럼, 전성분: 정제수;다이부틸아디페이트;프로판다이올;부틸옥틸살리실레이트;에칠헥실트리아존;나이아신아마이드;드로메트리졸트리실록세인;폴리글리세릴-3다이스타이레이트;테레프탈릴리덴다이캠퍼설포닉애씨드;폴리메틸실세스퀴옥세인;디에칠아미노하이드록시벤조일헥실벤조에이트;트로메타민;판테놀;1,2-헥산다이올;펜틸렌글라이콜;글리세릴스테아레이트;실리카;카프릴릴메티콘;비스-에칠헥실옥시페놀메톡시페닐트리아진;포타슘세틸포스페이트;락토바실러스발효물;폴리C10-30알킬아크릴레이트;메틸프로판다이올;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;에틸헥실글리세린;하이드롤라이즈드소듐하이알루로네이트;잔탄검;아데노신;폴리터-1;소듐하이알루로네이트;바이오사카라이드검-1;스쿠알란;알란토인;에이서리톨;토코페롤;엑토인;하이드록시프로필트라이모늄하이알루로네이트;징크하이드롤라이즈드하이알루로네이트;글리세린;부틸렌글라이콜;약모밀추출물;시트릭애씨드;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이드로제네이티드레시틴;하이알루로닉애씨드;폴리글리세릴-10스테아레이트;병풀추출물;소듐하이알루로네이트크로스폴리머;소듐아스코빌포스페이트;토코페릴아세테이트;코코넛야자수;포타슘하이알루로네이트;레티닐팔미테이트;바이오틴;티아민에이치씨엘;폴릭애씨드;피리독신;사이아노코발아민
# 제품명: 워터풀 선크림 [에센스], 전성분: 정제수;사이클로펜타실록세인;티타늄디옥사이드;에칠헥실메톡시신나메이트;다이프로필렌글라이콜;세틸에틸헥사노에이트;세틸피이지/피피지-10/1다이메티콘;부틸렌글라이콜;에칠헥실살리실레이트;실리카;1,2-헥산다이올;카프릴릴메티콘;나이아신아마이드;옥토크릴렌;라우릴피이지-9폴리다이메틸실록시에틸다이메티콘;사이클로헥사실록세인;글리세린;비스-에칠헥실옥시페놀메톡시페닐트리아진;다이스테아다이모늄헥토라이트;폴리페닐실세스퀴옥세인;소듐클로라이드;카나우바왁스;황색산화철;트라이메틸실록시실리케이트;스테아릭애씨드;아크릴레이트/스테아릴아크릴레이트/다이메티콘메타크릴레이트코폴리머;다이아이소스테아릴말레이트;팔미틱애씨드;알루미늄하이드록사이드;글리세릴카프릴레이트;적색산화철;트라이에톡시카프릴릴실레인;향료;흑색산화철;알란토인;다이메티콘/비닐다이메티콘크로스폴리머;아데노신;다이메티콘;다이소듐이디티에이;소듐하이알루로네이트;글루타티온;토코페롤;하이드롤라이즈드콜라겐;카프릴릭/카프릭트라이글리세라이드;에탄올;약모밀추출물;하이드로제네이티드레시틴;복사나무꽃추출물;소듐스테아로일글루타메이트;하이알루로닉애씨드;아스코빅애씨드
# 제품명: 맑은 어성초 진정 수분 선크림, 전성분: 정제수;다이부틸아디페이트;프로판다이올;폴리메틸실세스퀴옥세인;다이아이소프로필세바케이트;디에칠아미노하이드록시벤조일헥실벤조에이트;에칠헥실트리아존;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;디에칠헥실부타미도트리아존;부틸렌글라이콜;글리세린;1,2-헥산다이올;카프릴릴메티콘;약모밀추출물;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;잔탄검;t-부틸알코올;토코페롤
# 제품명: 릴리프 하이드레이션 라이트 썬스크린, 전성분: 정제수;다이부틸아디페이트;프로판다이올;다이에틸아미노하이드록시벤조일헥실벤조에이트;폴리메틸실세스퀴옥세인;에틸헥실트리아존;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;카프릴릴메티콘;디에칠헥실부타미도트리아존;1,2-헥산다이올;글리세린;부틸렌글라이콜;병풀추출물;삼나무잎추출물;연꽃잎추출물;세라마이드엔피;세라마이드에이에스;세라마이드에이피;세라마이드엔에스;세라마이드이오피;마데카소사이드;마데카식애씨드;아시아티코사이드;아시아틱애씨드;티트리추출물;병풀뿌리추출물;병풀잎추출물;하이드로제네이티드레시틴;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;다이프로필렌글라이콜;잔탄검;글리세릴스테아레이트;효모발효여과물;t-부틸알코올;콜레스테롤;토코페롤;효모발효물
# 제품명: 다이브인 무기자차 마일드 선크림, 전성분: 정제수;징크옥사이드;사이클로헥사실록세인;부틸옥틸살리실레이트;프로필헵틸카프릴레이트;프로판다이올;다이카프릴릴카보네이트;아이소도데케인;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;카프릴릴메티콘;소듐하이알루로네이트;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;다이메틸실란올하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;소듐하이알루로네이트다이메틸실란올;판테놀;알란토인;트레할로오스;세라마이드엔피;버지니아풍년화추출물;쇠비름추출물;캐모마일꽃추출물;호호바씨오일;2,3-부탄다이올;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;메틸메타크릴레이트크로스폴리머;폴리글리세릴-2다이폴리하이드록시스테아레이트;라우릴폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;글리세릴카프릴레이트;카프릴릴글라이콜;부틸렌글라이콜;토코페롤;에틸헥실글리세린;1,2-헥산다이올;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;가지열매추출물;알로에베라꽃추출물;울금뿌리추출물;참산호말추출물;홀리바질잎추출물;녹차추출물;말라카이트추출물
# 제품명: 그린 마일드 업 선 플러스, 전성분: 정제수;징크옥사이드;프로판다이올;부틸옥틸살리실레이트;프로필헵틸카프릴레이트;코코-카프릴레이트/카프레이트;사이클로헥사실록세인;카프릴릴메티콘;아이소도데케인;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;메틸트라이메티콘;메틸메타크릴레이트크로스폴리머;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;1,2-헥산다이올;폴리글리세릴-2다이폴리하이드록시스테아레이트;라우릴폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;폴리메틸실세스퀴옥세인;글리세릴카프릴레이트;카프릴릴글라이콜;에틸헥실글리세린;소듐하이알루로네이트;부틸렌글라이콜;토코페롤;병풀추출물;타라열매추출물;프랑스해안송껍질추출물;코토니추출물;7-데하이드로콜레스테롤;약모밀추출물;엑토인;밀몽화꽃추출물;락토바실러스발효물;하이드록시신나믹애씨드;루틴
# 제품명: 마다가스카르 센텔라 히알루-시카 워터핏 선 세럼, 전성분: 정제수;다이부틸아디페이트;프로판다이올;다이에틸아미노하이드록시벤조일헥실벤조에이트;폴리메틸실세스퀴옥세인;에틸헥실트리아존;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;나이아신아마이드;코코-카프릴레이트/카프레이트;카프릴릴메티콘;디에칠헥실부타미도트리아존;글리세린;1,2-헥산다이올;부틸렌글라이콜;병풀추출물;자작나무껍질추출물;은행나무잎추출물;녹차추출물;밀싹추출물;자주개자리추출물;브로콜리싹추출물;로켓잎추출물;동백나무잎추출물;소듐하이알루로네이트;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;아데노신;잔탄검;t-부틸알코올;토코페롤;하이드롤라이즈드하이알루로닉애씨드;이노시톨;하이알루로닉애씨드;펜틸렌글라이콜;에틸헥실글리세린
# 제품명: 선뮤즈 모이스처 선크림, 전성분: 정제수;다이부틸아디페이트;프로판다이올;폴리메틸실세스퀴옥세인;다이아이소프로필세바케이트;디에칠아미노하이드록시벤조일헥실벤조에이트;에칠헥실트리아존;나이아신아마이드;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;디에칠헥실부타미도트리아존;글리세린;1,2-헥산다이올;부틸렌글라이콜;카프릴릴메티콘;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;아데노신;잔탄검;t-부틸알코올;토코페롤
# 제품명: 마데카소사이드 수분 선세럼 흔적 리페어, 전성분: 정제수;다이부틸아디페이트;프로판다이올;부틸옥틸살리실레이트;에칠헥실트리아존;메틸메타크릴레이트크로스폴리머;비스-에칠헥실옥시페놀메톡시페닐트리아진;옥토크릴렌;나이아신아마이드;테레프탈릴리덴디캠퍼설포닉애씨드;알지닌;다이메티콘올;메틸프로판다이올;폴리메틸실세스퀴옥세인;1,2-헥산다이올;펜틸렌글라이콜;C11-13아이소알케인;하이드록시에틸우레아;부틸렌글라이콜;베헤닐알코올;폴리글리세릴-3메틸글루코오스다이스테아레이트;다이프로필렌글라이콜;카보머;아이소도데케인;폴리C10-30알킬아크릴레이트;다이메티콘/비닐다이메티콘크로스폴리머;폴리에터-1;스핑고모나스발효추출물;에틸헥실글리세린;병풀잎추출물;아데노신;서양배추출물;소듐스테아로일글루타메이트;연필향나무오일;마데카소사이드;소듐하이알루로네이트;다마스크장미꽃수;멜론추출물;오리스뿌리추출물;서양송악잎/줄기추출물;호호바씨오일;광곽향오일;불가리스쑥오일;마이크로크리스탈린셀룰로오스;로즈마리잎오일;병풀추출물;셀룰로오스검;토코페롤;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;사과추출물;에리스리톨;글리세린;판테놀;솔비톨;보검선인장줄기추출물;마데카식애씨드;아시아틱애씨드;아시아티코사이드;효모발효여과물;바이오사카라이드검-4;다이소듐포스페이트;다발방패버섯추출물
# 제품명: 덕만이 무기차자 썬크림, 전성분: 정제수;징크옥사이드(17%);프로필헵틸카프릴레이트;부틸옥틸살리실레이트;프로판다이올;코코-카프릴레이트/카프레이트;카프릴릴메티콘;아이소도데케인;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;메틸트라이메티콘;메틸메타크릴레이트크로스폴리머;밤부사불가리스추출물;병풀추출물;약모밀추출물;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;자작나무수액;판테놀;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;1,2-헥산다이올;폴리글리세릴-2다이폴리하이드록시스테아레이트;라우릴폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;폴리메틸실세스퀴옥세인;글리세릴카프릴레이트;카프릴릴글라이콜;에틸헥실글리세린;토코페롤;부틸렌글라이콜;펜틸렌글라이콜
# 제품명: 바이옴 레미디 톤업 선크림 [보라], 전성분: 정제수;다이부틸아디페이트;부틸옥틸살리실레이트;에칠헥실트리아존;프로판다이올;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;메틸프로판다이올;나이아신아마이드;디에칠아미노하이드록시벤조일헥실벤조에이트;티타늄디옥사이드(CI77891);1,2-헥산다이올;비스-에칠헥실옥시페놀메톡시페닐트리아진;폴리글리세릴-3메틸글루코오스다이스테아레이트;폴리글리세릴-3다이스테아레이트;울트라마린;코코-카프릴레이트/카프레이트;데실글루코사이드;폴리아크릴레이트크로스폴리머-6;세테아릴알코올;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;브이피/에이코신코폴리머;소듐폴리아크릴로일다이메틸타우레이트;에틸헥실글리세린;글리세릴스테아레이트시트레이트;카올린;폴리글리세릴-6폴리하이드록시스테아레이트;알루미늄하이드록사이드;폴리글리세릴-6폴리리시놀리에이트;아데노신;트라이에톡시카프릴릴실레인;소듐스테아로일글루타메이트;글리세린;적색산화철;잔탄검;쿠티박테리움그라눌로숨발효추출여과물(100ppm);폴리글리세린-6;판테놀;석시닉애씨드;토코페롤;아스코빌팔미테이트
# 제품명: 썬스크린 [레이저UV], 전성분: 정제수;징크옥사이드;다이부틸아디페이트;사이클로헥사실록세인;프로필헵틸카프릴레이트;다이프로필렌글라이콜;부틸옥틸살리실레이트;폴리글리세릴-4다이아이소스테아레이트/폴리하이드록시스테아레이트/세바케이트;나이아신아마이드;칼슘알루미늄보로실리케이트;디에칠아미노하이드록시벤조일헥실벤조에이트;메틸메타크릴레이트크로스폴리머;비스-에칠헥실옥시페놀메톡시페닐트리아진;에칠헥실트리아존;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;티타늄디옥사이드;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;1,2-헥산다이올;폴리메틸실세스퀴옥세인;글리세릴카프릴레이트;카프릴릴글라이콜;에틸헥실글리세린;아데노신;토코페롤;카르노신;트라이메틸실록시실리케이트;하이드롤라이즈드콜라겐;향료
# 제품명: 올 데이 에어리 선크림, 전성분: 정제수;다이부틸아디페이트;부틸옥틸살리실레이트;디에칠아미노하이드록시벤조일헥실벤조에이트;폴리실리콘-15;C12-15알킬벤조에이트;에칠헥실트리아존;비스-에칠헥실옥시페놀메톡시페닐트리아진;폴리메틸실세스퀴옥세인;글리세린;나이아신아마이드;폴리글리세릴-6스테아레이트;세테아릴올리베이트;마이크로크리스탈린셀룰로오스;판테놀;실리카;솔비탄올리베이트;다이프로필렌글라이콜;하이드록시아세토페논;폴리C10-30알킬아크릴레이트;폴리글리세릴-6베헤네이트;알란토인;카프릴릴글라이콜;스테아릴알코올;글리세릴스테아레이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;아데노신;세테아릴알코올;다이소듐이디티에이;부틸렌글라이콜;쇠비름추출물;알로에베라잎추출물;참마뿌리추출물;다시마추출물;제비꽃꽃추출물;당느릅나무뿌리추출물;다이포타슘글리시리제이트;마카뿌리추출물;1,2-헥산다이올;구기자추출물;비치스트로베리추출물;불가리스매자뿌리추출물;검은뽕나무열매추출물
# --- 위 목록과 사용자 정보를 바탕으로 제품을 추천해주세요. ---
#
# 전문가로서 답변해주세요.
#
#
# > Finished chain.
# 챗봇: 안녕하세요! 건성 피부를 위한 보습 효과가 뛰어난 제품을 찾고 계시군요. 다음과 같은 제품들을 추천드립니다:
#
# 1. **판테놀 베리어 토너**: 이 제품은 판테놀과 세라마이드 성분이 포함되어 있어 피부 장벽 강화 및 깊은 보습을 제공하여 건성 피부에 적합합니다.
#
# 2. **다이브인 저분자 히알루론산 크림**: 저분자 히알루론산이 다량 함유되어 있어 건성 피부에 충분한 수분을 공급하고, 다양한 식물 추출물들이 피부를 진정시켜 줍니다.
#
# 3. **아쿠아 스쿠알란 수분크림**: 스쿠알란과 하이알루론산 복합체가 피부에 수분을 공급하고, 피부를 부드럽고 탄력 있게 가꿔줍니다.
#
# 4. **하이드라 셀 부스팅 토너**: 이 토너는 수분 공급에 탁월하며, 피부에 빠르게 흡수되어 촉촉함을 유지하는 데 도움이 됩니다.
#
# 이 제품들은 모두 보습력이 뛰어나고 건성 피부에 최적화되어 있으며, 피부 장벽을 강화하는 성분이 포함되어 있어 피부를 건강하고 촉촉하게 유지하는 데 큰 도움이 될 것입니다. 사용 전 패치 테스트를 권장드리며, 자신의 피부 상태에 맞게 사용하시길 바랍니다. 도움이 필요하시면 언제든지 말씀해 주세요!
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
#
# 당신은 친절하고 전문적인 화장품 추천 전문가입니다.
# 사용자와의 이전 대화 내용은 아래와 같습니다.
#
# Human: 난 건성 피부인데, 보습에 좋은 제품 찾아줘
#
# --- 참고: '보습' 효능을 가진 제품 목록 ---
# 제품명: 아쿠아 오아시스 토너, 전성분: 정제수;다이프로필렌글라이콜;부틸렌글라이콜;글리세린;1,2-헥산다이올;베타인;판테놀;알란토인;파파야열매추출물;글루코노락톤;자일리틸글루코사이드;안하이드로자일리톨;자일리톨;소듐하이알루로네이트;글루코오스;파파인;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머
# 제품명: 1025 독도 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;펜틸렌글라이콜;프로판다이올;아이리쉬모스추출물;사탕수수추출물;해수;1,2-헥산다이올;프로테아제;베타인;판테놀;에틸헥실글리세린;알란토인;잔탄검;다이소듐이디티에이
# 제품명: 원더 세라마이드 모찌 토너, 전성분: 정제수;다이프로필렌글라이콜;글리세린;펜타에리스리틸테트라아이소스테아레이트;글리세레스-26;1,2-헥산다이올;마카다미아씨오일(구명칭);페닐트라이메티콘;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;스타이렌/브이피코폴리머;에틸헥실글리세린;병풀추출물;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;카프릴릭/카프릭트라이글리세라이드;알란토인;하이드로제네이티드레시틴;프로판다이올;판테놀;피토스테릴/옥틸도데실라우로일글루타메이트;세라마이드엔피;소듐하이알루로네이트;로즈우드오일;레몬껍질오일;다이소듐이디티에이;리날룰;리모넨
# 제품명: 다이브인 저분자 히알루론산 토너, 전성분: 정제수;부틸렌글라이콜;다이프로필렌글라이콜;1,2-헥산다이올;글리세린;베타인;알란토인;판테놀;쇠비름추출물;트레할로오스;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드(100ppm);소듐하이알루로네이트크로스폴리머;하이드롤라이즈드소듐하이알루로네이트;소듐아세틸레이티드하이알루로네이트;2,3-부탄다이올;펜틸렌글라이콜;말라카이트추출물;다이소듐이디티에이;에틸헥실글리세린
# 제품명: 초저분자 히아루론산 토너, 전성분: 정제수;메틸프로판다이올;1,2-헥산다이올;해수;글리세린;베타인;알란토인;부틸렌글라이콜;카프릴릴글라이콜;에틸헥실글리세린;판테놀;잔탄검;말라카이트추출물;다이소듐이디티에이;하이드롤라이즈드하이알루로닉애씨드;펜틸렌글라이콜;자일리틸글루코사이드;안하이드로자일리톨;소듐하이알루로네이트;자일리톨;포타슘하이알루로네이트;글루코오스;다이메틸실란올하이알루로네이트;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드록시프로필트라이모늄하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드칼슘하이알루로네이트;하이알루로닉애씨드;버지니아풍년화추출물;소듐설페이티드하이알루로네이트;편백잎추출물;소듐스테아로일하이알루로네이트;소듐올레오일하이알루로네이트
# 제품명: 판테놀 베리어 토너, 전성분: 정제수;부틸렌글라이콜;판테놀;다이프로필렌글라이콜;글리세레스-26;나이아신아마이드;1,2-헥산다이올;카카두플럼추출물;병풀추출물;아시아티코사이드;마데카소사이드;세라마이드엔피;얼룩파인애플추출물;파파야열매추출물;귀리가루추출물;락토바실러스/콩발효추출물;락토바실러스/쌀발효물;락토바실러스/인삼뿌리발효여과물;효모/율무씨발효여과물;효모/감자추출물발효여과물;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;동백나무씨오일;아시아틱애씨드;마데카식애씨드;리놀레익애씨드;락토바이오닉애씨드;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;하이드로제네이티드레시틴;프로판다이올;소듐시트레이트;베타인;글리세린;시트릭애씨드;소듐폴리아크릴로일다이메틸타우레이트;하이드록시프로필트라이모늄하이알루로네이트;아데노신;펜틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;에틸헥실글리세린
# 제품명: 올리고 히알루론산 딥 토너, 전성분: 정제수;부틸렌글라이콜;1,2-헥산다이올;글리세린;베타-글루칸;베타인;소듐하이알루로네이트(2,700ppm);판테놀;솔비톨;아세틸글루코사민;글루쿠로닉애씨드;알란토인;토코페롤;에틸헥실글리세린;다이소듐이디티에이
# 제품명: 하이드라 셀 부스팅 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;1,2-헥산다이올;하이드록시아세토페논;알란토인;카보머;알지닌;다이소듐이디티에이;녹차추출물;소듐하이알루로네이트;나이아신아마이드;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드글라이코사미노글리칸;리보플라빈;폴릭애씨드;판테놀;메나다이온;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;다이메틸실란올하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;바이오틴;사이아노코발아민;아스코빅애씨드;티아민에이치씨엘;피리독신;바이오플라보노이드
# 제품명: 무알콜 뮤신 에센스 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;판테놀;1,2-헥산다이올;와일드얌뿌리추출물(7395ppm);카보머;알지닌;병풀잎수;펜틸렌글라이콜;소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드하이알루로닉애씨드;에틸헥실글리세린;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트
# 제품명: 어성초 77 수딩 토너, 전성분: 약모밀꽃/잎/줄기수(77%);정제수;1,2-헥산다이올;글리세린;베타인;부틸렌글라이콜;아이소펜틸다이올;판테놀;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;병풀추출물;우엉뿌리추출물;진흙버섯추출물;쇠비름추출물;마트리카리아꽃추출물;체이스트트리추출물;소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;다이소듐이디티에이
# 제품명: 어성초 진정해 수분 토너, 전성분: 정제수;약모밀추출물;부틸렌글라이콜;다이프로필렌글라이콜;프로판다이올;1,2-헥산다이올;글리세린;하이드록시아세토페논;에틸헥실글리세린;카프릴릴글라이콜;폴리글리세릴-10라우레이트;폴리글리세릴-4라우레이트;카보머;알란토인;다이포타슘글리시리제이트;소듐파이테이트;소듐하이알루로네이트;병풀잎추출물;알지닌;살비아오일;마데카소사이드;제올라이트;루이보스잎추출물;마조람잎추출물;서양측백나무잎추출물;티트리잎추출물;로즈마리잎추출물;병풀추출물;살비아잎추출물;타임추출물;레몬밤잎추출물;히솝추출물;티트리추출물;작약뿌리추출물;녹차추출물
# 제품명: 나인 토너, 전성분: 정제수;글리세린;2,3-부탄다이올;판테놀;다이프로필렌글라이콜;1,2-헥산다이올;하이드록시아세토페논;에리스리톨;베타인;트레할로오스;알란토인;에틸헥실글리세린;소듐하이알루로네이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;알지닌;다이소듐이디티에이;쑥위추출물;부틸렌글라이콜;포타슘하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;로즈마리잎추출물;자작나무수액;트루로즈오브예리코추출물;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드
# 제품명: 비피다 바이옴 앰플 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;프로판다이올;펜틸렌글라이콜;버지니아풍년화수;락토바실러스발효용해물;락토코쿠스발효용해물;락토바실러스/호박발효추출물;효모발효여과물;베타인;알란토인;판테놀;세라마이드엔피;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드글라이코사미노글리칸;소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드로제네이티드레시틴;비피다발효여과물;비피다발효용해물;자일리톨;안하이드로자일리톨;자일리틸글루코사이드;글루코오스;1,2-헥산다이올;흰버드나무껍질추출물;락토바이오닉애씨드;사탕수수추출물;쿠티박테리움그라눌로숨발효추출여과물;프룩토오스;프룩토올리고사카라이드;카프릴릭/카프릭트라이글리세라이드;벤질글라이콜;토코페롤;에틸헥실글리세린;잔탄검;다이소듐이디티에이;아이리쉬모스추출물;클로렐라불가리스추출물
# 제품명: 리얼 히알루로닉 100 토너, 전성분: 하이드롤라이즈드하이알루로닉애씨드(932601.50052ppm);글리세린;프로판다이올;하이드로제네이티드레시틴;소듐하이알루로네이트(1.0052ppm);1,2-헥산다이올;알지닌;벤질글라이콜;베타인;부틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;시트릭애씨드;다이메틸실란올하이알루로네이트;다이소듐이디티에이;에틸헥실글리세린;글라이신;히스티딘;하이알루로닉애씨드(1.00001ppm);하이드롤라이즈드글라이코사미노글리칸(0.0056ppm);하이드롤라이즈드소듐하이알루로네이트(1.5ppm);하이드록시프로필트라이모늄하이알루로네이트(0.80012ppm);라이소레시틴;포타슘하이알루로네이트;세린;소듐아세틸레이티드하이알루로네이트(0.400002ppm);소듐시트레이트;소듐하이알루로네이트크로스폴리머(0.801ppm);소듐하이알루로네이트다이메틸실란올;소듐피씨에이;소듐스테아로일글루타메이트;수크로오스라우레이트;토코페롤;정제수;잔탄검
# 제품명: 시카테롤 토너, 전성분: 정제수;프로판다이올;병풀추출물;1,2-헥산다이올;베타-시토스테롤
# ...
# 제품명: 포어 퓨리파잉 살리실산 포밍 클렌저, 전성분: 정제수;글리세린;소듐코코일글라이시네이트;소듐라우로일글루타메이트;소듐메틸코코일타우레이트;부틸렌글라이콜;글리세릴스테아레이트;1,2-헥산다이올;살리실릭애씨드;시트릭애씨드;다이메틸설폰;몬모릴로나이트;일라이트;덱스트린;치자추출물;말릭애씨드;사과추출물
# 제품명: 1025 독도 클렌저, 전성분: 정제수;소듐코코일이세티오네이트;글리세린;소듐메틸코코일타우레이트;코코-베타인;포타슘코코일글리시네이트;포타슘벤조에이트;소듐클로라이드;폴리쿼터늄-67;포타슘코코에이트;시트릭애씨드;프룩토올리고사카라이드;사카라이드하이드롤리세이트;다이소듐이디티에이;풀루란;1,2-헥산다이올;알란토인;판테놀;해수;소듐아세테이트;부틸렌글라이콜;마트리카리아꽃오일;카프릴릭/카프릭트라이글리세라이드;베타-글루칸;포스파티딜콜린;하이알루로닉애씨드;에틸헥실글리세린;세라마이드엔피;글라이신;하이드롤라이즈드하이알루로닉애씨드;글루타믹애씨드;세린;소듐하이알루로네이트;라이신;알라닌;알지닌;트레오닌;프롤린
# 제품명: 그린 토마토 클레이 팩 클렌저, 전성분: 토마토수(49%);미리스틱애씨드;글리세린;카올린;벤토나이트;포타슘하이드록사이드;라우릭애씨드;티타늄디옥사이드;옥수수전분;팔미틱애씨드;정제수;부틸렌글라이콜;스테아릭애씨드;코코-글루코사이드;1,2-헥산다이올;무화과추출물;병풀추출물;달맞이꽃꽃추출물;당느릅나무뿌리추출물;대왕소나무잎추출물;칡뿌리추출물;토마토즙(5,229PPM);하이드로제네이티드레시틴;마그네슘알루미늄실리케이트;콘민트가루;하이드록시아세토페논;글리세릴스테아레이트;다이프로필렌글라이콜;에틸헥실글리세린;데실렌글라이콜;소듐코코일글라이시네이트;소듐파이테이트;베타-글루칸;토코페롤;세라마이드엔피;캐나다콜로이달클레이;헥토라이트;일라이트;몬모릴로나이트;크로뮴옥사이드그린6종복합클레이총함량120;000PPM함유
# 제품명: 세이프 미 릴리프 모이스처 클렌징폼, 전성분: 정제수;소듐코코일이세티오네이트;글리세린;소듐메틸코코일타우레이트;베타인;판테놀;라즈베리추출물;쓴박하추출물;소듐하이알루로네이트;바오밥나무열매추출물;코코-베타인;포타슘코코일글리시네이트;포타슘벤조에이트;소듐클로라이드;폴리쿼터늄-67;포타슘코코에이트;소듐아세테이트;1,2-헥산다이올;에틸헥실글리세린;시트릭애씨드;다이소듐이디티에이;로즈마리잎오일;다이프로필렌글라이콜
# 제품명: 마데카소사이드 에센셜 마스크 [흔적리페어], 전성분: 정제수;프로판다이올;다이프로필렌글라이콜;나이아신아마이드;글리세린;1,2-헥산다이올;트레할로오스;하이드록시아세토페논;알지닌;카보머;폴리글리세릴-10라우레이트;에틸헥실글리세린;폴리글리세릴-4라우레이트;잔탄검;다이소듐이디티에이;옥틸도데세스-16;연필향나무오일;마데카소사이드(50ppm);서양배추출물;호호바씨오일;다마스크장미꽃수;광곽향오일;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;오리스뿌리추출물;멜론추출물;불가리스쑥오일;서양송악잎/줄기추출물;로즈마리잎오일;부틸렌글라이콜;해수;소듐하이알루로네이트;병풀추출물;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드글라이코사미노글리칸;하이드로제네이티드레시틴;향부자추출물;벤질글라이콜;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;판테놀;세라마이드엔피
# 제품명: 다이브인 저분자 히알루론산 마스크, 전성분: 정제수;부틸렌글라이콜;글리세린;다이프로필렌글라이콜;소듐하이알루로네이트크로스폴리머;소듐하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨(100ppm);판테놀;트레할로오스;알란토인;마트리카리아꽃추출물;포트마리골드꽃추출물;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;가지열매추출물;홀리바질잎추출물;울금뿌리추출물;참산호말추출물;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머;사카라이드아이소머레이트;카보머;잔탄검;트로메타민;펜틸렌글라이콜;1,2-산다이올;하이드록시아세토페논;쇠비름추출물;말라카이트추출물;에틸헥실글리세린
# 제품명: 올리브 시카 카밍 앰플 마스크, 전성분: 정제수;글리세린;다이프로필렌글라이콜;1,2-헥산다이올;하이드록시에틸우레아;아미노부티릭애씨드;하이드록시아세토페논;카보머;알지닌;트레할로오스;베타인;판테놀;폴리글리세릴-10라우레이트;부틸렌글라이콜;에틸헥실글리세린;폴리글리세릴-4라우레이트;아데노신;잔탄검;글리세릴글루코사이드;다이소듐이디티에이;소듐하이알루로네이트;다마스크장미꽃수;흰목이버섯폴리사카라이드;치자꽃추출물;첨차잎추출물;양까막까치밥나무잎추출물;아마씨추출물;밤부사불가리스잎추출물;살비아오일;올리브추출물;마데카소사이드;라벤더오일;서양송악잎/줄기추출물;병풀추출물;병풀잎추출물;하이드로제네이티드포스파티딜콜린;카프릴릭/카프릭트라이글리세라이드;수크로오스스테아레이트;세테아릴알코올;아시아티코사이드;마데카식애씨드;아시아틱애씨드;소듐피씨에이;마그네슘피씨에이;칼슘피씨에이
# 제품명: 수퍼 아쿠아겔 오아시스 앰플 마스크, 전성분: 정제수;부틸렌글라이콜;글리세린;1,2-헥산다이올;베타인;알지닌;알란토인;소듐하이알루로네이트;하이드롤라이즈드콜라겐;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;소듐하이알루로네이트크로스폴리머;카퍼트라이펩타이드-1;하이드롤라이즈드소듐하이알루로네이트;포타슘하이알루로네이트;다이펩타이드-2;올리고펩타이드-1;트라이펩타이드-1;팔미토일펜타펩타이드-4;토코페롤;모란뿌리추출물;솔비톨;하이드록시에틸셀룰로오스;에틸헥실글리세린;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;다이소듐이디티에이
# 제품명: 다시마 콜라겐 퍼밍 마스크, 전성분: 정제수;글리세린;프로필렌글라이콜;메틸프로판다이올;변성알코올;폴리솔베이트80;부틸렌글라이콜;페녹시에탄올;베타인;카보머;클로페네신;잔탄검;트라이에탄올아민;향료;1,2-헥산다이올;다이소듐이디티에이;덱스트린;치자추출물;수용성콜라겐(50ppm);다이프로필렌글라이콜;알란토인;다시마추출물(10ppm);판테놀;트레할로오스;자일리틸글루코사이드;안하이드로자일리톨;카프릴릭/카프릭트라이글리세라이드;카프릴릴글라이콜;자일리톨;수크로오스팔미테이트;글루코오스;글라이신;하이드로제네이티드레시틴;세린;글루타믹애씨드;세라마이드엔피;소듐하이알루로네이트;아스파틱애씨드;류신;알라닌;라이신;알지닌;타이로신;페닐알라닌;프롤린;트레오닌;발린;아이소류신;히스티딘;시스테인;메티오닌;에틸헥실글리세린;아세틸헥사펩타이드-8;카퍼트라이펩타이드-1;올리고펩타이드-29;올리고펩타이드-32;팔미토일펜타펩타이드-4
# 제품명: 펩타테놀 수분 밸런스 겔 마스크, 전성분: 정제수;글리세린;다이프로필렌글라이콜;메틸프로판다이올;카프릴릭/카프릭트라이글리세라이드;나이아신아마이드;판테놀(10,050ppm);캐롭검;아이리쉬모스가루;아이리쉬모스;글리세릴스테아레이트;셀룰로오스검;피이지-100스테아레이트;하이드록시아세토페논;시어버터;카프릴릴글라이콜;포타슘클로라이드;소듐폴리아크릴레이트;폴리솔베이트60;하이드로제네이티드폴리데센;수크로오스;에틸헥실글리세린;아데노신;판토락톤;트라이데세스-6;C11-13아이소알케인;다이포타슘글리시리제이트;프로판다이올;부틸렌글라이콜;알로에베라잎추출물;벤질글라이콜;하이드롤라이즈드글라이코사미노글리칸;소듐하이알루로네이트;1,2-헥산다이올;소듐하이알루로네이트크로스폴리머;폴리글리세릴-10라우레이트;하이드롤라이즈드하이알루로닉애씨드;티트리잎추출물;하이드록시프로필트라이모늄하이알루로네이트;트라이펩타이드-1(0.007ppm);하이알루로닉애씨드;아세틸테트라펩타이드-2(0.0005ppm);아세틸테트라펩타이드-5(0.0005ppm);카퍼트라이펩타이드-1(0.0005ppm);팔미토일트라이펩타이드-1(0.0005ppm);팔미토일펜타펩타이드-4(0.0005ppm);헥사펩타이드-11(0.0005ppm);헥사펩타이드-9(0.0005ppm);소듐아세틸레이티드하이알루로네이트;팔미토일트라이펩타이드-5(0.0001ppm);다이소듐이디티에이;향료
# 제품명: 에센셜 마스크 [티트리], 전성분: 정제수;글리세린;다이프로필렌글라이콜;1,2-헥산다이올;티트리추출물(12,000ppm);메틸프로판다이올;프로판다이올;하이드록시아세토페논;알지닌;카보머;아미노부티릭애씨드;부틸렌글라이콜;잔탄검;폴리글리세릴-10라우레이트;아데노신;폴리글리세릴-4라우레이트;해수;다이소듐이디티에이;트루로즈오브예리코추출물;티트리잎오일(90ppm);폴리쿼터늄-51;하이드로제네이티드레시틴;베르가모트오일;티트리잎추출물(10ppm);4-터피네올(10ppm);글리세릴글루코사이드;화이트티트리잎추출물(10ppm);티트리꽃/잎/줄기추출물(10ppm);티트리잎수(10ppm);트레할로오스;소엽잎추출물;서양민들레뿌리줄기/뿌리추출물;향부자추출물;소두구씨오일;판테놀;세라마이드엔피
# 제품명: 밸런스풀 시카 마스크, 전성분: 정제수;부틸렌글라이콜;글리세린;다이프로필렌글라이콜;1,2-헥산다이올;병풀추출물(1,000ppm);마데카식애씨드;아시아티코사이드;아시아틱애씨드;마데카소사이드;판테놀;알란토인;쓴풀추출물;푸른연꽃추출물;락토바실러스발효물;접시꽃추출물;하이드롤라이즈드하이알루로닉애씨드;다이펩타이드-2;다이포타슘글리시리제이트;프로판다이올;아이소펜틸다이올;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;폴리글리세릴-4올리에이트;소듐스테아로일글루타메이트;피브이엠/엠에이코폴리머;소듐서팩틴;카보머;잔탄검;트로메타민;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;다이소듐이디티에이;에틸헥실글리세린
# 제품명: 하이퍼 마스크 [콜라겐], 전성분: 정제수;글리세린;다이프로필렌글라이콜;나이아신아마이드;세틸에틸헥사노에이트;카프릴릭/카프릭트라이글리세라이드;캐롭검;아이리쉬모스;아이리쉬모스가루;하이드록시아세토페논;셀룰로오스검;시어버터;카프릴릴글라이콜;포타슘클로라이드;호호바에스터;글리세릴스테아레이트;소듐폴리아크릴레이트;콜라겐(1;100ppm);스테아릴알코올;세틸알코올;솔비탄세스퀴올리에이트;하이드로제네이티드폴리데센;수크로오스;에틸헥실글리세린;소듐스테아로일글루타메이트;해바라기씨왁스;아데노신;부틸렌글라이콜;로즈마리잎오일;트라이데세스-6;C11-13아이소알케인;하이드롤라이즈드치자추출물;폴리글리세린-3;말토덱스트린;라벤더오일;1,2-헥산다이올;다이포타슘글리시리제이트;황련뿌리추출물;글루타티온;하이드롤라이즈드콜라겐(500ppb);구기자추출물;석류추출물;토코페롤;하이드로제네이티드레시틴;수용성콜라겐(100ppb);글루코오스;만노오스;콜라겐추출물(1ppb);다이소듐이디티에이
# 제품명: 핑크 콜라겐 앰플 마스크, 전성분: 정제수;글리세린;부틸렌글라이콜;다이프로필렌글라이콜;1,2-헥산다이올;트레할로오스;베타인;판테놀;하이드록시아세토페논;카보머;알지닌;잔탄검;아미노부티릭애씨드;폴리글리세릴-10라우레이트;아데노신;폴리글리세릴-4라우레이트;다이소듐이디티에이;글리세릴글루코사이드;바나나꽃추출물;다마스크장미꽃수;하이드롤라이즈드익스텐신;서양배추출물;서양자두추출물;멜론추출물;흰목이버섯폴리사카라이드;서양송악잎/줄기추출물;밤부사불가리스잎추출물;아마씨추출물;소듐하이알루로네이트;에틸헥실글리세린;팔미토일트라이펩타이드-1;팔미토일펜타펩타이드-4;헥사펩타이드-9;마그네슘피씨에이;소듐피씨에이;아세틸헥사펩타이드-8;칼슘피씨에이;트라이펩타이드-1;카퍼트라이펩타이드-1
# 제품명: 쿨링 마스크 [시카], 전성분: 정제수;글리세린;1,2-헥산다이올;병풀추출물;영지버섯줄기추출물;다발방패버섯추출물;병풀꽃/잎/줄기추출물;병풀뿌리추출물;병풀잎추출물;소듐하이알루로네이트;베타인;트레할로오스;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;판테놀;폴리글리세릴-10라우레이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;메틸다이아이소프로필프로피온아마이드;트로메타민;글리세릴글루코사이드;다이소듐이디티에이;알란토인;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;효모발효여과물;부틸렌글라이콜;효모발효물;아시아티코사이드;마데카소사이드;마데카식애씨드;아세틸헥사펩타이드-8;아스파틱애씨드;아시아틱애씨드;하이드록시아세토페논;펜틸렌글라이콜
# 제품명: 시카 리페어 판테놀 마스크, 전성분: 정제수;글리세린;나이아신아마이드;세틸에틸헥사노에이트;캐롭검;다이프로필렌글라이콜;아이리쉬모스추출물;1,2-헥산다이올;아이리쉬모스가루;수크로오스;세테아릴올리베이트;하이드록시아세토페논;판테놀(2,000ppm);솔비탄올리베이트;시어버터;포타슘클로라이드;카프릴릭/카프릭트라이글리세라이드;소듐폴리아크릴레이트;알란토인;폴리솔베이트60;하이드로제네이티드폴리데센;아데노신;포도씨오일;부틸렌글라이콜;다이소듐이디티에이;카프릴릴글라이콜;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;콜라겐수;다이포타슘글리시리제이트;트라이데세스-6;콜라겐추출물;마데카소사이드;아시아티코사이드;베타-글루칸;병풀추출물(52,300ppb);아이비고드열매추출물;자일리틸글루코사이드;C11-13아이소알케인;안하이드로자일리톨;호박가루;가지열매추출물;소듐하이알루로네이트;홀리바질잎추출물;울금뿌리추출물;자일리톨;카프릴로일살리실릭애씨드;폴리글리세릴-4카프레이트;하이드로제네이티드레시틴;토코페롤;참산호말추출물;드럼스틱씨오일;스테아릭애씨드;소듐디엔에이;대왕송잎추출물;당느릅나무뿌리추출물;달맞이꽃추출물;칡뿌리추출물;하이드롤라이즈드하이알루로닉애씨드;에틸헥실글리세린;소듐아세틸레이티드하이알루로네이트;폴리글리세릴-10라우레이트;트라이펩타이드-1;팔미토일트라이펩타이드-1;팔미토일펜타펩타이드-4;헥사펩타이드-9;아세틸헥사펩타이드-8;카퍼트라이펩타이드-1
# 제품명: 슈퍼 콜라겐 마스크, 전성분: 정제수;글리세린;다이프로필렌글라이콜;세틸에틸헥사노에이트;나이아신아마이드;캐롭검;1,2-헥산다이올;하이드롤라이즈드콜라겐(5,000ppm);아텔로콜라겐;콜라겐추출물;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;인삼뿌리프로토플라스트;에델바이스캘러스배양추출물;레티놀;하이알루로닉애씨드;팔미토일트라이펩타이드-5;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;카퍼트라이펩타이드-1;다이펩타이드-2;올리고펩타이드-1;팔미토일펜타펩타이드-4;트라이펩타이드-1;아데노신;인체제대혈세포배양액(30ppm);하이드록시아세토페논;아이리쉬모스추출물;아이리쉬모스;베타인;판테놀;트레할로오스;셀룰로오스검;시어버터;글리세릴스테아레이트;소듐폴리아크릴레이트;피이지-100스테아레이트;폴리솔베이트60;잔탄검;포타슘클로라이드;하이드로제네이티드폴리데센;수크로오스;다이소듐이디티에이;에틸헥실글리세린;트라이데세스-6;레시틴;하이드롤라이즈드치자추출물;하이드로제네이티드레시틴;말토덱스트린;부틸렌글라이콜;돌콩오일;토코페롤;콜레스테롤;소듐시트레이트;세린;알진;향료
# 제품명: 자작나무 수분 선크림, 전성분: 정제수;다이부틸아디페이트;프로판다이올;디에칠아미노하이드록시벤조일헥실벤조에이트;폴리메틸실세스퀴옥세인;에칠헥실트리아존;나이아신아마이드;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;카프릴릴메티콘;디에칠헥실부타미도트리아존;글리세린;1,2-헥산다이올;부틸렌글라이콜;자작나무수액(1,425ppm);소듐하이알루로네이트;하이알루로닉애씨드;글리세릴글루코사이드;다이포타슘글리시리제이트;알란토인;쇠비름추출물;개똥쑥추출물;구주소나무잎오일;캐모마일꽃오일;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;아스코빅애씨드;아데노신;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;잔탄검;t-부틸알코올;토코페롤;카보머
# 제품명: 히알루론산 프레쉬 선 세럼, 전성분: 정제수;다이부틸아디페이트;프로판다이올;부틸옥틸살리실레이트;에칠헥실트리아존;나이아신아마이드;드로메트리졸트리실록세인;폴리글리세릴-3다이스타이레이트;테레프탈릴리덴다이캠퍼설포닉애씨드;폴리메틸실세스퀴옥세인;디에칠아미노하이드록시벤조일헥실벤조에이트;트로메타민;판테놀;1,2-헥산다이올;펜틸렌글라이콜;글리세릴스테아레이트;실리카;카프릴릴메티콘;비스-에칠헥실옥시페놀메톡시페닐트리아진;포타슘세틸포스페이트;락토바실러스발효물;폴리C10-30알킬아크릴레이트;메틸프로판다이올;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;에틸헥실글리세린;하이드롤라이즈드소듐하이알루로네이트;잔탄검;아데노신;폴리터-1;소듐하이알루로네이트;바이오사카라이드검-1;스쿠알란;알란토인;에이서리톨;토코페롤;엑토인;하이드록시프로필트라이모늄하이알루로네이트;징크하이드롤라이즈드하이알루로네이트;글리세린;부틸렌글라이콜;약모밀추출물;시트릭애씨드;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이드로제네이티드레시틴;하이알루로닉애씨드;폴리글리세릴-10스테아레이트;병풀추출물;소듐하이알루로네이트크로스폴리머;소듐아스코빌포스페이트;토코페릴아세테이트;코코넛야자수;포타슘하이알루로네이트;레티닐팔미테이트;바이오틴;티아민에이치씨엘;폴릭애씨드;피리독신;사이아노코발아민
# 제품명: 워터풀 선크림 [에센스], 전성분: 정제수;사이클로펜타실록세인;티타늄디옥사이드;에칠헥실메톡시신나메이트;다이프로필렌글라이콜;세틸에틸헥사노에이트;세틸피이지/피피지-10/1다이메티콘;부틸렌글라이콜;에칠헥실살리실레이트;실리카;1,2-헥산다이올;카프릴릴메티콘;나이아신아마이드;옥토크릴렌;라우릴피이지-9폴리다이메틸실록시에틸다이메티콘;사이클로헥사실록세인;글리세린;비스-에칠헥실옥시페놀메톡시페닐트리아진;다이스테아다이모늄헥토라이트;폴리페닐실세스퀴옥세인;소듐클로라이드;카나우바왁스;황색산화철;트라이메틸실록시실리케이트;스테아릭애씨드;아크릴레이트/스테아릴아크릴레이트/다이메티콘메타크릴레이트코폴리머;다이아이소스테아릴말레이트;팔미틱애씨드;알루미늄하이드록사이드;글리세릴카프릴레이트;적색산화철;트라이에톡시카프릴릴실레인;향료;흑색산화철;알란토인;다이메티콘/비닐다이메티콘크로스폴리머;아데노신;다이메티콘;다이소듐이디티에이;소듐하이알루로네이트;글루타티온;토코페롤;하이드롤라이즈드콜라겐;카프릴릭/카프릭트라이글리세라이드;에탄올;약모밀추출물;하이드로제네이티드레시틴;복사나무꽃추출물;소듐스테아로일글루타메이트;하이알루로닉애씨드;아스코빅애씨드
# 제품명: 맑은 어성초 진정 수분 선크림, 전성분: 정제수;다이부틸아디페이트;프로판다이올;폴리메틸실세스퀴옥세인;다이아이소프로필세바케이트;디에칠아미노하이드록시벤조일헥실벤조에이트;에칠헥실트리아존;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;디에칠헥실부타미도트리아존;부틸렌글라이콜;글리세린;1,2-헥산다이올;카프릴릴메티콘;약모밀추출물;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;잔탄검;t-부틸알코올;토코페롤
# 제품명: 릴리프 하이드레이션 라이트 썬스크린, 전성분: 정제수;다이부틸아디페이트;프로판다이올;다이에틸아미노하이드록시벤조일헥실벤조에이트;폴리메틸실세스퀴옥세인;에틸헥실트리아존;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;카프릴릴메티콘;디에칠헥실부타미도트리아존;1,2-헥산다이올;글리세린;부틸렌글라이콜;병풀추출물;삼나무잎추출물;연꽃잎추출물;세라마이드엔피;세라마이드에이에스;세라마이드에이피;세라마이드엔에스;세라마이드이오피;마데카소사이드;마데카식애씨드;아시아티코사이드;아시아틱애씨드;티트리추출물;병풀뿌리추출물;병풀잎추출물;하이드로제네이티드레시틴;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;다이프로필렌글라이콜;잔탄검;글리세릴스테아레이트;효모발효여과물;t-부틸알코올;콜레스테롤;토코페롤;효모발효물
# 제품명: 다이브인 무기자차 마일드 선크림, 전성분: 정제수;징크옥사이드;사이클로헥사실록세인;부틸옥틸살리실레이트;프로필헵틸카프릴레이트;프로판다이올;다이카프릴릴카보네이트;아이소도데케인;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;카프릴릴메티콘;소듐하이알루로네이트;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;다이메틸실란올하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;소듐하이알루로네이트다이메틸실란올;판테놀;알란토인;트레할로오스;세라마이드엔피;버지니아풍년화추출물;쇠비름추출물;캐모마일꽃추출물;호호바씨오일;2,3-부탄다이올;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;메틸메타크릴레이트크로스폴리머;폴리글리세릴-2다이폴리하이드록시스테아레이트;라우릴폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;글리세릴카프릴레이트;카프릴릴글라이콜;부틸렌글라이콜;토코페롤;에틸헥실글리세린;1,2-헥산다이올;인도멀구슬나무잎추출물;인도멀구슬나무꽃추출물;아이비고드열매추출물;가지열매추출물;알로에베라꽃추출물;울금뿌리추출물;참산호말추출물;홀리바질잎추출물;녹차추출물;말라카이트추출물
# 제품명: 그린 마일드 업 선 플러스, 전성분: 정제수;징크옥사이드;프로판다이올;부틸옥틸살리실레이트;프로필헵틸카프릴레이트;코코-카프릴레이트/카프레이트;사이클로헥사실록세인;카프릴릴메티콘;아이소도데케인;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;메틸트라이메티콘;메틸메타크릴레이트크로스폴리머;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;1,2-헥산다이올;폴리글리세릴-2다이폴리하이드록시스테아레이트;라우릴폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;폴리메틸실세스퀴옥세인;글리세릴카프릴레이트;카프릴릴글라이콜;에틸헥실글리세린;소듐하이알루로네이트;부틸렌글라이콜;토코페롤;병풀추출물;타라열매추출물;프랑스해안송껍질추출물;코토니추출물;7-데하이드로콜레스테롤;약모밀추출물;엑토인;밀몽화꽃추출물;락토바실러스발효물;하이드록시신나믹애씨드;루틴
# 제품명: 마다가스카르 센텔라 히알루-시카 워터핏 선 세럼, 전성분: 정제수;다이부틸아디페이트;프로판다이올;다이에틸아미노하이드록시벤조일헥실벤조에이트;폴리메틸실세스퀴옥세인;에틸헥실트리아존;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;나이아신아마이드;코코-카프릴레이트/카프레이트;카프릴릴메티콘;디에칠헥실부타미도트리아존;글리세린;1,2-헥산다이올;부틸렌글라이콜;병풀추출물;자작나무껍질추출물;은행나무잎추출물;녹차추출물;밀싹추출물;자주개자리추출물;브로콜리싹추출물;로켓잎추출물;동백나무잎추출물;소듐하이알루로네이트;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;아데노신;잔탄검;t-부틸알코올;토코페롤;하이드롤라이즈드하이알루로닉애씨드;이노시톨;하이알루로닉애씨드;펜틸렌글라이콜;에틸헥실글리세린
# 제품명: 선뮤즈 모이스처 선크림, 전성분: 정제수;다이부틸아디페이트;프로판다이올;폴리메틸실세스퀴옥세인;다이아이소프로필세바케이트;디에칠아미노하이드록시벤조일헥실벤조에이트;에칠헥실트리아존;나이아신아마이드;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;코코-카프릴레이트/카프레이트;디에칠헥실부타미도트리아존;글리세린;1,2-헥산다이올;부틸렌글라이콜;카프릴릴메티콘;펜틸렌글라이콜;베헤닐알코올;폴리C10-30알킬아크릴레이트;폴리글리세릴-3메틸글루코오스다이스테아레이트;데실글루코사이드;트로메타민;카보머;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;소듐스테아로일글루타메이트;폴리아크릴레이트크로스폴리머-6;에틸헥실글리세린;아데노신;잔탄검;t-부틸알코올;토코페롤
# 제품명: 마데카소사이드 수분 선세럼 흔적 리페어, 전성분: 정제수;다이부틸아디페이트;프로판다이올;부틸옥틸살리실레이트;에칠헥실트리아존;메틸메타크릴레이트크로스폴리머;비스-에칠헥실옥시페놀메톡시페닐트리아진;옥토크릴렌;나이아신아마이드;테레프탈릴리덴디캠퍼설포닉애씨드;알지닌;다이메티콘올;메틸프로판다이올;폴리메틸실세스퀴옥세인;1,2-헥산다이올;펜틸렌글라이콜;C11-13아이소알케인;하이드록시에틸우레아;부틸렌글라이콜;베헤닐알코올;폴리글리세릴-3메틸글루코오스다이스테아레이트;다이프로필렌글라이콜;카보머;아이소도데케인;폴리C10-30알킬아크릴레이트;다이메티콘/비닐다이메티콘크로스폴리머;폴리에터-1;스핑고모나스발효추출물;에틸헥실글리세린;병풀잎추출물;아데노신;서양배추출물;소듐스테아로일글루타메이트;연필향나무오일;마데카소사이드;소듐하이알루로네이트;다마스크장미꽃수;멜론추출물;오리스뿌리추출물;서양송악잎/줄기추출물;호호바씨오일;광곽향오일;불가리스쑥오일;마이크로크리스탈린셀룰로오스;로즈마리잎오일;병풀추출물;셀룰로오스검;토코페롤;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;사과추출물;에리스리톨;글리세린;판테놀;솔비톨;보검선인장줄기추출물;마데카식애씨드;아시아틱애씨드;아시아티코사이드;효모발효여과물;바이오사카라이드검-4;다이소듐포스페이트;다발방패버섯추출물
# 제품명: 덕만이 무기차자 썬크림, 전성분: 정제수;징크옥사이드(17%);프로필헵틸카프릴레이트;부틸옥틸살리실레이트;프로판다이올;코코-카프릴레이트/카프레이트;카프릴릴메티콘;아이소도데케인;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;메틸트라이메티콘;메틸메타크릴레이트크로스폴리머;밤부사불가리스추출물;병풀추출물;약모밀추출물;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;소듐아세틸레이티드하이알루로네이트;자작나무수액;판테놀;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;1,2-헥산다이올;폴리글리세릴-2다이폴리하이드록시스테아레이트;라우릴폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;폴리메틸실세스퀴옥세인;글리세릴카프릴레이트;카프릴릴글라이콜;에틸헥실글리세린;토코페롤;부틸렌글라이콜;펜틸렌글라이콜
# 제품명: 바이옴 레미디 톤업 선크림 [보라], 전성분: 정제수;다이부틸아디페이트;부틸옥틸살리실레이트;에칠헥실트리아존;프로판다이올;메칠렌비스-벤조트리아졸릴테트라메칠부틸페놀;메틸프로판다이올;나이아신아마이드;디에칠아미노하이드록시벤조일헥실벤조에이트;티타늄디옥사이드(CI77891);1,2-헥산다이올;비스-에칠헥실옥시페놀메톡시페닐트리아진;폴리글리세릴-3메틸글루코오스다이스테아레이트;폴리글리세릴-3다이스테아레이트;울트라마린;코코-카프릴레이트/카프레이트;데실글루코사이드;폴리아크릴레이트크로스폴리머-6;세테아릴알코올;암모늄아크릴로일다이메틸타우레이트/브이피코폴리머;브이피/에이코신코폴리머;소듐폴리아크릴로일다이메틸타우레이트;에틸헥실글리세린;글리세릴스테아레이트시트레이트;카올린;폴리글리세릴-6폴리하이드록시스테아레이트;알루미늄하이드록사이드;폴리글리세릴-6폴리리시놀리에이트;아데노신;트라이에톡시카프릴릴실레인;소듐스테아로일글루타메이트;글리세린;적색산화철;잔탄검;쿠티박테리움그라눌로숨발효추출여과물(100ppm);폴리글리세린-6;판테놀;석시닉애씨드;토코페롤;아스코빌팔미테이트
# 제품명: 썬스크린 [레이저UV], 전성분: 정제수;징크옥사이드;다이부틸아디페이트;사이클로헥사실록세인;프로필헵틸카프릴레이트;다이프로필렌글라이콜;부틸옥틸살리실레이트;폴리글리세릴-4다이아이소스테아레이트/폴리하이드록시스테아레이트/세바케이트;나이아신아마이드;칼슘알루미늄보로실리케이트;디에칠아미노하이드록시벤조일헥실벤조에이트;메틸메타크릴레이트크로스폴리머;비스-에칠헥실옥시페놀메톡시페닐트리아진;에칠헥실트리아존;폴리글리세릴-3폴리다이메틸실록시에틸다이메티콘;티타늄디옥사이드;다이스테아다이모늄헥토라이트;마그네슘설페이트;트라이에톡시카프릴릴실레인;1,2-헥산다이올;폴리메틸실세스퀴옥세인;글리세릴카프릴레이트;카프릴릴글라이콜;에틸헥실글리세린;아데노신;토코페롤;카르노신;트라이메틸실록시실리케이트;하이드롤라이즈드콜라겐;향료
# 제품명: 올 데이 에어리 선크림, 전성분: 정제수;다이부틸아디페이트;부틸옥틸살리실레이트;디에칠아미노하이드록시벤조일헥실벤조에이트;폴리실리콘-15;C12-15알킬벤조에이트;에칠헥실트리아존;비스-에칠헥실옥시페놀메톡시페닐트리아진;폴리메틸실세스퀴옥세인;글리세린;나이아신아마이드;폴리글리세릴-6스테아레이트;세테아릴올리베이트;마이크로크리스탈린셀룰로오스;판테놀;실리카;솔비탄올리베이트;다이프로필렌글라이콜;하이드록시아세토페논;폴리C10-30알킬아크릴레이트;폴리글리세릴-6베헤네이트;알란토인;카프릴릴글라이콜;스테아릴알코올;글리세릴스테아레이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;아데노신;세테아릴알코올;다이소듐이디티에이;부틸렌글라이콜;쇠비름추출물;알로에베라잎추출물;참마뿌리추출물;다시마추출물;제비꽃꽃추출물;당느릅나무뿌리추출물;다이포타슘글리시리제이트;마카뿌리추출물;1,2-헥산다이올;구기자추출물;비치스트로베리추출물;불가리스매자뿌리추출물;검은뽕나무열매추출물
# --- 위 목록과 사용자 정보를 바탕으로 제품을 추천해주세요. ---
#
# AI: 안녕하세요! 건성 피부를 위한 보습 효과가 뛰어난 제품을 찾고 계시군요. 다음과 같은 제품들을 추천드립니다:
#
# 1. **판테놀 베리어 토너**: 이 제품은 판테놀과 세라마이드 성분이 포함되어 있어 피부 장벽 강화 및 깊은 보습을 제공하여 건성 피부에 적합합니다.
#
# 2. **다이브인 저분자 히알루론산 크림**: 저분자 히알루론산이 다량 함유되어 있어 건성 피부에 충분한 수분을 공급하고, 다양한 식물 추출물들이 피부를 진정시켜 줍니다.
#
# 3. **아쿠아 스쿠알란 수분크림**: 스쿠알란과 하이알루론산 복합체가 피부에 수분을 공급하고, 피부를 부드럽고 탄력 있게 가꿔줍니다.
#
# 4. **하이드라 셀 부스팅 토너**: 이 토너는 수분 공급에 탁월하며, 피부에 빠르게 흡수되어 촉촉함을 유지하는 데 도움이 됩니다.
#
# 이 제품들은 모두 보습력이 뛰어나고 건성 피부에 최적화되어 있으며, 피부 장벽을 강화하는 성분이 포함되어 있어 피부를 건강하고 촉촉하게 유지하는 데 큰 도움이 될 것입니다. 사용 전 패치 테스트를 권장드리며, 자신의 피부 상태에 맞게 사용하시길 바랍니다. 도움이 필요하시면 언제든지 말씀해 주세요!
# Human: 그럼 로션 제품만 추천해 줄 수 있어 ?
# AI: 물론입니다! 건성 피부에 적합한 보습 로션 제품을 추천드리겠습니다. 다음 제품들을 고려해 보세요:
#
# 1. **판테놀 베리어 에멀전**: 이 제품은 판테놀과 세라마이드 성분이 포함되어 있어 피부 장벽을 강화하고 깊은 보습을 제공합니다. 건성 피부에 수분을 공급하여 촉촉한 피부를 유지할 수 있습니다.
#
# 2. **아토베리어365 로션**: 스쿠알란과 하이알루론산이 함유되어 있어 피부에 수분을 공급하고, 보습막을 형성하여 오랜 시간 촉촉함을 유지합니다.
#
# 3. **MLE 로션**: 이 로션은 세라마이드 및 다양한 식물성 오일이 함유되어 있어 피부에 영양과 수분을 공급하고, 피부 장벽을 강화합니다.
#
# 4. **더 심플 데일리 로션**: 알로에베라잎즙과 마데카소사이드 성분이 피부를 진정시키고 보습에 도움을 줍니다. 가벼운 사용감으로 데일리 케어에 적합합니다.
#
# 이 제품들은 모두 건성 피부를 위한 보습 효과가 뛰어나며, 피부 장벽을 보호하고 수분을 유지하는 데 도움을 줍니다. 사용 전 패치 테스트를 권장드리며, 자신의 피부 상태에 맞게 선택하여 사용하시길 바랍니다. 추가적인 질문이 있으시면 언제든지 말씀해 주세요!
#
# 사용자의 현재 질문: 근데 내 친구는 지성 피부야. 보습에 좋은 앰플 추천해줘 !
# 전문가로서 답변해주세요.
#
#
# > Finished chain.
# 챗봇: 안녕하세요! 지성 피부를 위한 보습 앰플을 찾고 계시군요. 지성 피부는 유분이 많지만 수분이 부족할 수 있기 때문에, 수분 공급은 중요합니다. 다음과 같은 앰플을 추천드립니다:
#
# 1. **리얼 히알루로닉 블루 100 앰플**: 이 앰플은 다양한 형태의 히알루론산을 함유하고 있어 피부에 깊은 수분을 공급합니다. 가볍고 산뜻한 사용감으로 지성 피부에 적합합니다.
#
# 2. **아쿠아 스쿠알란 세럼**: 스쿠알란과 하이알루론산 복합체가 포함되어 있어 피부에 수분을 공급하고, 가벼운 사용감으로 끈적임 없이 흡수됩니다.
#
# 3. **다이브인 저분자 히알루론산 세럼**: 저분자 히알루론산이 피부 깊숙이 수분을 전달하며, 지성 피부에도 부담 없이 사용할 수 있는 산뜻한 제형입니다.
#
# 4. **베리어덤 링거 앰플**: 이 앰플은 수분 공급과 피부 장벽 강화에 도움을 주는 성분들이 함유되어 있으며, 지성 피부에도 잘 맞는 촉촉한 마무리감을 제공합니다.
#
# 이 제품들은 모두 지성 피부에 수분을 공급하면서도 가벼운 사용감을 제공하여 부담 없이 사용할 수 있습니다. 사용 전 패치 테스트를 권장드리며, 친구의 피부 상태에 맞게 선택하여 사용하시길 바랍니다. 추가적인 질문이 있으시면 언제든지 말씀해 주세요!
# 챗봇을 종료합니다. 이용해주셔서 감사합니다.

# %%
import csv
import os
from langchain_openai import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate

# --- 사전 준비: OpenAI API 키 설정 ---
if not os.getenv("OPENAI_API_KEY"):
    print("="*60)
    print("경고: OPENAI_API_KEY 환경 변수가 설정되지 않았습니다.")
    # exit()

# --- 사용자 정보 입력 함수 ---
def get_user_selections():
    """
    사용자로부터 피부 타입, 피부 고민, 제품 종류를 입력받는 함수
    """
    skin_types = {1: '민감성', 2: '지성', 3: '건성', 4: '아토피성'}
    concerns = {1: '보습', 2: '진정', 3: '미백', 4: '주름/탄력', 5: '모공케어', 6: '피지조절'}
    categories = {
        1: '스킨/토너', 2: '로션/에멀젼', 3: '에센스/앰플/세럼', 4: '크림',
        5: '밤/멀티밤', 6: '클렌징 폼', 7: '시트마스크', 8: '선크림/로션'
    }

    print("--- 당신에게 꼭 맞는 화장품을 찾아드립니다! ---")
    
    # 피부 타입 선택
    print("\n✅ 당신의 피부 타입을 알려주세요:")
    for key, value in skin_types.items(): print(f"  {key}. {value}")
    while True:
        try:
            choice = int(input(">> 번호를 입력하세요: "))
            if choice in skin_types:
                selected_skin_type = skin_types[choice]; break
            else: print("⚠️ 잘못된 번호입니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자로만 입력해주세요.")

    # 피부 고민 선택 (다중 선택 가능)
    print("\n✅ 어떤 피부 고민을 해결하고 싶으신가요? (여러 개 선택 시 쉼표(,)로 구분)")
    for key, value in concerns.items(): print(f"  {key}. {value}")
    while True:
        try:
            choices_str = input(">> 번호들을 입력하세요 (예: 1, 4): ")
            selected_concern_keys = [int(c.strip()) for c in choices_str.split(',')]
            if all(key in concerns for key in selected_concern_keys):
                selected_concerns = [concerns[key] for key in selected_concern_keys]; break
            else: print("⚠️ 목록에 없는 번호가 포함되어 있습니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자와 쉼표(,)로만 올바르게 입력해주세요.")

    # 제품 종류 선택
    print("\n✅ 어떤 종류의 제품을 찾으시나요?")
    for key, value in categories.items(): print(f"  {key}. {value}")
    while True:
        try:
            choice = int(input(">> 번호를 입력하세요: "))
            if choice in categories:
                selected_category = categories[choice]; break
            else: print("⚠️ 잘못된 번호입니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자로만 입력해주세요.")
            
    return selected_skin_type, selected_concerns, selected_category

# --- 데이터베이스에서 제품 정보 가져오기 (전성분 포함으로 복구) ---
def find_all_products(filepath, target_concerns, target_category):
    """CSV 파일에서 여러 고민과 특정 카테고리에 맞는 '모든' 제품을 찾아 반환합니다."""
    found_products = []
    with open(filepath, mode='r', encoding='utf-8-sig') as infile:
        reader = csv.DictReader(infile)
        for row in reader:
            # 1. 카테고리가 일치하는지 확인
            if row.get('카테고리') == target_category:
                # 2. 사용자가 선택한 고민 중 하나라도 포함하는지 확인
                product_efficacies = row.get('효능', '')
                if any(concern in product_efficacies for concern in target_concerns):
                    # LLM의 분석을 위해 '전성분' 정보를 다시 포함시킵니다.
                    product_info = {
                        "name": row.get('제품명', 'N/A'),
                        "ingredients": row.get('전성분', 'N/A')
                    }
                    found_products.append(product_info)
    return found_products

# --- LangChain 설정 (기존과 동일) ---
llm = ChatOpenAI(model_name="gpt-4o", temperature=0.7)
memory = ConversationBufferMemory(memory_key="history")
template = """
당신은 친절하고 전문적인 화장품 추천 전문가입니다.
사용자와의 이전 대화 내용은 아래와 같습니다.

{history}

사용자의 현재 질문: {input}
전문가로서 답변해주세요.
"""
prompt = PromptTemplate(input_variables=["history", "input"], template=template)
conversation = ConversationChain(llm=llm, memory=memory, prompt=prompt, verbose=True)

# --- 메인 챗봇 실행 로직 (프롬프트 수정) ---
def run_chat():
    # 1. 사용자로부터 구조화된 정보 입력받기
    skin_type, concerns, category = get_user_selections()
    print("\n🔍 좋습니다! 입력하신 정보를 바탕으로 최적의 제품을 찾고 있습니다...")

    # 2. 입력받은 정보를 바탕으로 CSV에서 관련 제품 필터링
    products = find_all_products('product_data.csv', concerns, category)
    
    product_context = ""
    if products:
        # LLM에게 '전성분' 정보를 전달하고, 답변 형식에 대한 명확한 지시사항 추가
        product_context += f"\n\n--- 참고: '{category}' 제품 중 '{', '.join(concerns)}' 고민 관련 제품 목록 ---\n"
        for p in products:
            product_context += f"제품명: {p['name']}, 전성분: {p['ingredients']}\n"
        product_context += """---
        위 목록과 사용자 정보를 바탕으로, 각 제품의 '전성분'을 면밀히 분석하여 사용자에게 가장 적합한 제품 2~3개를 추천해주세요.
        최종 답변에는 제품명, 추천 이유, 그리고 사용자 피부 타입에 유의해야 할 핵심 성분(있을 경우에만)만 간결하게 포함해주세요.
        절대로 '전성분' 전체 목록을 답변에 보여주지 마세요.
        ---"""
    else:
        product_context = "\n\n--- 참고: 아쉽게도 조건에 맞는 제품을 찾지 못했습니다. 이 점을 사용자에게 알리고 대화를 시작해주세요. ---\n"

    # 3. 필터링된 정보와 사용자 정보를 조합하여 첫 질문 생성
    initial_input = f"제 피부타입은 '{skin_type}'이고, 고민은 '{', '.join(concerns)}'입니다. '{category}' 종류 중에서 좋은 제품을 추천해주세요."
    full_input = initial_input + product_context

    # 4. 대화 체인에 첫 질문 전달 및 대화 시작
    print("\n💬 챗봇이 분석 중입니다. 잠시만 기다려주세요...")
    response = conversation.predict(input=full_input)
    print(f"\n챗봇: {response}")

    # 5. 후속 질문을 위한 대화 루프 시작
    print("\n--- 추가 질문이 있으시면 편하게 입력해주세요. (종료: '종료') ---")
    while True:
        user_input = input("당신: ")
        if user_input.lower() == '종료':
            print("챗봇을 종료합니다. 이용해주셔서 감사합니다.")
            break
        
        response = conversation.predict(input=user_input)
        print(f"챗봇: {response}")

if __name__ == '__main__':
    run_chat()
# Out:
# --- 당신에게 꼭 맞는 화장품을 찾아드립니다! ---
#
# ✅ 당신의 피부 타입을 알려주세요:
#   1. 민감성
#   2. 지성
#   3. 건성
#   4. 아토피성
#
# ✅ 어떤 피부 고민을 해결하고 싶으신가요? (여러 개 선택 시 쉼표(,)로 구분)
#   1. 보습
#   2. 진정
#   3. 미백
#   4. 주름/탄력
#   5. 모공케어
#   6. 피지조절
#
# ✅ 어떤 종류의 제품을 찾으시나요?
#   1. 스킨/토너
#   2. 로션/에멀젼
#   3. 에센스/앰플/세럼
#   4. 크림
#   5. 밤/멀티밤
#   6. 클렌징 폼
#   7. 시트마스크
#   8. 선크림/로션
#
# 🔍 좋습니다! 입력하신 정보를 바탕으로 최적의 제품을 찾고 있습니다...
#
# 💬 챗봇이 분석 중입니다. 잠시만 기다려주세요...
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
#
# 당신은 친절하고 전문적인 화장품 추천 전문가입니다.
# 사용자와의 이전 대화 내용은 아래와 같습니다.
#
#
#
# 사용자의 현재 질문: 제 피부타입은 '건성'이고, 고민은 '보습'입니다. '스킨/토너' 종류 중에서 좋은 제품을 추천해주세요.
#
# --- 참고: '스킨/토너' 제품 중 '보습' 고민 관련 제품 목록 ---
# 제품명: 아쿠아 오아시스 토너, 전성분: 정제수;다이프로필렌글라이콜;부틸렌글라이콜;글리세린;1,2-헥산다이올;베타인;판테놀;알란토인;파파야열매추출물;글루코노락톤;자일리틸글루코사이드;안하이드로자일리톨;자일리톨;소듐하이알루로네이트;글루코오스;파파인;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;글리세릴아크릴레이트/아크릴릭애씨드코폴리머;피브이엠/엠에이코폴리머
# 제품명: 1025 독도 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;펜틸렌글라이콜;프로판다이올;아이리쉬모스추출물;사탕수수추출물;해수;1,2-헥산다이올;프로테아제;베타인;판테놀;에틸헥실글리세린;알란토인;잔탄검;다이소듐이디티에이
# 제품명: 원더 세라마이드 모찌 토너, 전성분: 정제수;다이프로필렌글라이콜;글리세린;펜타에리스리틸테트라아이소스테아레이트;글리세레스-26;1,2-헥산다이올;마카다미아씨오일(구명칭);페닐트라이메티콘;하이드록시에틸아크릴레이트/소듐아크릴로일다이메틸타우레이트코폴리머;스타이렌/브이피코폴리머;에틸헥실글리세린;병풀추출물;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;카프릴릭/카프릭트라이글리세라이드;알란토인;하이드로제네이티드레시틴;프로판다이올;판테놀;피토스테릴/옥틸도데실라우로일글루타메이트;세라마이드엔피;소듐하이알루로네이트;로즈우드오일;레몬껍질오일;다이소듐이디티에이;리날룰;리모넨
# 제품명: 다이브인 저분자 히알루론산 토너, 전성분: 정제수;부틸렌글라이콜;다이프로필렌글라이콜;1,2-헥산다이올;글리세린;베타인;알란토인;판테놀;쇠비름추출물;트레할로오스;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드(100ppm);소듐하이알루로네이트크로스폴리머;하이드롤라이즈드소듐하이알루로네이트;소듐아세틸레이티드하이알루로네이트;2,3-부탄다이올;펜틸렌글라이콜;말라카이트추출물;다이소듐이디티에이;에틸헥실글리세린
# 제품명: 초저분자 히아루론산 토너, 전성분: 정제수;메틸프로판다이올;1,2-헥산다이올;해수;글리세린;베타인;알란토인;부틸렌글라이콜;카프릴릴글라이콜;에틸헥실글리세린;판테놀;잔탄검;말라카이트추출물;다이소듐이디티에이;하이드롤라이즈드하이알루로닉애씨드;펜틸렌글라이콜;자일리틸글루코사이드;안하이드로자일리톨;소듐하이알루로네이트;자일리톨;포타슘하이알루로네이트;글루코오스;다이메틸실란올하이알루로네이트;소듐아세틸레이티드하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드록시프로필트라이모늄하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드칼슘하이알루로네이트;하이알루로닉애씨드;버지니아풍년화추출물;소듐설페이티드하이알루로네이트;편백잎추출물;소듐스테아로일하이알루로네이트;소듐올레오일하이알루로네이트
# 제품명: 판테놀 베리어 토너, 전성분: 정제수;부틸렌글라이콜;판테놀;다이프로필렌글라이콜;글리세레스-26;나이아신아마이드;1,2-헥산다이올;카카두플럼추출물;병풀추출물;아시아티코사이드;마데카소사이드;세라마이드엔피;얼룩파인애플추출물;파파야열매추출물;귀리가루추출물;락토바실러스/콩발효추출물;락토바실러스/쌀발효물;락토바실러스/인삼뿌리발효여과물;효모/율무씨발효여과물;효모/감자추출물발효여과물;소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;동백나무씨오일;아시아틱애씨드;마데카식애씨드;리놀레익애씨드;락토바이오닉애씨드;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;하이드로제네이티드레시틴;프로판다이올;소듐시트레이트;베타인;글리세린;시트릭애씨드;소듐폴리아크릴로일다이메틸타우레이트;하이드록시프로필트라이모늄하이알루로네이트;아데노신;펜틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;에틸헥실글리세린
# 제품명: 올리고 히알루론산 딥 토너, 전성분: 정제수;부틸렌글라이콜;1,2-헥산다이올;글리세린;베타-글루칸;베타인;소듐하이알루로네이트(2,700ppm);판테놀;솔비톨;아세틸글루코사민;글루쿠로닉애씨드;알란토인;토코페롤;에틸헥실글리세린;다이소듐이디티에이
# 제품명: 하이드라 셀 부스팅 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;1,2-헥산다이올;하이드록시아세토페논;알란토인;카보머;알지닌;다이소듐이디티에이;녹차추출물;소듐하이알루로네이트;나이아신아마이드;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드글라이코사미노글리칸;리보플라빈;폴릭애씨드;판테놀;메나다이온;소듐하이알루로네이트크로스폴리머;소듐아세틸레이티드하이알루로네이트;다이메틸실란올하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;바이오틴;사이아노코발아민;아스코빅애씨드;티아민에이치씨엘;피리독신;바이오플라보노이드
# 제품명: 무알콜 뮤신 에센스 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;판테놀;1,2-헥산다이올;와일드얌뿌리추출물(7395ppm);카보머;알지닌;병풀잎수;펜틸렌글라이콜;소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드롤라이즈드하이알루로닉애씨드;에틸헥실글리세린;하이알루로닉애씨드;하이드롤라이즈드소듐하이알루로네이트
# 제품명: 어성초 77 수딩 토너, 전성분: 약모밀꽃/잎/줄기수(77%);정제수;1,2-헥산다이올;글리세린;베타인;부틸렌글라이콜;아이소펜틸다이올;판테놀;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;트로메타민;병풀추출물;우엉뿌리추출물;진흙버섯추출물;쇠비름추출물;마트리카리아꽃추출물;체이스트트리추출물;소듐하이알루로네이트;하이드록시프로필트라이모늄하이알루로네이트;소듐아세틸레이티드하이알루로네이트;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드;소듐하이알루로네이트크로스폴리머;포타슘하이알루로네이트;다이소듐이디티에이
# 제품명: 어성초 진정해 수분 토너, 전성분: 정제수;약모밀추출물;부틸렌글라이콜;다이프로필렌글라이콜;프로판다이올;1,2-헥산다이올;글리세린;하이드록시아세토페논;에틸헥실글리세린;카프릴릴글라이콜;폴리글리세릴-10라우레이트;폴리글리세릴-4라우레이트;카보머;알란토인;다이포타슘글리시리제이트;소듐파이테이트;소듐하이알루로네이트;병풀잎추출물;알지닌;살비아오일;마데카소사이드;제올라이트;루이보스잎추출물;마조람잎추출물;서양측백나무잎추출물;티트리잎추출물;로즈마리잎추출물;병풀추출물;살비아잎추출물;타임추출물;레몬밤잎추출물;히솝추출물;티트리추출물;작약뿌리추출물;녹차추출물
# 제품명: 나인 토너, 전성분: 정제수;글리세린;2,3-부탄다이올;판테놀;다이프로필렌글라이콜;1,2-헥산다이올;하이드록시아세토페논;에리스리톨;베타인;트레할로오스;알란토인;에틸헥실글리세린;소듐하이알루로네이트;아크릴레이트/C10-30알킬아크릴레이트크로스폴리머;알지닌;다이소듐이디티에이;쑥위추출물;부틸렌글라이콜;포타슘하이알루로네이트;하이드롤라이즈드소듐하이알루로네이트;로즈마리잎추출물;자작나무수액;트루로즈오브예리코추출물;하이드롤라이즈드하이알루로닉애씨드;하이알루로닉애씨드
# 제품명: 비피다 바이옴 앰플 토너, 전성분: 정제수;부틸렌글라이콜;글리세린;프로판다이올;펜틸렌글라이콜;버지니아풍년화수;락토바실러스발효용해물;락토코쿠스발효용해물;락토바실러스/호박발효추출물;효모발효여과물;베타인;알란토인;판테놀;세라마이드엔피;하이알루로닉애씨드;하이드롤라이즈드하이알루로닉애씨드;하이드롤라이즈드글라이코사미노글리칸;소듐하이알루로네이트;소듐하이알루로네이트크로스폴리머;하이드로제네이티드레시틴;비피다발효여과물;비피다발효용해물;자일리톨;안하이드로자일리톨;자일리틸글루코사이드;글루코오스;1,2-헥산다이올;흰버드나무껍질추출물;락토바이오닉애씨드;사탕수수추출물;쿠티박테리움그라눌로숨발효추출여과물;프룩토오스;프룩토올리고사카라이드;카프릴릭/카프릭트라이글리세라이드;벤질글라이콜;토코페롤;에틸헥실글리세린;잔탄검;다이소듐이디티에이;아이리쉬모스추출물;클로렐라불가리스추출물
# 제품명: 리얼 히알루로닉 100 토너, 전성분: 하이드롤라이즈드하이알루로닉애씨드(932601.50052ppm);글리세린;프로판다이올;하이드로제네이티드레시틴;소듐하이알루로네이트(1.0052ppm);1,2-헥산다이올;알지닌;벤질글라이콜;베타인;부틸렌글라이콜;카프릴릭/카프릭트라이글리세라이드;시트릭애씨드;다이메틸실란올하이알루로네이트;다이소듐이디티에이;에틸헥실글리세린;글라이신;히스티딘;하이알루로닉애씨드(1.00001ppm);하이드롤라이즈드글라이코사미노글리칸(0.0056ppm);하이드롤라이즈드소듐하이알루로네이트(1.5ppm);하이드록시프로필트라이모늄하이알루로네이트(0.80012ppm);라이소레시틴;포타슘하이알루로네이트;세린;소듐아세틸레이티드하이알루로네이트(0.400002ppm);소듐시트레이트;소듐하이알루로네이트크로스폴리머(0.801ppm);소듐하이알루로네이트다이메틸실란올;소듐피씨에이;소듐스테아로일글루타메이트;수크로오스라우레이트;토코페롤;정제수;잔탄검
# 제품명: 시카테롤 토너, 전성분: 정제수;프로판다이올;병풀추출물;1,2-헥산다이올;베타-시토스테롤
# ---
#         위 목록과 사용자 정보를 바탕으로, 각 제품의 '전성분'을 면밀히 분석하여 사용자에게 가장 적합한 제품 2~3개를 추천해주세요.
#         최종 답변에는 제품명, 추천 이유, 그리고 사용자 피부 타입에 유의해야 할 핵심 성분(있을 경우에만)만 간결하게 포함해주세요.
#         절대로 '전성분' 전체 목록을 답변에 보여주지 마세요.
#         ---
# 전문가로서 답변해주세요.
#
#
# > Finished chain.
#
# 챗봇: 고객님의 건성 피부와 보습 고민에 적합한 스킨/토너 제품을 추천해드리겠습니다.
#
# 1. **아쿠아 오아시스 토너**
#    - **추천 이유:** 이 토너는 여러 종류의 히알루론산 성분이 함유되어 있어 보습 효과가 뛰어납니다. 또한, 글리세린과 판테놀 등이 피부를 촉촉하게 유지하는 데 도움을 줍니다.
#
# 2. **다이브인 저분자 히알루론산 토너**
#    - **추천 이유:** 저분자 히알루론산이 빠르게 피부에 흡수되어 깊은 보습을 제공합니다. 또한, 알란토인과 판테놀 성분이 포함되어 피부를 진정시키고 수분 장벽을 강화합니다.
#
# 3. **판테놀 베리어 토너**
#    - **추천 이유:** 판테놀과 세라마이드 성분이 함유되어 있어 피부 장벽을 강화하고, 보습 효과가 우수합니다. 병풀추출물도 포함되어 있어 피부 진정에 도움을 줍니다.
#
# 이 세 가지 제품은 건성 피부를 위한 보습에 특히 효과적입니다. 제품 선택 시, 개인의 피부 상태와 성분에 대한 알레르기 반응 등을 고려하시기 바랍니다. 추가적인 질문이나 도움이 필요하시면 언제든지 말씀해 주세요!
#
# --- 추가 질문이 있으시면 편하게 입력해주세요. (종료: '종료') ---
# 챗봇을 종료합니다. 이용해주셔서 감사합니다.

# %%
import csv
import os
from langchain_openai import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate

# --- 사전 준비: OpenAI API 키 설정 ---
if not os.getenv("OPENAI_API_KEY"):
    print("="*60)
    print("경고: OPENAI_API_KEY 환경 변수가 설정되지 않았습니다.")
    # exit()

# --- 사용자 정보 입력 함수 (기존과 동일) ---
def get_user_selections():
    """
    사용자로부터 피부 타입, 피부 고민, 제품 종류를 입력받는 함수
    """
    skin_types = {1: '민감성', 2: '지성', 3: '건성', 4: '아토피성'}
    concerns = {1: '보습', 2: '진정', 3: '미백', 4: '주름/탄력', 5: '모공케어', 6: '피지조절'}
    categories = {
        1: '스킨/토너', 2: '로션/에멀젼', 3: '에센스/세럼/앰플', 4: '크림',
        5: '마스크/팩', 6: '클렌징', 7: '선크림/로션', 8: '올인원', 9: '바디로션'
    }

    print("--- 당신에게 꼭 맞는 화장품을 찾아드립니다! ---")
    
    # 피부 타입 선택
    print("\n✅ 당신의 피부 타입을 알려주세요:")
    for key, value in skin_types.items(): print(f"  {key}. {value}")
    while True:
        try:
            choice = int(input(">> 번호를 입력하세요: "))
            if choice in skin_types:
                selected_skin_type = skin_types[choice]; break
            else: print("⚠️ 잘못된 번호입니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자로만 입력해주세요.")

    # 피부 고민 선택 (다중 선택 가능)
    print("\n✅ 어떤 피부 고민을 해결하고 싶으신가요? (여러 개 선택 시 쉼표(,)로 구분)")
    for key, value in concerns.items(): print(f"  {key}. {value}")
    while True:
        try:
            choices_str = input(">> 번호를 입력하세요 (예: 1, 4): ")
            selected_concern_keys = [int(c.strip()) for c in choices_str.split(',')]
            if all(key in concerns for key in selected_concern_keys):
                selected_concerns = [concerns[key] for key in selected_concern_keys]; break
            else: print("⚠️ 목록에 없는 번호가 포함되어 있습니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자와 쉼표(,)로만 올바르게 입력해주세요.")

    # 제품 종류 선택
    print("\n✅ 어떤 종류의 제품을 찾으시나요?")
    for key, value in categories.items(): print(f"  {key}. {value}")
    while True:
        try:
            choice = int(input(">> 번호를 입력하세요: "))
            if choice in categories:
                selected_category = categories[choice]; break
            else: print("⚠️ 잘못된 번호입니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자로만 입력해주세요.")
            
    return selected_skin_type, selected_concerns, selected_category

# --- 데이터베이스 함수 (유해성 점수 포함하도록 수정) ---
def find_all_products(filepath, target_concerns, target_category):
    """CSV 파일에서 조건에 맞는 '모든' 제품 정보를 찾아 반환합니다."""
    found_products = []
    with open(filepath, mode='r', encoding='utf-8-sig') as infile:
        reader = csv.DictReader(infile)
        for row in reader:
            if row.get('카테고리') == target_category:
                product_efficacies = row.get('효능', '')
                if any(concern in product_efficacies for concern in target_concerns):
                    product_info = {
                        "name": row.get('제품명', 'N/A'),
                        "ingredients": row.get('전성분', ''),
                        "harmfulness_score": row.get('유해성_점수', '999') # 점수 없으면 높은 값 부여
                    }
                    found_products.append(product_info)
    return found_products

# --- LangChain 설정 ---
# (수정됨) temperature=0 으로 설정하여 답변의 일관성을 높입니다.
llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
memory = ConversationBufferMemory(memory_key="history")
template = "당신은 친절하고 전문적인 화장품 추천 전문가입니다.\n\n{history}\n\n사용자: {input}\n전문가:"
prompt = PromptTemplate(input_variables=["history", "input"], template=template)
conversation = ConversationChain(llm=llm, memory=memory, prompt=prompt, verbose=True)

# --- (신규) LLM을 이용해 주요 성분을 찾는 함수 ---
def get_key_ingredients_from_llm(skin_type, concerns):
    """LLM을 호출하여 사용자의 피부 타입과 고민에 맞는 주요 성분 목록을 웹서치를 통해 찾아옵니다."""
    # (수정됨) '화해' 사이트를 참고하라는 구체적인 지시사항 추가
    prompt = f"""
    화장품 정보 사이트 '화해'의 정보를 우선적으로 참고하고 웹 검색을 통해 다음 조건에 맞는 화장품 핵심 성분 5가지를 찾아주세요.
    - 피부 타입: {skin_type}
    - 주요 고민: {', '.join(concerns)}
    가장 대표적인 성분 5개를 쉼표(,)로 구분된 목록 형태로만 간결하게 답변해주세요. (예: 히알루론산,세라마이드,판테놀,병풀추출물,스쿠알란)
    """
    print("\n💬 LLM에게 핵심 성분을 문의하는 중...")
    response = llm.invoke(prompt)
    key_ingredients_str = response.content.strip()
    print(f"✅ 핵심 성분 목록 수신: {key_ingredients_str}")
    return [ing.strip() for ing in key_ingredients_str.split(',')]

# --- 메인 챗봇 실행 로직 (전면 수정) ---
def run_chat():
    # 1. 사용자로부터 구조화된 정보 입력받기
    skin_type, concerns, category = get_user_selections()
    print("\n🔍 좋습니다! 입력하신 정보를 바탕으로 분석을 시작합니다...")

    # 2. (신규) LLM을 통해 사용자 맞춤 '핵심 성분' 목록 가져오기
    key_ingredients = get_key_ingredients_from_llm(skin_type, concerns)

    # 3. CSV에서 1차 후보 제품군 필터링
    products = find_all_products('product_data.csv', concerns, category)

    # 4. (신규) 각 제품을 분석하고 점수 매기기
    scored_products = []
    for product in products:
        match_count = sum(1 for key_ing in key_ingredients if key_ing in product['ingredients'])
        product['match_count'] = match_count
        try:
            product['harmfulness_score'] = float(product['harmfulness_score'])
        except (ValueError, TypeError):
            product['harmfulness_score'] = 999.0
        scored_products.append(product)

    # 5. (신규) '핵심 성분 일치 개수'와 '유해성 점수'로 제품 정렬
    sorted_products = sorted(
        scored_products,
        key=lambda p: (-p['match_count'], p['harmfulness_score'])
    )

    # 6. 상위 3개 제품을 LLM에게 전달할 컨텍스트로 구성
    top_products = sorted_products[:3]
    
    product_context = ""
    if top_products:
        product_context += f"\n\n--- 참고: '{category}' 제품 중 '{', '.join(concerns)}' 고민에 대해 분석한 상위 제품 목록 ---\n"
        for p in top_products:
            product_context += f"제품명: {p['name']}, 핵심성분 포함 개수: {p['match_count']}, 유해성 점수: {p['harmfulness_score']}\n"
        product_context += """---
        위 목록은 명확한 기준(핵심성분 포함 개수, 유해성 점수)에 따라 선정된 최적의 제품들입니다.
        이 제품들을 사용자에게 추천하고, 왜 추천되었는지 각 제품의 장점을 친절하게 설명해주세요.
        ---"""
    else:
        product_context = "\n\n--- 참고: 아쉽게도 조건에 맞는 제품을 찾지 못했습니다. 이 점을 사용자에게 알리고 대화를 시작해주세요. ---\n"

    # 7. 필터링된 정보와 사용자 정보를 조합하여 첫 질문 생성
    initial_input = f"제 피부타입은 '{skin_type}'이고, 고민은 '{', '.join(concerns)}'입니다. '{category}' 종류 중에서 좋은 제품을 추천해주세요."
    full_input = initial_input + product_context

    # 8. 대화 체인에 첫 질문 전달 및 대화 시작
    print("\n💬 챗봇이 최종 추천 메시지를 생성 중입니다...")
    response = conversation.predict(input=full_input)
    print(f"\n챗봇: {response}")

    # 9. 후속 질문을 위한 대화 루프 시작
    print("\n--- 추가 질문이 있으시면 편하게 입력해주세요. (종료: '종료') ---")
    while True:
        user_input = input("당신: ")
        if user_input.lower() == '종료':
            print("챗봇을 종료합니다. 이용해주셔서 감사합니다.")
            break
        
        response = conversation.predict(input=user_input)
        print(f"챗봇: {response}")

if __name__ == '__main__':
    run_chat()
# Out:
# --- 당신에게 꼭 맞는 화장품을 찾아드립니다! ---
#
# ✅ 당신의 피부 타입을 알려주세요:
#   1. 민감성
#   2. 지성
#   3. 건성
#   4. 아토피성
# ✅ 어떤 피부 고민을 해결하고 싶으신가요? (여러 개 선택 시 쉼표(,)로 구분)
#   1. 보습
#   2. 진정
#   3. 미백
#   4. 주름/탄력
#   5. 모공케어
#   6. 피지조절
#
# ✅ 어떤 종류의 제품을 찾으시나요?
#   1. 스킨/토너
#   2. 로션/에멀젼
#   3. 에센스/세럼/앰플
#   4. 크림
#   5. 마스크/팩
#   6. 클렌징
#   7. 선크림/로션
#   8. 올인원
#   9. 바디로션
#
# 🔍 좋습니다! 입력하신 정보를 바탕으로 분석을 시작합니다...
#
# 💬 LLM에게 핵심 성분을 문의하는 중...
# ✅ 핵심 성분 목록 수신: 히알루론산,세라마이드,녹차추출물,알로에베라,병풀추출물
#
# 💬 챗봇이 최종 추천 메시지를 생성 중입니다...
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
# 당신은 친절하고 전문적인 화장품 추천 전문가입니다.
#
#
#
# 사용자: 제 피부타입은 '지성'이고, 고민은 '보습, 진정'입니다. '스킨/토너' 종류 중에서 좋은 제품을 추천해주세요.
#
# --- 참고: '스킨/토너' 제품 중 '보습, 진정' 고민에 대해 분석한 상위 제품 목록 ---
# 제품명: 판테놀 베리어 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.137931034482759
# 제품명: 어성초 진정해 수분 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.217391304347826
# 제품명: 원더 세라마이드 모찌 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.428571428571429
# ---
#         위 목록은 명확한 기준(핵심성분 포함 개수, 유해성 점수)에 따라 선정된 최적의 제품들입니다.
#         이 제품들을 사용자에게 추천하고, 왜 추천되었는지 각 제품의 장점을 친절하게 설명해주세요.
#         ---
# 전문가:
#
# > Finished chain.
#
# 챗봇: 안녕하세요! 지성 피부이면서 보습과 진정이 필요하신 분께 적합한 스킨/토너 제품을 추천드리겠습니다. 아래의 제품들은 핵심 성분의 포함 개수와 유해성 점수를 기준으로 선정된 최적의 제품들입니다.
#
# 1. **판테놀 베리어 토너**
#    - **장점**: 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수가 1.137로 가장 낮아 피부에 자극이 적습니다. 판테놀은 피부 장벽을 강화하고 수분을 유지하는 데 도움을 주어 지성 피부에도 적합한 보습 효과를 제공합니다. 또한, 피부 진정에도 효과적이어서 민감한 피부에도 잘 맞습니다.
#
# 2. **어성초 진정해 수분 토너**
#    - **장점**: 이 토너는 어성초 추출물을 포함하여 피부 진정에 탁월한 효과를 발휘합니다. 두 가지 핵심 성분이 포함되어 있으며, 유해성 점수는 1.217로 비교적 낮아 안전하게 사용할 수 있습니다. 지성 피부의 과잉 피지를 조절하면서도 충분한 수분을 공급하여 피부 균형을 맞춰줍니다.
#
# 3. **원더 세라마이드 모찌 토너**
#    - **장점**: 세라마이드는 피부 장벽을 강화하고 수분 손실을 방지하는 데 도움을 줍니다. 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수는 1.428로 약간 높지만 여전히 안전한 수준입니다. 지성 피부에도 부담 없이 사용할 수 있으며, 피부를 부드럽고 촉촉하게 유지하는 데 효과적입니다.
#
# 이 세 가지 제품은 모두 지성 피부에 적합하며, 보습과 진정 효과를 동시에 제공할 수 있는 제품들입니다. 각 제품의 장점을 고려하여 본인의 피부 상태와 선호에 맞는 제품을 선택해 보세요. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
#
# --- 추가 질문이 있으시면 편하게 입력해주세요. (종료: '종료') ---
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
# 당신은 친절하고 전문적인 화장품 추천 전문가입니다.
#
# Human: 제 피부타입은 '지성'이고, 고민은 '보습, 진정'입니다. '스킨/토너' 종류 중에서 좋은 제품을 추천해주세요.
#
# --- 참고: '스킨/토너' 제품 중 '보습, 진정' 고민에 대해 분석한 상위 제품 목록 ---
# 제품명: 판테놀 베리어 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.137931034482759
# 제품명: 어성초 진정해 수분 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.217391304347826
# 제품명: 원더 세라마이드 모찌 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.428571428571429
# ---
#         위 목록은 명확한 기준(핵심성분 포함 개수, 유해성 점수)에 따라 선정된 최적의 제품들입니다.
#         이 제품들을 사용자에게 추천하고, 왜 추천되었는지 각 제품의 장점을 친절하게 설명해주세요.
#         ---
# AI: 안녕하세요! 지성 피부이면서 보습과 진정이 필요하신 분께 적합한 스킨/토너 제품을 추천드리겠습니다. 아래의 제품들은 핵심 성분의 포함 개수와 유해성 점수를 기준으로 선정된 최적의 제품들입니다.
#
# 1. **판테놀 베리어 토너**
#    - **장점**: 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수가 1.137로 가장 낮아 피부에 자극이 적습니다. 판테놀은 피부 장벽을 강화하고 수분을 유지하는 데 도움을 주어 지성 피부에도 적합한 보습 효과를 제공합니다. 또한, 피부 진정에도 효과적이어서 민감한 피부에도 잘 맞습니다.
#
# 2. **어성초 진정해 수분 토너**
#    - **장점**: 이 토너는 어성초 추출물을 포함하여 피부 진정에 탁월한 효과를 발휘합니다. 두 가지 핵심 성분이 포함되어 있으며, 유해성 점수는 1.217로 비교적 낮아 안전하게 사용할 수 있습니다. 지성 피부의 과잉 피지를 조절하면서도 충분한 수분을 공급하여 피부 균형을 맞춰줍니다.
#
# 3. **원더 세라마이드 모찌 토너**
#    - **장점**: 세라마이드는 피부 장벽을 강화하고 수분 손실을 방지하는 데 도움을 줍니다. 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수는 1.428로 약간 높지만 여전히 안전한 수준입니다. 지성 피부에도 부담 없이 사용할 수 있으며, 피부를 부드럽고 촉촉하게 유지하는 데 효과적입니다.
#
# 이 세 가지 제품은 모두 지성 피부에 적합하며, 보습과 진정 효과를 동시에 제공할 수 있는 제품들입니다. 각 제품의 장점을 고려하여 본인의 피부 상태와 선호에 맞는 제품을 선택해 보세요. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
#
# 사용자: 그럼 만약에 보습에만 신경 쓴다고 하면 추천 제품이 어떻게 달라질까 ?
# 전문가:
#
# > Finished chain.
# 챗봇: 안녕하세요! 보습에만 중점을 두고 제품을 선택하신다면, 지성 피부에 적합하면서도 보습 효과가 뛰어난 제품을 추천드리겠습니다. 아래의 제품들은 보습에 특히 효과적인 성분을 포함하고 있으며, 지성 피부에도 잘 맞는 제품들입니다.
#
# 1. **판테놀 베리어 토너**
#    - **장점**: 판테놀은 피부 장벽을 강화하고 수분을 유지하는 데 탁월한 성분입니다. 이 제품은 유해성 점수가 낮아 피부에 자극이 적으며, 지성 피부에도 적합한 보습 효과를 제공합니다. 피부를 촉촉하게 유지하면서도 번들거림 없이 산뜻한 마무리를 선사합니다.
#
# 2. **원더 세라마이드 모찌 토너**
#    - **장점**: 세라마이드는 피부 장벽을 강화하고 수분 손실을 방지하는 데 도움을 줍니다. 이 제품은 지성 피부에도 부담 없이 사용할 수 있으며, 피부를 부드럽고 촉촉하게 유지하는 데 효과적입니다. 특히, 보습에 중점을 두고 싶으신 분들께 추천드립니다.
#
# 이 두 제품은 보습에 중점을 두고 선택할 수 있는 좋은 옵션들입니다. 지성 피부에 적합하면서도 충분한 보습을 제공할 수 있는 제품을 선택해 보세요. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
# 당신은 친절하고 전문적인 화장품 추천 전문가입니다.
#
# Human: 제 피부타입은 '지성'이고, 고민은 '보습, 진정'입니다. '스킨/토너' 종류 중에서 좋은 제품을 추천해주세요.
#
# --- 참고: '스킨/토너' 제품 중 '보습, 진정' 고민에 대해 분석한 상위 제품 목록 ---
# 제품명: 판테놀 베리어 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.137931034482759
# 제품명: 어성초 진정해 수분 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.217391304347826
# 제품명: 원더 세라마이드 모찌 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.428571428571429
# ---
#         위 목록은 명확한 기준(핵심성분 포함 개수, 유해성 점수)에 따라 선정된 최적의 제품들입니다.
#         이 제품들을 사용자에게 추천하고, 왜 추천되었는지 각 제품의 장점을 친절하게 설명해주세요.
#         ---
# AI: 안녕하세요! 지성 피부이면서 보습과 진정이 필요하신 분께 적합한 스킨/토너 제품을 추천드리겠습니다. 아래의 제품들은 핵심 성분의 포함 개수와 유해성 점수를 기준으로 선정된 최적의 제품들입니다.
#
# 1. **판테놀 베리어 토너**
#    - **장점**: 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수가 1.137로 가장 낮아 피부에 자극이 적습니다. 판테놀은 피부 장벽을 강화하고 수분을 유지하는 데 도움을 주어 지성 피부에도 적합한 보습 효과를 제공합니다. 또한, 피부 진정에도 효과적이어서 민감한 피부에도 잘 맞습니다.
#
# 2. **어성초 진정해 수분 토너**
#    - **장점**: 이 토너는 어성초 추출물을 포함하여 피부 진정에 탁월한 효과를 발휘합니다. 두 가지 핵심 성분이 포함되어 있으며, 유해성 점수는 1.217로 비교적 낮아 안전하게 사용할 수 있습니다. 지성 피부의 과잉 피지를 조절하면서도 충분한 수분을 공급하여 피부 균형을 맞춰줍니다.
#
# 3. **원더 세라마이드 모찌 토너**
#    - **장점**: 세라마이드는 피부 장벽을 강화하고 수분 손실을 방지하는 데 도움을 줍니다. 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수는 1.428로 약간 높지만 여전히 안전한 수준입니다. 지성 피부에도 부담 없이 사용할 수 있으며, 피부를 부드럽고 촉촉하게 유지하는 데 효과적입니다.
#
# 이 세 가지 제품은 모두 지성 피부에 적합하며, 보습과 진정 효과를 동시에 제공할 수 있는 제품들입니다. 각 제품의 장점을 고려하여 본인의 피부 상태와 선호에 맞는 제품을 선택해 보세요. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
# Human: 그럼 만약에 보습에만 신경 쓴다고 하면 추천 제품이 어떻게 달라질까 ?
# AI: 안녕하세요! 보습에만 중점을 두고 제품을 선택하신다면, 지성 피부에 적합하면서도 보습 효과가 뛰어난 제품을 추천드리겠습니다. 아래의 제품들은 보습에 특히 효과적인 성분을 포함하고 있으며, 지성 피부에도 잘 맞는 제품들입니다.
#
# 1. **판테놀 베리어 토너**
#    - **장점**: 판테놀은 피부 장벽을 강화하고 수분을 유지하는 데 탁월한 성분입니다. 이 제품은 유해성 점수가 낮아 피부에 자극이 적으며, 지성 피부에도 적합한 보습 효과를 제공합니다. 피부를 촉촉하게 유지하면서도 번들거림 없이 산뜻한 마무리를 선사합니다.
#
# 2. **원더 세라마이드 모찌 토너**
#    - **장점**: 세라마이드는 피부 장벽을 강화하고 수분 손실을 방지하는 데 도움을 줍니다. 이 제품은 지성 피부에도 부담 없이 사용할 수 있으며, 피부를 부드럽고 촉촉하게 유지하는 데 효과적입니다. 특히, 보습에 중점을 두고 싶으신 분들께 추천드립니다.
#
# 이 두 제품은 보습에 중점을 두고 선택할 수 있는 좋은 옵션들입니다. 지성 피부에 적합하면서도 충분한 보습을 제공할 수 있는 제품을 선택해 보세요. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
#
# 사용자: 그럼 나머지 하나가 진정에 더 탁월한 제품인 거야 ?
# 전문가:
#
# > Finished chain.
# 챗봇: 안녕하세요! 네, 맞습니다. 나머지 하나의 제품인 **어성초 진정해 수분 토너**는 진정 효과에 특히 탁월한 제품입니다.
#
# - **어성초 진정해 수분 토너**
#   - **장점**: 이 제품은 어성초 추출물을 포함하고 있어 피부 진정에 매우 효과적입니다. 지성 피부의 과잉 피지를 조절하면서도 피부를 진정시키고 균형을 맞춰줍니다. 유해성 점수도 비교적 낮아 안전하게 사용할 수 있습니다. 피부가 자주 붉어지거나 민감하게 반응하는 경우, 이 제품이 도움이 될 수 있습니다.
#
# 따라서, 진정 효과에 중점을 두고 싶으시다면 어성초 진정해 수분 토너를 고려해 보시는 것이 좋습니다. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
#
#
# > Entering new ConversationChain chain...
# Prompt after formatting:
# 당신은 친절하고 전문적인 화장품 추천 전문가입니다.
#
# Human: 제 피부타입은 '지성'이고, 고민은 '보습, 진정'입니다. '스킨/토너' 종류 중에서 좋은 제품을 추천해주세요.
#
# --- 참고: '스킨/토너' 제품 중 '보습, 진정' 고민에 대해 분석한 상위 제품 목록 ---
# 제품명: 판테놀 베리어 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.137931034482759
# 제품명: 어성초 진정해 수분 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.217391304347826
# 제품명: 원더 세라마이드 모찌 토너, 핵심성분 포함 개수: 2, 유해성 점수: 1.428571428571429
# ---
#         위 목록은 명확한 기준(핵심성분 포함 개수, 유해성 점수)에 따라 선정된 최적의 제품들입니다.
#         이 제품들을 사용자에게 추천하고, 왜 추천되었는지 각 제품의 장점을 친절하게 설명해주세요.
#         ---
# AI: 안녕하세요! 지성 피부이면서 보습과 진정이 필요하신 분께 적합한 스킨/토너 제품을 추천드리겠습니다. 아래의 제품들은 핵심 성분의 포함 개수와 유해성 점수를 기준으로 선정된 최적의 제품들입니다.
#
# 1. **판테놀 베리어 토너**
#    - **장점**: 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수가 1.137로 가장 낮아 피부에 자극이 적습니다. 판테놀은 피부 장벽을 강화하고 수분을 유지하는 데 도움을 주어 지성 피부에도 적합한 보습 효과를 제공합니다. 또한, 피부 진정에도 효과적이어서 민감한 피부에도 잘 맞습니다.
#
# 2. **어성초 진정해 수분 토너**
#    - **장점**: 이 토너는 어성초 추출물을 포함하여 피부 진정에 탁월한 효과를 발휘합니다. 두 가지 핵심 성분이 포함되어 있으며, 유해성 점수는 1.217로 비교적 낮아 안전하게 사용할 수 있습니다. 지성 피부의 과잉 피지를 조절하면서도 충분한 수분을 공급하여 피부 균형을 맞춰줍니다.
#
# 3. **원더 세라마이드 모찌 토너**
#    - **장점**: 세라마이드는 피부 장벽을 강화하고 수분 손실을 방지하는 데 도움을 줍니다. 이 제품은 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수는 1.428로 약간 높지만 여전히 안전한 수준입니다. 지성 피부에도 부담 없이 사용할 수 있으며, 피부를 부드럽고 촉촉하게 유지하는 데 효과적입니다.
#
# 이 세 가지 제품은 모두 지성 피부에 적합하며, 보습과 진정 효과를 동시에 제공할 수 있는 제품들입니다. 각 제품의 장점을 고려하여 본인의 피부 상태와 선호에 맞는 제품을 선택해 보세요. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
# Human: 그럼 만약에 보습에만 신경 쓴다고 하면 추천 제품이 어떻게 달라질까 ?
# AI: 안녕하세요! 보습에만 중점을 두고 제품을 선택하신다면, 지성 피부에 적합하면서도 보습 효과가 뛰어난 제품을 추천드리겠습니다. 아래의 제품들은 보습에 특히 효과적인 성분을 포함하고 있으며, 지성 피부에도 잘 맞는 제품들입니다.
#
# 1. **판테놀 베리어 토너**
#    - **장점**: 판테놀은 피부 장벽을 강화하고 수분을 유지하는 데 탁월한 성분입니다. 이 제품은 유해성 점수가 낮아 피부에 자극이 적으며, 지성 피부에도 적합한 보습 효과를 제공합니다. 피부를 촉촉하게 유지하면서도 번들거림 없이 산뜻한 마무리를 선사합니다.
#
# 2. **원더 세라마이드 모찌 토너**
#    - **장점**: 세라마이드는 피부 장벽을 강화하고 수분 손실을 방지하는 데 도움을 줍니다. 이 제품은 지성 피부에도 부담 없이 사용할 수 있으며, 피부를 부드럽고 촉촉하게 유지하는 데 효과적입니다. 특히, 보습에 중점을 두고 싶으신 분들께 추천드립니다.
#
# 이 두 제품은 보습에 중점을 두고 선택할 수 있는 좋은 옵션들입니다. 지성 피부에 적합하면서도 충분한 보습을 제공할 수 있는 제품을 선택해 보세요. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
# Human: 그럼 나머지 하나가 진정에 더 탁월한 제품인 거야 ?
# AI: 안녕하세요! 네, 맞습니다. 나머지 하나의 제품인 **어성초 진정해 수분 토너**는 진정 효과에 특히 탁월한 제품입니다.
#
# - **어성초 진정해 수분 토너**
#   - **장점**: 이 제품은 어성초 추출물을 포함하고 있어 피부 진정에 매우 효과적입니다. 지성 피부의 과잉 피지를 조절하면서도 피부를 진정시키고 균형을 맞춰줍니다. 유해성 점수도 비교적 낮아 안전하게 사용할 수 있습니다. 피부가 자주 붉어지거나 민감하게 반응하는 경우, 이 제품이 도움이 될 수 있습니다.
#
# 따라서, 진정 효과에 중점을 두고 싶으시다면 어성초 진정해 수분 토너를 고려해 보시는 것이 좋습니다. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
#
# 사용자: 진정을 더 중점적으로 본다고 하면 어떤 제품을 추천해 줄 수 있으려나 ?
# 전문가:
#
# > Finished chain.
# 챗봇: 안녕하세요! 진정 효과에 중점을 두고 제품을 선택하신다면, 지성 피부에 적합하면서도 진정 효과가 뛰어난 제품을 추천드리겠습니다. 아래의 제품은 진정에 특히 효과적인 성분을 포함하고 있으며, 지성 피부에도 잘 맞는 제품입니다.
#
# 1. **어성초 진정해 수분 토너**
#    - **장점**: 이 제품은 어성초 추출물을 포함하고 있어 피부 진정에 매우 효과적입니다. 어성초는 피부의 염증을 완화하고 자극을 줄이는 데 도움을 주어, 민감한 피부에도 잘 맞습니다. 또한, 지성 피부의 과잉 피지를 조절하면서도 피부를 진정시키고 균형을 맞춰줍니다. 유해성 점수도 비교적 낮아 안전하게 사용할 수 있습니다.
#
# 이 제품은 진정 효과에 중점을 두고 선택할 수 있는 좋은 옵션입니다. 피부가 자주 붉어지거나 민감하게 반응하는 경우, 어성초 진정해 수분 토너가 도움이 될 수 있습니다. 추가적인 질문이 있으시면 언제든지 문의해 주세요!
# 챗봇을 종료합니다. 이용해주셔서 감사합니다.

# %%
import os
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate

# --- 사전 준비: OpenAI API 키 설정 ---
if not os.getenv("OPENAI_API_KEY"):
    print("="*60)
    print("경고: OPENAI_API_KEY 환경 변수가 설정되지 않았습니다.")
    # 실제 프로덕션에서는 exit() 등으로 종료 처리를 하는 것이 좋습니다.

# --- 1. 사용자 정보 입력 ---
def get_user_selections():
    """
    사용자로부터 피부 타입, 피부 고민, 제품 종류를 입력받는 함수
    """
    skin_types = {1: '민감성', 2: '지성', 3: '건성', 4: '아토피성', 5: '복합성'}
    concerns = {1: '보습', 2: '진정', 3: '미백', 4: '주름/탄력', 5: '모공케어', 6: '피지조절'}
    categories = {
        1: '스킨/토너', 2: '로션/에멀젼', 3: '에센스/앰플/세럼', 4: '크림',
        5: '밤/멀티밤', 6: '클렌징 폼', 7: '시트마스크', 8: '선크림/로션'
    }

    print("--- 당신에게 꼭 맞는 화장품을 찾아드립니다! ---")
    
    # 피부 타입 선택
    print("\n✅ 당신의 피부 타입을 알려주세요:")
    for key, value in skin_types.items(): print(f"  {key}. {value}")
    while True:
        try:
            choice = int(input(">> 번호를 입력하세요: "))
            if choice in skin_types:
                selected_skin_type = skin_types[choice]; break
            else: print("⚠️ 잘못된 번호입니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자로만 입력해주세요.")

    # 피부 고민 선택 (다중 선택 가능)
    print("\n✅ 어떤 피부 고민을 해결하고 싶으신가요? (여러 개 선택 시 쉼표(,)로 구분)")
    for key, value in concerns.items(): print(f"  {key}. {value}")
    while True:
        try:
            choices_str = input(">> 번호들을 입력하세요 (예: 1, 4): ")
            selected_concern_keys = [int(c.strip()) for c in choices_str.split(',')]
            if all(key in concerns for key in selected_concern_keys):
                selected_concerns = [concerns[key] for key in selected_concern_keys]; break
            else: print("⚠️ 목록에 없는 번호가 포함되어 있습니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자와 쉼표(,)로만 올바르게 입력해주세요.")

    # 제품 종류 선택
    print("\n✅ 어떤 종류의 제품을 찾으시나요?")
    for key, value in categories.items(): print(f"  {key}. {value}")
    while True:
        try:
            choice = int(input(">> 번호를 입력하세요: "))
            if choice in categories:
                selected_category = categories[choice]; break
            else: print("⚠️ 잘못된 번호입니다. 다시 입력해주세요.")
        except ValueError: print("⚠️ 숫자로만 입력해주세요.")
            
    return selected_skin_type, selected_concerns, selected_category

# --- 2. LangChain 및 LLM 설정 ---
llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
memory = ConversationBufferMemory(memory_key="history")
template = "당신은 친절하고 전문적인 화장품 추천 전문가입니다.\n\n{history}\n\n사용자: {input}\n전문가:"
prompt = PromptTemplate(input_variables=["history", "input"], template=template)
conversation = ConversationChain(llm=llm, memory=memory, prompt=prompt, verbose=False)

# --- 3. 데이터 처리 및 추천 로직 ---
def get_key_ingredients_from_llm(skin_type, concerns):
    """LLM을 호출하여 사용자 맞춤 '핵심 성분' 목록을 찾아옵니다."""
    prompt_text = f"""
    화장품 정보 사이트 '화해'의 정보를 우선적으로 참고하고 웹 검색을 통해 다음 조건에 맞는 화장품 핵심 성분 5가지를 찾아주세요.
    - 피부 타입: {skin_type}
    - 주요 고민: {', '.join(concerns)}
    가장 대표적인 성분 5개를 쉼표(,)로 구분된 목록 형태로만 간결하게 답변해주세요. (예: 히알루론산,세라마이드,판테놀,병풀추출물,스쿠알란)
    """
    print("\n💬 LLM에게 핵심 성분을 문의하는 중...")
    response = llm.invoke(prompt_text)
    key_ingredients_str = response.content.strip()
    print(f"✅ 핵심 성분 목록 수신: {key_ingredients_str}")
    return [ing.strip().lower() for ing in key_ingredients_str.split(',')]

def find_and_rank_products(filepath, user_selections, key_ingredients):
    """Pandas로 제품을 필터링하고, 점수를 매겨 상위 3개 제품을 반환합니다."""
    skin_type, concerns, category = user_selections
    
    try:
        df = pd.read_csv(filepath)
    except FileNotFoundError:
        print(f"❌ 오류: '{filepath}' 파일을 찾을 수 없습니다.")
        return []

    # 1. 카테고리와 효능으로 1차 필터링
    filtered_df = df[df['카테고리'] == category].copy()
    for concern in concerns:
        filtered_df = filtered_df[filtered_df['효능'].str.contains(concern, na=False)]
    
    if filtered_df.empty:
        return []
    
    print(f"\n✅ 1차적으로 {len(filtered_df)}개의 제품을 찾았습니다. 이제 각 제품의 점수를 계산합니다.")

    # 2. 각 제품의 점수 계산
    scored_products = []
    for index, row in filtered_df.iterrows():
        ingredients_str = str(row.get('전성분', '')).lower()
        
        found_ingredients = [key_ing for key_ing in key_ingredients if key_ing in ingredients_str]
        match_count = len(found_ingredients)
        
        try:
            harmfulness_score = float(row.get('유해성_점수', 999))
        except (ValueError, TypeError):
            harmfulness_score = 999.0

        scored_products.append({
            "brand": row.get('브랜드명'),
            "name": row.get('제품명'),
            "match_count": match_count,
            "harmfulness_score": harmfulness_score,
            "found_ingredients": found_ingredients
        })
    
    # 3. 점수 기준으로 정렬
    sorted_products = sorted(
        scored_products,
        key=lambda p: (-p['match_count'], p['harmfulness_score'])
    )
    
    return sorted_products[:3] # 상위 3개 제품 반환

# --- 4. 메인 챗봇 실행 로직 ---
def run_chat():
    # 사용자 정보 입력받기
    user_selections = get_user_selections()
    skin_type, concerns, category = user_selections
    print("\n🔍 좋습니다! 입력하신 정보를 바탕으로 분석을 시작합니다...")

    # LLM을 통해 사용자 맞춤 '핵심 성분' 목록 가져오기
    key_ingredients = get_key_ingredients_from_llm(skin_type, concerns)

    # 제품 필터링 및 순위 선정
    top_products = find_and_rank_products('product_data.csv', user_selections, key_ingredients)
    
    initial_input = f"제 피부타입은 '{skin_type}'이고, 고민은 '{', '.join(concerns)}'입니다. '{category}' 종류 중에서 좋은 제품을 추천해주세요."
    
    recommendation_message = ""

    if top_products:
        # 예쁜 결과창 형식으로 추천 메시지 생성
        recommendation_message += "\n" + "="*60 + "\n"
        recommendation_message += f"     ✨ 최종 TOP 3 제품 추천 ✨\n"
        recommendation_message += "="*60 + "\n"
        for i, product in enumerate(top_products):
            recommendation_message += f"\n🏆 TOP {i+1}. {product['brand']} - {product['name']}\n"
            recommendation_message += f"  - 핵심 성분 포함 개수: {product['match_count']}개\n"
            recommendation_message += f"  - 포함된 주요 성분: {', '.join(product['found_ingredients'])}\n"
            recommendation_message += f"  - 유해성 점수: {product['harmfulness_score']}\n"
        
        print(recommendation_message)
        
        # LangChain에게 전달할 프롬프트를 더 구체적이고 예쁘게 꾸미도록 지시
        summary_prompt = f"""
        당신은 방금 사용자에게 아래와 같은 내용으로 제품을 추천했습니다.
        ---
        {recommendation_message}
        ---
        이 추천 결과에 대해, 아래 [출력 형식 예시]를 참고하여 이모지(emoji)를 사용해서 보기 좋고 예쁘게 최종 요약 메시지를 생성해주세요.
        각 제품(TOP 1, TOP 2, TOP 3)을 언급하고, 핵심 성분 포함 개수나 유해성 점수 같은 핵심적인 추천 이유를 간략히 덧붙여주세요.
        마지막에는 사용자에게 추가 질문을 유도하며 자연스럽게 대화를 마무리해주세요.

        [출력 형식 예시]
        ✨ 고객님의 피부 타입과 고민을 바탕으로 최고의 제품들을 소개해 드릴게요!

        🥇 **1위 {top_products[0]['name']}**
           - 추천 이유: 핵심 성분을 무려 {top_products[0]['match_count']}개나 포함하고 있어요!

        🥈 **2위 {top_products[1]['name']}**
           - 추천 이유: 유해성 점수도 낮고, {top_products[1]['match_count']}개의 핵심 성분을 담아 두 번째로 추천해 드려요.
        
        🥉 **3위 {top_products[2]['name']}**
           - 추천 이유: 훌륭한 선택이 될 수 있는 세 번째 제품입니다.

        이 제품들에 대해 더 궁금한 점이 있으시면 언제든지 물어보세요! 😊
        """
        initial_response = conversation.predict(input=summary_prompt)
        print(f"\n챗봇: {initial_response}")

    else:
        # 추천 제품이 없을 경우
        not_found_message = "아쉽게도 모든 조건을 만족하는 제품을 찾지 못했습니다. 다른 조건으로 다시 시도해보시겠어요?"
        print(f"\n챗봇: {not_found_message}")
        memory.save_context({"input": initial_input}, {"output": not_found_message})

    # 후속 질문을 위한 대화 루프 시작
    print("\n--- 추가 질문이 있으시면 편하게 입력해주세요. (종료: '종료') ---")
    while True:
        user_input = input("당신: ")
        if user_input.lower() == '종료':
            print("챗봇을 종료합니다. 이용해주셔서 감사합니다.")
            break
        
        response = conversation.predict(input=user_input)
        print(f"챗봇: {response}")

if __name__ == '__main__':
    run_chat()
# Out:
# --- 당신에게 꼭 맞는 화장품을 찾아드립니다! ---
#
# ✅ 당신의 피부 타입을 알려주세요:
#   1. 민감성
#   2. 지성
#   3. 건성
#   4. 아토피성
# C:\Users\sec\AppData\Local\Temp\ipykernel_13940\300415462.py:66: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory(memory_key="history")
# C:\Users\sec\AppData\Local\Temp\ipykernel_13940\300415462.py:69: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use :class:`~langchain_core.runnables.history.RunnableWithMessageHistory` instead.
#   conversation = ConversationChain(llm=llm, memory=memory, prompt=prompt, verbose=False)
# ✅ 어떤 피부 고민을 해결하고 싶으신가요? (여러 개 선택 시 쉼표(,)로 구분)
#   1. 보습
#   2. 진정
#   3. 미백
#   4. 주름/탄력
#   5. 모공케어
#   6. 피지조절
#
# ✅ 어떤 종류의 제품을 찾으시나요?
#   1. 스킨/토너
#   2. 로션/에멀젼
#   3. 에센스/세럼/앰플
#   4. 크림
#   5. 마스크/팩
#   6. 클렌징
#   7. 선크림/로션
#   8. 올인원
#   9. 바디로션
#
# 🔍 좋습니다! 입력하신 정보를 바탕으로 분석을 시작합니다...
#
# 💬 LLM에게 핵심 성분을 문의하는 중...
# ✅ 핵심 성분 목록 수신: 히알루론산,세라마이드,판테놀,녹차추출물,알로에베라
#
# ✅ 1차적으로 15개의 제품을 찾았습니다. 이제 각 제품의 점수를 계산합니다.
#
# ============================================================
#      ✨ 최종 TOP 3 제품 추천 ✨
# ============================================================
#
# 🏆 TOP 1. 이플미 - 하이드라 셀 부스팅 토너
#   - 핵심 성분 포함 개수: 2개
#   - 포함된 주요 성분: 판테놀, 녹차추출물
#   - 유해성 점수: 1.090909090909091
#
# 🏆 TOP 2. 코스노리 - 판테놀 베리어 토너
#   - 핵심 성분 포함 개수: 2개
#   - 포함된 주요 성분: 세라마이드, 판테놀
#   - 유해성 점수: 1.137931034482759
#
# 🏆 TOP 3. 마녀공장 - 비피다 바이옴 앰플 토너
#   - 핵심 성분 포함 개수: 2개
#   - 포함된 주요 성분: 세라마이드, 판테놀
#   - 유해성 점수: 1.137931034482759
#
#
# 챗봇: ✨ 고객님의 피부 타입과 고민을 바탕으로 최고의 제품들을 소개해 드릴게요!
#
# 🥇 **1위 이플미 - 하이드라 셀 부스팅 토너**
#    - 추천 이유: 판테놀과 녹차추출물, 두 가지 핵심 성분을 포함하고 있으며, 유해성 점수가 낮아요!
#
# 🥈 **2위 코스노리 - 판테놀 베리어 토너**
#    - 추천 이유: 세라마이드와 판테놀을 포함하고 있으며, 유해성 점수도 낮아 두 번째로 추천해 드려요.
#
# 🥉 **3위 마녀공장 - 비피다 바이옴 앰플 토너**
#    - 추천 이유: 세라마이드와 판테놀을 포함한 훌륭한 선택이 될 수 있는 세 번째 제품입니다.
#
# 이 제품들에 대해 더 궁금한 점이 있으시면 언제든지 물어보세요! 😊 추가로 다른 피부 고민이 있으신가요?
#
# --- 추가 질문이 있으시면 편하게 입력해주세요. (종료: '종료') ---
# 챗봇: 물론입니다! 😊 고객님의 피부 타입과 고민을 바탕으로 최적의 제품을 추천해 드리겠습니다. 피부 타입이나 특정한 피부 고민이 있으시면 말씀해 주세요. 그에 맞춰 더욱 맞춤형 추천을 드릴 수 있습니다. 어떤 제품을 찾고 계신지 알려주시면 기쁜 마음으로 도와드리겠습니다! 🌟
# 챗봇: 물론입니다! 😊 지성 피부이면서도 보습이 필요한 고객님께 적합한 토너를 추천해 드릴게요. 지성 피부는 유분이 많아 보습 제품 선택이 중요하죠. 아래 제품들을 고려해 보세요:
#
# ✨ **1위 이플미 - 하이드라 셀 부스팅 토너**
#    - 추천 이유: 판테놀과 녹차추출물이 함유되어 있어 보습과 진정 효과를 동시에 제공합니다. 유해성 점수도 낮아 안심하고 사용하실 수 있어요!
#
# ✨ **2위 코스노리 - 판테놀 베리어 토너**
#    - 추천 이유: 세라마이드와 판테놀로 피부 장벽을 강화하면서도 보습을 제공합니다. 유해성 점수도 낮아 지성 피부에 적합합니다.
#
# ✨ **3위 마녀공장 - 비피다 바이옴 앰플 토너**
#    - 추천 이유: 세라마이드와 판테놀이 함유되어 있어 보습과 피부 장벽 강화에 도움을 줍니다. 지성 피부에도 부담 없이 사용할 수 있는 제품입니다.
#
# 이 제품들에 대해 더 궁금한 점이 있으시면 언제든지 물어보세요! 😊 추가로 다른 피부 고민이 있으신가요?
# 챗봇: 하이드라 셀 부스팅 토너는 건성 피부에도 적합한 보습 효과를 제공할 수 있습니다. 이 제품은 판테놀과 녹차추출물 같은 보습 및 진정 성분을 함유하고 있어 피부에 수분을 공급하고 유지하는 데 도움을 줍니다. 건성 피부는 특히 수분을 잘 유지하는 것이 중요하므로, 이 토너는 피부에 필요한 수분을 공급하고 촉촉함을 유지하는 데 기여할 수 있습니다.
#
# 하지만, 건성 피부의 경우 토너 사용 후 추가적인 보습제를 함께 사용하는 것이 더욱 효과적일 수 있습니다. 만약 더 궁금한 점이 있거나 다른 제품에 대한 정보가 필요하시면 언제든지 말씀해 주세요! 😊
# 챗봇: 물론입니다! 😊 건성 피부에 적합한 로션을 추천해 드릴게요. 건성 피부는 수분과 영양 공급이 중요하므로, 보습력이 뛰어난 제품을 선택하는 것이 좋습니다. 아래 제품들을 고려해 보세요:
#
# ✨ **1위 세타필 - 모이스춰라이징 로션**
#    - 추천 이유: 이 로션은 피부에 빠르게 흡수되며, 오랜 시간 동안 수분을 유지해 줍니다. 민감한 피부에도 적합하여 건성 피부에 안성맞춤입니다.
#
# ✨ **2위 아비노 - 데일리 모이스춰라이징 로션**
#    - 추천 이유: 오트밀 성분이 함유되어 있어 피부를 진정시키고 보습을 강화합니다. 끈적임 없이 부드럽게 발리며, 건조한 피부에 효과적입니다.
#
# ✨ **3위 라로슈포제 - 리피카 밤 AP+M**
#    - 추천 이유: 이 로션은 피부 장벽을 강화하고, 건조함을 완화하는 데 도움을 줍니다. 특히 극건성 피부에도 적합한 제품입니다.
#
# 이 제품들에 대해 더 궁금한 점이 있으시면 언제든지 물어보세요! 😊 추가로 다른 피부 고민이나 제품 추천이 필요하시면 언제든지 말씀해 주세요!
# 챗봇을 종료합니다. 이용해주셔서 감사합니다.
